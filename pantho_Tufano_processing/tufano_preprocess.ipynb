# %%
# !dir "../codes"
# Out:
#  Volume in drive E has no label.
#  Volume Serial Number is 825C-A14C
#
#  Directory of E:\codes
#
# 10/22/2019  11:54 PM    <DIR>          .
# 10/22/2019  11:54 PM    <DIR>          ..
# 10/22/2019  11:48 PM    <DIR>          .bazelproject
# 10/22/2019  11:48 PM    <DIR>          .bazelrc
# 10/22/2019  11:48 PM    <DIR>          .bazelversion
# 10/22/2019  11:48 PM    <DIR>          .buckconfig
# 10/22/2019  11:48 PM    <DIR>          .buckversion
# 10/22/2019  11:49 PM    <DIR>          .clang-format
# 10/22/2019  11:49 PM    <DIR>          .coveragerc
# 10/22/2019  11:49 PM    <DIR>          .env
# 10/22/2019  11:49 PM    <DIR>          .evergreen-config.yml
# 10/22/2019  11:49 PM    <DIR>          .fixtures.yml
# 10/22/2019  11:49 PM    <DIR>          .fixtures.yml.local
# 10/22/2019  11:49 PM    <DIR>          .gitattributes
# 10/22/2019  11:49 PM    <DIR>          .githooks-pre-commit
# 10/22/2019  11:49 PM    <DIR>          .githooks-pre-push
# ...

# %%
import os
def getListOfFiles(dirName):
    # create a list of file and sub directories 
    # names in the given directory 
    listOfFile = os.listdir(dirName)
    allFiles = list()
    # Iterate over all the entries
    for entry in listOfFile:
        # Create full path
        fullPath = os.path.join(dirName, entry)
        # If entry is a directory then get the list of files in this directory 
        if os.path.isdir(fullPath):
            allFiles = allFiles + getListOfFiles(fullPath)
        else:
            allFiles.append(fullPath)
                
    return allFiles
files = getListOfFiles("../codes/")

# %%
print(len(files))
print(files[-10:])
# Out:
# 187539
# ['../codes/polarsys_95\\2.java', '../codes/polarsys_96\\10.ecore', '../codes/polarsys_96\\9.ecore', '../codes/polarsys_97\\2.properties', '../codes/polarsys_97\\3.properties', '../codes/polarsys_98\\2.xml', '../codes/polarsys_98\\3.xml', '../codes/polarsys_99\\2.xml', '../codes/polarsys_99\\3.xml', '../codes/polarsys_MapJSON.json']

# %%
java_files = []
for f in files:
    if f[-4:]=='java':
        java_files.append(f)
print(len(java_files))
s = "abc"
f = s
f = "2"
print(s, f)
# Out:
# 91003
# abc 2

# %%
import subprocess
s = "../codes/polarsys_95\\2.java"
s = s.replace("codes", "pantho_Tufano_processing/processed")
s = s.replace("\\", "/")
s = s.split("/")
file_name = s[-1]
s = '/'.join(s[:-1])
print(s)
print(file_name)
# Out:
# ../pantho_Tufano_processing/processed/polarsys_95
# 2.java

# %%
java -jar src2abs-0.1-jar-with-dependencies.jar single class f <output_abstract_path> idioms.csv

# %%
from pathlib import Path
def read(path):
    return open(path, 'r', encoding = 'utf-8').read()

for f in java_files:
    java_cmd = "java -jar src2abs-0.1-jar-with-dependencies.jar single class "
    java_cmd = java_cmd + f+" "
    s = f
    s = s.replace("codes", "pantho_Tufano_processing/processed")
    s = s.replace("\\", "/")
    s = s.split("/")
    file_name = s[-1]
    path = '/'.join(s[:-1])
    s = '/'.join(s)
    Path(path).mkdir(parents=True, exist_ok=True)
    java_cmd = java_cmd+s+' idioms.csv'
    check = subprocess.call(java_cmd.replace('/', '\\'), shell=True)
    #print(java_cmd)
    if check != 0:
        print(java_cmd)
        print("java cmd execusion failed on file ", f)
    #else:
    #    os.rename(s+'\\out.java', s+'\\'+file_name)
    #    os.rename(s+'\\out.java.map', s+'\\'+file_name+".map")

# %%
def getJsonData(JsonFile):
    with open(JsonFile, encoding="utf8") as f:
        data = json.load(f)
    return data

def read(path):
    return open(path, 'r', encoding = 'utf-8').read()

unique_data = getJsonData('unique_data.json')
for data in unique_data:
    java_cmd = "java -jar src2abs-0.1-jar-with-dependencies.jar single class "
    java_cmd = java_cmd + f+" "
    s = f
    s = s.replace("codes", "pantho_Tufano_processing/unique_data_processed")
    s = s.replace("\\", "/")
    s = s.split("/")
    file_name = s[-1]
    path = '/'.join(s[:-1])
    s = '/'.join(s)
    Path(path).mkdir(parents=True, exist_ok=True)
    java_cmd = java_cmd+s+' idioms.csv'
    check = subprocess.call(java_cmd.replace('/', '\\'), shell=True)
    #print(java_cmd)
    if check != 0:
        print(java_cmd)
        print("java cmd execusion failed on file ", f)
# Out:
# ../codes/acumos_12\1.java
# ['pantho', 'abc', 'de', 'fs']

# %%
import json
def getJsonData(JsonFile):
    with open(JsonFile, encoding="utf8") as f:
        data = json.load(f)
    return data

def read(path):
    return open(path, 'r', encoding = 'utf-8').read()

unique_data = getJsonData('unique_data.json')
print(unique_data[0])
data = unique_data[0]
# Out:
# {'actual_line_number': 5, 'base_code_line_number': 6, 'base_patch_number': 2, 'changed_code': ' * Copyright (C) 2017 AT&T Intellectual Property & Tech Mahindra. All rights reserved.', 'changed_patch_number': 4, 'code_file_name': 'acumos_647', 'comment_id': 'c80bb11f_61c30f6e1', 'line_change': 1, 'message': 'This is an ugly copyright line.  Please fix in all files.', 'previous_code': ' * Copyright (C) 2017 AT&T Intellectual'}

# %%
data = unique_data[10]
f = '../codes/'+data['code_file_name']+'/'+str(data['base_patch_number'])+'.java'
main_code = read(f)
line_no = data['base_code_line_number']
main_code = main_code.split("\n")
main_code.insert(line_no-1, 'string "Start focus";')
main_code.insert(line_no+2, "string 'end focus';")
main_code = "\n".join(main_code)
print(main_code)
java_cmd = "java -jar src2abs-0.1-jar-with-dependencies.jar single method "
java_cmd = java_cmd + f+" "
s = f
s = s.replace("codes", "pantho_Tufano_processing/unique_data_processed")
s = s.replace("\\", "/")
s = s.split("/")
file_name = s[-1]
path = '/'.join(s[:-1])
s = '/'.join(s)
Path(path).mkdir(parents=True, exist_ok=True)
java_cmd = java_cmd+s+' idioms.csv'
check = subprocess.call(java_cmd.replace('/', '\\'), shell=True)
#print(java_cmd)
if check != 0:
    print(java_cmd)
    print("java cmd execusion failed on file ", f)
# Out:
#  * ===============LICENSE_START=======================================================
#  * Acumos
#  * ===================================================================================
#  * Copyright (C) 2017 AT&T Intellectual Property & Tech Mahindra. All rights reserved.
#  * ===================================================================================
#  * This Acumos software file is distributed by AT&T and Tech Mahindra
#  * under the Apache License, Version 2.0 (the "License");
#  * you may not use this file except in compliance with the License.
#  * You may obtain a copy of the License at
#  *
#  *      http://www.apache.org/licenses/LICENSE-2.0
#  *
#  * This file is distributed on an "AS IS" BASIS,
#  * WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#  * See the License for the specific language governing permissions and
#  * limitations under the License.
# ...

# %%
print(dic)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-c27a91a536de> in <module>
# ----> 1 print(dic)
#
# NameError: name 'dic' is not defined

# %%
import os
def getListOfFiles(dirName):
    # create a list of file and sub directories 
    # names in the given directory 
    listOfFile = os.listdir(dirName)
    allFiles = list()
    # Iterate over all the entries
    for entry in listOfFile:
        # Create full path
        fullPath = os.path.join(dirName, entry)
        # If entry is a directory then get the list of files in this directory 
        if os.path.isdir(fullPath):
            allFiles = allFiles + getListOfFiles(fullPath)
        else:
            allFiles.append(fullPath)
                
    return allFiles
files = getListOfFiles("../codes/")
print(len(files))
# Out:
# 187662

# %%
java_files = []
for f in files:
    if f[-4:]=='java':
        java_files.append(f)
print(len(java_files))
s = "abc"
f = s
f = "2"
print(s,f)
# Out:
# 91126
# abc 2

# %%
method_files = getListOfFiles("../pantho_Tufano_processing/processed/") #91003
print(len(method_files)/2)
# Out:
# 91003.0

# %%
import json
def getJsonData(JsonFile):
    with open(JsonFile, encoding="utf8") as f:
        data = json.load(f)
    return data

def read(path):
    return open(path, 'r', encoding = 'utf-8').read()

unique_data = getJsonData('unique_data.json')
print(len(unique_data))
print(unique_data[0])
l = []

for data in unique_data:
    l.append(data['code_file_name']+data[''])
len(set(l))
# Out:
# {'actual_line_number': 5, 'base_code_line_number': 6, 'base_patch_number': 2, 'changed_code': ' * Copyright (C) 2017 AT&T Intellectual Property & Tech Mahindra. All rights reserved.', 'changed_patch_number': 4, 'code_file_name': 'acumos_647', 'comment_id': 'c80bb11f_61c30f6e1', 'line_change': 1, 'message': 'This is an ugly copyright line.  Please fix in all files.', 'previous_code': ' * Copyright (C) 2017 AT&T Intellectual'}
# 0

# %%
print(unique_data[14818])
print(unique_data[14819])
# Out:
# {'actual_line_number': 76, 'base_code_line_number': 77, 'base_patch_number': 1, 'changed_code': '                    lockManager.lock(datasetId, -1, LockMode.X, txnCtx);', 'changed_patch_number': 2, 'code_file_name': 'asterix_864', 'comment_id': '3aa0d159_25ca14a215161', 'line_change': 1, 'message': 'The third parameter should be LockMode.S instead of 1(which is LockMode.IS and this IS lockmode will allow concurrent modification by other transactions)', 'previous_code': '                    lockManager.lock(datasetId, -1, (byte) 1, txnCtx);'}
# ...

# %%
print(len(unique_data))
# Out:
# 55836

# %%
print(unique_data[26264])
print(unique_data[26265])
# Out:
# {'actual_line_number': 394, 'base_code_line_number': 394, 'base_patch_number': 11, 'changed_code': '  // backend lib-cache entry. Returns -1 if a modified time is not applicable.', 'changed_patch_number': 12, 'code_file_name': 'cloudera_1585', 'comment_id': '5a1bcf29_3c6b0a5c37048', 'line_change': 1, 'message': 'not necessary obvious that the lib cache is in the BE, so better "in its backend lib-cache entry"', 'previous_code': '  // lib-cache entry. Returns -1 if a modified time is not applicable.'}
# ...

# %%
print(unique_data[38710])
# Out:
# {'actual_line_number': 70, 'base_code_line_number': 71, 'base_patch_number': 1, 'changed_code': '\t\t\t\t\t.thenAcceptAsync(languageServers ->', 'changed_patch_number': 2, 'code_file_name': 'eclipse_5134', 'comment_id': '5b7a99c6_d020b91b50025', 'line_change': 1, 'message': 'allLinks should now be made a variable, and shared between both futures.', 'previous_code': '\t\t\t\t.thenComposeAsync(languageServers -> {'}

# %%
from os import path
import subprocess
def getJsonData(JsonFile):
    with open(JsonFile, encoding="utf8") as f:
        data = json.load(f)
    return data

def read(path):
    return open(path, 'r', encoding = 'utf-8').read()

unique_data = getJsonData('unique_data.json')
for data in unique_data:
    code_file_name = data['code_file_name']
    base_patch_number = data['base_patch_number']
    main_code_path = "../pantho_Tufano_processing/method_data_processed/"+code_file_name+'/'+str(base_patch_number)+'.java'
    #code_data = read(main_code_path)
    #print(main_code_path)
    if(path.exists(main_code_path)):
        f = main_code_path
        java_cmd = "java -jar src2abs-0.1-jar-with-dependencies.jar single method "
        java_cmd = java_cmd + f+" "
        s = f
        s = s.replace("method_data_processed", "methods_var")
        s = s.replace("\\", "/")
        s = s.split("/")
        file_name = s[-1]
        ath = '/'.join(s[:-1])
        s = '/'.join(s)
        Path(ath).mkdir(parents=True, exist_ok=True)
        java_cmd = java_cmd+s+' idioms.csv'
        check = subprocess.call(java_cmd.replace('/', '\\'), shell=True)
        #print(java_cmd)
        if check != 0:
            print(java_cmd)
            print("java cmd execusion failed on file ", f)

# %%
from os import path
train_x = []
train_y = []
BASE="../pantho_Tufano_processing/methods_var/"
main_BASE = "../codes/"
def read(path):
    return open(path, 'r', encoding = 'utf-8').read()

for data in unique_data:
    #train_x.append("pantho_Tufano_processing/method_data_processed")
    code_file_name = data['code_file_name']
    base_patch_number = data['base_patch_number']
    main_code_path = BASE+code_file_name+'/'+str(base_patch_number)+'.java'
    if(path.exists(main_code_path)):
        code_data = read(main_code_path)
        train_x.append(code_data)
        train_y.append(data['changed_code'])
print(len(train_x))
# Out:
# 40527

# %%
print(len(train_x))
print(train_x[0])

freq = []
cnt=0
len(train_x)
for i in train_x:
    freq.append(len(i.split(" ")))
    if len(i.split(" "))<=100:
        #print(i)
        cnt+=1
print(cnt)
# Out:
# 40527
# private VAR_1 VAR_2 ( ) { final String VAR_3 = VAR_4 class . VAR_5 ( ) . VAR_6 ( ) ; VAR_1 VAR_2 = new VAR_1 ( STRING_1 , STRING_2 , ( VAR_3 == null ? STRING_3 : VAR_3 ) , STRING_4 , new VAR_7 ( STRING_5 ,
# 14417

# %%
            
from sklearn.model_selection import train_test_split
train_x, test_x, train_y, test_y = train_test_split(train_x, train_y, test_size=0.1, random_state=2020)

train_x, val_x, train_y, val_y = train_test_split(train_x, train_y, test_size=0.1, random_state=2020)
print("train len = ", len(train_x))
print("test len = ", len(test_x))
print("valdation len = ", len(val_x))
# Out:
# train len =  23967
# test len =  23967
# valdation len =  2663

# %%
def write_txt(file_name, lst):
    with open(file_name, 'w', encoding = 'utf-8') as output:
        for row in lst:
            output.write(row + '\n')

# %%
freq = []
cnt=0
len(train_x)
for i in train_x:
    freq.append(len(i.split(" ")))
    if len(i.split(" "))<=400:
        #print(i)
        cnt+=1
print(cnt)
# Out:
# 20099

# %%
'''
from collections import Counter
import pandas as pd
count = Counter(freq)
df = pd.DataFrame.from_dict(count, orient='index')
df.plot(kind='bar')
'''
import matplotlib.pyplot as plt
plt.hist(freq)
plt.show()

# %%
write_txt("../pantho_Tufano_processing/our_data/train/"+"buggy.txt",train_x)
write_txt("../pantho_Tufano_processing/our_data/train/"+"fixed.txt",train_y)
write_txt("../pantho_Tufano_processing/our_data/test/"+"buggy.txt",test_x)
write_txt("../pantho_Tufano_processing/our_data/test/"+"fixed.txt",test_y)
write_txt("../pantho_Tufano_processing/our_data/eval/"+"buggy.txt",val_x)
write_txt("../pantho_Tufano_processing/our_data/eval/"+"fixed.txt",val_x)

# %%
unique_data
# Out:
# [{'actual_line_number': 5,
#   'base_code_line_number': 6,
#   'base_patch_number': 2,
#   'changed_code': ' * Copyright (C) 2017 AT&T Intellectual Property & Tech Mahindra. All rights reserved.',
#   'changed_patch_number': 4,
#   'code_file_name': 'acumos_647',
#   'comment_id': 'c80bb11f_61c30f6e1',
#   'line_change': 1,
#   'message': 'This is an ugly copyright line.  Please fix in all files.',
#   'previous_code': ' * Copyright (C) 2017 AT&T Intellectual'},
#  {'actual_line_number': 5,
#   'base_code_line_number': 6,
#   'base_patch_number': 1,
#   'changed_code': ' * Copyright (C) 2017 AT&T Intellectual Property & Tech Mahindra. All rights reserved.',
#   'changed_patch_number': 4,
#   'code_file_name': 'acumos_646',
#   'comment_id': 'dcb5fd70_540e782a2',
#   'line_change': 1,
#   'message': 'This is not the expected format of the License header.  Why all the tab characters?',
#   'previous_code': ' * Copyright (C) 2017 AT&T Intellectual'},
#  {'actual_line_number': 24,
# ...

# %%
#for creating the test set
import json
def getJsonData(JsonFile):
    with open(JsonFile, encoding="utf8") as f:
        data = json.load(f)
    return data

def read(path):
    return open(path, 'r', encoding = 'utf-8').read()

unique_data = getJsonData('unique_data.json')
print(unique_data[0])
data = unique_data[0]
data
# Out:
# {'actual_line_number': 5, 'base_code_line_number': 6, 'base_patch_number': 2, 'changed_code': ' * Copyright (C) 2017 AT&T Intellectual Property & Tech Mahindra. All rights reserved.', 'changed_patch_number': 4, 'code_file_name': 'acumos_647', 'comment_id': 'c80bb11f_61c30f6e1', 'line_change': 1, 'message': 'This is an ugly copyright line.  Please fix in all files.', 'previous_code': ' * Copyright (C) 2017 AT&T Intellectual'}
# {'actual_line_number': 5,
#  'base_code_line_number': 6,
#  'base_patch_number': 2,
#  'changed_code': ' * Copyright (C) 2017 AT&T Intellectual Property & Tech Mahindra. All rights reserved.',
#  'changed_patch_number': 4,
#  'code_file_name': 'acumos_647',
#  'comment_id': 'c80bb11f_61c30f6e1',
#  'line_change': 1,
#  'message': 'This is an ugly copyright line.  Please fix in all files.',
#  'previous_code': ' * Copyright (C) 2017 AT&T Intellectual'}

# %%
from os import path
train_x = []
train_y = []
BASE="../pantho_Tufano_processing/methods_var/"
main_BASE = "../codes/"
def read(path):
    return open(path, 'r', encoding = 'utf-8').read()

visited_dic = {}
for data in unique_data:
    code_file_name = data['code_file_name']
    base_patch_number = data['base_patch_number']
    main_code_path = BASE+code_file_name+'/'+str(base_patch_number)+'.java'
    if(path.exists(main_code_path)):
        code_data = read(main_code_path)
        if code_data not in visited_dic.keys():
            train_x.append(code_data)
            train_y.append(data['changed_code'])
            visited_dic[code_data] = "visited"
            
print(len(train_x))
# Out:
# 15234

# %%
import os
def getListOfFiles(dirName):
    # create a list of file and sub directories 
    # names in the given directory 
    listOfFile = os.listdir(dirName)
    allFiles = list()
    # Iterate over all the entries
    for entry in listOfFile:
        # Create full path
        fullPath = os.path.join(dirName, entry)
        # If entry is a directory then get the list of files in this directory 
        if os.path.isdir(fullPath):
            allFiles = allFiles + getListOfFiles(fullPath)
        else:
            allFiles.append(fullPath)
                
    return allFiles
main_loc = "E:/pantho_Tufano_processing/tufano_data"
for folder in os.listdir(main_loc):
    flist = getListOfFiles(main_loc+"/"+folder)
    files = []
    print(folder)
    save_loc =main_loc+"_processed/"+folder+'/'
    for f in flist:
        files.append(f.replace("\\", "/").split("/")[-1])
    print(len(files))
    prev = []
    nxt = []
    for f in files:
        if "prev" in f:
            prev.append(f)
        else:
            nxt.append(f)
    #for i in range(len(nxt)):
    #    print(prev[i], nxt[i])
    #print()
# Out:
# acumos_145
# 118
# acumos_146
# 68
# acumos_147
# 350
# acumos_149
# 2
# acumos_167
# 4
# acumos_177
# 500
# acumos_197
# 2
# acumos_198
# 2
# acumos_199
# 8
# acumos_200
# 32
# acumos_202
# 252
# acumos_203
# 4
# acumos_205
# 2
# acumos_206
# 4
# acumos_207
# 2
# acumos_208
# 1474
# acumos_21
# 2
# acumos_210
# 2
# acumos_211
# 358
# acumos_213
# 4
# acumos_217
# 2
# acumos_22
# 4
# acumos_221
# 676
# acumos_222
# 210
# acumos_227
# 20
# acumos_228
# 10
# acumos_229
# 20
# acumos_234
# 20
# acumos_235
# 2
# acumos_237
# 2
# acumos_238
# 40
# acumos_240
# 38
# acumos_243
# 2
# acumos_244
# 10
# acumos_245
# 4
# acumos_26
# 158
# acumos_265
# 6
# acumos_266
# 2
# acumos_267
# 2
# acumos_27
# 2
# acumos_274
# 2
# acumos_275
# 4
# acumos_277
# 12
# acumos_278
# 60
# acumos_279
# 2
# acumos_281
# 4
# acumos_284
# 2
# acumos_29
# 2
# acumos_30
# 4
# acumos_32
# 2
# acumos_35
# 110
# acumos_36
# 4
# acumos_361
# 20
# acumos_364
# 4
# acumos_366
# 4
# acumos_372
# 2
# acumos_373
# 162
# ...

# %%
## continue from here to create own data from tufano

from os import path
import subprocess
def getJsonData(JsonFile):
    with open(JsonFile, encoding="utf8") as f:
        data = json.load(f)
    return data

def read(path):
    return open(path, 'r', encoding = 'utf-8').read()
main_loc = "E:/pantho_Tufano_processing/tufano_data"
for folder in os.listdir(main_loc):
    flist = getListOfFiles(main_loc+"/"+folder)
    files = []
    for f in flist:
        files.append(f.replace("\\", "/").split("/")[-1])
    #print(len(files))
    save_loc =main_loc+"_processed/"+folder+'/'
    prev = []
    nxt = []
    for f in files:
        if "prev" in f:
            prev.append(f)
        else:
            nxt.append(f)
    for i in range(len(nxt)):
        #print(prev[i], nxt[i])
        f = main_loc+'/'+folder+'/'+prev[i]
        java_cmd = "java -jar src2abs-0.1-jar-with-dependencies.jar single method "
        java_cmd = java_cmd + f+" "
        
        s = save_loc+nxt[i]
        s = s.split("/")
        file_name = s[-1]
        ath = '/'.join(s[:-1])
        s = '/'.join(s)
        Path(ath).mkdir(parents=True, exist_ok=True)
        java_cmd = java_cmd+s+' idioms.csv'
        check = subprocess.call(java_cmd.replace('/', '\\'), shell=True)
        #print(java_cmd)
        if check != 0:
            print(java_cmd)
            print("java cmd execusion failed on file ", f)

# %%
## continue from here to create own data from tufano
from os import path
train_x = []
train_y = []
BASE="../pantho_Tufano_processing/tufano_data_procesed/"
main_BASE = "../codes/"
def read(path):
    return open(path, 'r', encoding = 'utf-8').read()

for folder in os.listdir(BASE):
    flist = getListOfFiles(main_loc+"/"+folder)
    files = []
    for f in flist:
        if f[-4:]=="java":
            files.append(f.replace("\\", "/").split("/")[-1])
    print(len(files))
    prev = []
    nxt = []
    for f in files:
        if "prev" in f:
            prev.append(f)
        else:
            nxt.append(f)
    for i in range(len(nxt)):
        BASE+'folder'+'/'+prev[i]

# %%
#for creating the test set
import json
def getJsonData(JsonFile):
    with open(JsonFile, encoding="utf8") as f:
        data = json.load(f)
    return data

def read(path):
    return open(path, 'r', encoding = 'utf-8').read()

unique_data = getJsonData('unique_data.json')
print(unique_data[0])
data = unique_data[0]
data
# Out:
# {'actual_line_number': 5, 'base_code_line_number': 6, 'base_patch_number': 2, 'changed_code': ' * Copyright (C) 2017 AT&T Intellectual Property & Tech Mahindra. All rights reserved.', 'changed_patch_number': 4, 'code_file_name': 'acumos_647', 'comment_id': 'c80bb11f_61c30f6e1', 'line_change': 1, 'message': 'This is an ugly copyright line.  Please fix in all files.', 'previous_code': ' * Copyright (C) 2017 AT&T Intellectual'}
# {'actual_line_number': 5,
#  'base_code_line_number': 6,
#  'base_patch_number': 2,
#  'changed_code': ' * Copyright (C) 2017 AT&T Intellectual Property & Tech Mahindra. All rights reserved.',
#  'changed_patch_number': 4,
#  'code_file_name': 'acumos_647',
#  'comment_id': 'c80bb11f_61c30f6e1',
#  'line_change': 1,
#  'message': 'This is an ugly copyright line.  Please fix in all files.',
#  'previous_code': ' * Copyright (C) 2017 AT&T Intellectual'}

# %%
# less then 50 for tufano small dataset

#50-100 token function in tufano preprocess

#usual large function greaterm than 100 token 

# global scope (non code )

#string comment

# just one line change

# %%
from os import path
train_x = []
train_y = []
BASE="../pantho_Tufano_processing/methods_var/"
main_BASE = "../codes/"
def read(path):
    return open(path, 'r', encoding = 'utf-8').read()
less_then_50 = []
less_then_100 = []
greater_then_100 = []
non_function = []
for idx,data in enumerate(unique_data):
    #train_x.append("pantho_Tufano_processing/method_data_processed")
    code_file_name = data['code_file_name']
    base_patch_number = data['base_patch_number']
    main_code_path = BASE+code_file_name+'/'+str(base_patch_number)+'.java'
    if(path.exists(main_code_path)):
        code_data = read(main_code_path)
        if(len(code_data.split(" "))<=50):
            #print(data)
            less_then_50.append(idx)
        if 50<len(code_data.split())<=100:
            less_then_100.append(idx)
        if len(code_data.split())>100:
            greater_then_100.append(idx)
    else:
        non_function.append(idx)

# %%
print(len(less_then_50))
print(len(less_then_100))
print(len(greater_then_100))
# Out:
# 6660
# 7757
# 26110

# %%
import random
random.seed(2020)
less_50_data = random.sample(less_then_50, 100)
less_100_data = random.sample(less_then_100, 100)
greater_100_data = random.sample(greater_then_100, 100)
print(sorted(less_50_data))
print(sorted(less_100_data))
print(sorted(greater_100_data))
# Out:
# [1050, 1604, 1605, 1787, 2009, 2684, 3876, 3975, 4127, 4430, 4611, 5121, 6176, 6699, 7481, 8275, 8515, 8751, 8983, 9008, 9971, 12058, 12360, 12830, 13807, 13878, 14109, 14131, 14141, 14273, 14382, 14389, 15789, 19460, 20073, 20233, 20730, 21177, 24060, 24314, 24507, 25791, 26959, 28533, 29672, 29864, 30923, 31006, 31507, 31805, 32083, 32187, 32258, 32426, 33050, 33179, 33412, 34357, 34753, 34754, 34758, 35680, 36017, 36876, 37082, 37132, 37402, 37559, 38494, 39488, 41934, 42661, 42821, 42890, 43206, 43208, 43266, 43284, 43407, 43474, 43641, 44158, 44599, 44752, 46699, 46700, 46705, 46924, 47885, 48712, 49179, 50184, 50625, 51390, 51716, 52779, 52889, 54850, 54917, 54941]
# ...

# %%
for idx in non_function[:500]:
    print(idx)
    print(unique_data[idx])
# Out:
# 0
# {'actual_line_number': 5, 'base_code_line_number': 6, 'base_patch_number': 2, 'changed_code': ' * Copyright (C) 2017 AT&T Intellectual Property & Tech Mahindra. All rights reserved.', 'changed_patch_number': 4, 'code_file_name': 'acumos_647', 'comment_id': 'c80bb11f_61c30f6e1', 'line_change': 1, 'message': 'This is an ugly copyright line.  Please fix in all files.', 'previous_code': ' * Copyright (C) 2017 AT&T Intellectual'}
# 1
# {'actual_line_number': 5, 'base_code_line_number': 6, 'base_patch_number': 1, 'changed_code': ' * Copyright (C) 2017 AT&T Intellectual Property & Tech Mahindra. All rights reserved.', 'changed_patch_number': 4, 'code_file_name': 'acumos_646', 'comment_id': 'dcb5fd70_540e782a2', 'line_change': 1, 'message': 'This is not the expected format of the License header.  Why all the tab characters?', 'previous_code': ' * Copyright (C) 2017 AT&T Intellectual'}
# 2
# ...

# %%
# less then 50 for tufano small dataset
[1050, 1604, 1605, 1787, 2009, 2684, 3876, 3975, 4127, 4430, 4611, 5121, 6176, 6699, 7481, 8275, 8515, 8751, 8983, 9008, 9971, 12058, 12360, 12830, 13807, 13878, 14109, 14131, 14141, 14273, 14382, 14389, 15789, 19460, 20073, 20233, 20730, 21177, 24060, 24314, 24507, 25791, 26959, 28533, 29672, 29864, 30923, 31006, 31507, 31805, 32083, 32187, 32258, 32426, 33050, 33179, 33412, 34357, 34753, 34754, 34758, 35680, 36017, 36876, 37082, 37132, 37402, 37559, 38494, 39488, 41934, 42661, 42821, 42890, 43206, 43208, 43266, 43284, 43407, 43474, 43641, 44158, 44599, 44752, 46699, 46700, 46705, 46924, 47885, 48712, 49179, 50184, 50625, 51390, 51716, 52779, 52889, 54850, 54917, 54941]

#50-100 token function in tufano preprocess
[1170, 1869, 2035, 2091, 2092, 4178, 4216, 4904, 5155, 5616, 5856, 6103, 6569, 6786, 7563, 8716, 10669, 10783, 12252, 12305, 13982, 13989, 15368, 15518, 18745, 18794, 20172, 20692, 21434, 21848, 22620, 24290, 24381, 24581, 25372, 25409, 26101, 26820, 26825, 27801, 28031, 28382, 28659, 29777, 29838, 30653, 31171, 31318, 32220, 32244, 32535, 33425, 33432, 33609, 33646, 34872, 36798, 37168, 37171, 37178, 37927, 38030, 38541, 38774, 39100, 39538, 40196, 40556, 40596, 41247, 42522, 43027, 43367, 44649, 44994, 45318, 46131, 47305, 47447, 47663, 47798, 48249, 48993, 49217, 49401, 49570, 50358, 50525, 50599, 50812, 51098, 51540, 52043, 52108, 52583, 52947, 53525, 53775, 55659, 55824]

# usual large function greaterm than 100 token 
[292, 732, 2160, 4163, 4763, 5281, 6486, 6489, 10234, 10323, 11096, 13468, 14204, 15451, 15659, 16097, 16668, 16839, 16929, 17066, 18212, 18415, 19001, 19211, 20075, 21027, 21306, 21370, 21638, 21788, 22956, 23128, 23673, 23960, 24475, 24476, 24666, 24677, 24727, 24860, 24982, 25548, 25814, 25949, 26352, 26737, 28504, 28721, 28729, 28754, 29122, 29177, 29420, 29462, 29945, 30335, 31248, 31266, 31857, 32718, 33896, 34773, 34914, 35555, 36250, 36729, 36750, 37294, 37376, 37530, 37849, 37852, 40053, 40062, 40073, 40394, 40776, 41276, 41527, 42103, 42760, 44180, 44940, 45972, 46190, 47863, 48176, 48237, 48426, 49025, 49898, 50255, 50385, 50921, 51430, 52772, 53884, 54626, 55634, 55677]

# global scope (non code ) and string comment
584 (lisence change)

# just one line change 
629, 585, 588 609, (single variable name change or type change ), 549, 561, 583 (function_name_change or extends change),

# %%
unique_data[588]
# Out:
# {'actual_line_number': 52,
#  'base_code_line_number': 52,
#  'base_patch_number': 1,
#  'changed_code': '\tprivate InputValidationService inputValidationService;',
#  'changed_patch_number': 2,
#  'code_file_name': 'acumos_707',
#  'comment_id': '5aa07901_a9a037bf618',
#  'line_change': 1,
#  'message': 'private',
#  'previous_code': '\tInputValidationService inputValidationService;'}

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
print(len(word_tokenize("DataSourceAutoConfiguration.class, HibernateJpaAutoConfiguration.class")))
# Out:
# 3
