# %%
#unified_with_date

# %%
from nltk.tokenize import MWETokenizer, TweetTokenizer, WordPunctTokenizer 
from nltk.tokenize import word_tokenize
import re

VALUES = ['>>>=', '>>=', '<<=',  '%=', '^=', '|=', '&=', '/=',
                  '*=', '-=', '+=', '<<', '--', '++', '||', '&&', '!=',
                  '>=', '<=', '==', '%', '^', '|', '&', '/', '*', '-',
                  '+', ':', '?', '~', '!', '<', '>', '=', '...', '->', '::', '\\', '\\\\', '\*', '*\\', '\\\\\\']
INFIX = ['||', '&&', '|', '^', '&', '==', '!=', '<', '>', '<=', '>=', 
             '<<', '>>', '>>>', '+', '-', '*', '/', '%']
PREFIX = ['++', '--', '!', '~', '+', '-']
POSTFIX = ['++', '--']
ASSIGNMENT = ['=', '+=', '-=', '*=', '/=', '&=', '|=', '^=', '%=', '<<=', '>>=', '>>>=']
LAMBDA = ['->']
COMMENT = ['//', '/*', '*/']
METHOD_REFERENCE = ['::']

WHITESPACE_DICT = {"                ":'<|16-s|>', 
                   "            ":'<|12-s|>', 
                   "        ":'<|8-s|>', 
                   "    ":'<|4-s|>', 
                   "  ":'<|2-s|>', " ":'<|s|>',
                   "\t\t\t\t":'<|4-t|>',"\t\t\t":'<|3-t|>',"\t\t":'<|2-t|>',"\t":'<|t|>',"\n":'<|nl|>'}

WHITESPACES = [WHITESPACE_DICT[x] for x in WHITESPACE_DICT]

CUSTOM_TOKEN = ["<|startcode|>", "<|endcode|>", "<|startfocus|>", "<|endfocus|>", "<|startcomment|>", "<|endcomment|>", 
                   "<|stringliteral|>", "<|singlelinecomment|>", "<|multilinecomment|>", "<|del|>"]

values = list(set(INFIX+PREFIX+POSTFIX+ASSIGNMENT+LAMBDA+COMMENT+METHOD_REFERENCE))
token_phrases = []
word_punct_tokenizer = WordPunctTokenizer()
for tok in CUSTOM_TOKEN+WHITESPACES:
    temp = tuple(word_punct_tokenizer.tokenize(tok))
    token_phrases.append(temp)
for w in values:
    temp = tuple(MWETokenizer().tokenize(w))
    if len(temp) > 1:
        token_phrases.append(temp)

word_punct_tokenizer = WordPunctTokenizer()
tweet_tokenizer = TweetTokenizer()
mwe_tokenizer = MWETokenizer(token_phrases, separator="")

def state(c):
    n = ord(c)
    if n>=97 and n<=122: # lower case
        return 1
    elif n>=65 and n<=90: # upper case
        return 2
    elif n>=48 and n<=57: # numbers
        return 3
    elif c.isspace(): # whitespaces
        return 4
    elif c in ['_', '$']: 
        return 5
    elif n < 128:
        return 6
    else:
        return 7

def space_up(s):
    if s is None or s == "":
        return ""
    new_s = s[0]
    for i in range(1,len(s)):
        prev_state = state(s[i-1])
        curr_state = state(s[i])
        if prev_state in [1,2] and curr_state in [3]:
            new_s += " "
        elif prev_state in [1] and curr_state in [2]:
            new_s += " "
        elif prev_state in [3] and curr_state in [1,2]:
            new_s += " "
        elif prev_state in [1,2,3] and curr_state in [5]:
            new_s += " "
        elif prev_state in [5] and curr_state in [1,2,3]:
            new_s += " "
        new_s+=s[i]
    return new_s

def white_space_tokenize(s):
    for x in WHITESPACE_DICT:
        s = s.replace(x, WHITESPACE_DICT[x])
    for key in WHITESPACE_DICT:
        val = WHITESPACE_DICT[x]
        s = s.replace(val, " "+val+" ")
    return s

def extreme_tokenization(comment):
    comment = white_space_tokenize(comment)
    comment = space_up(comment)
    tokenized = tweet_tokenizer.tokenize(comment)
    tokenized = word_punct_tokenizer.tokenize(' '.join(tokenized))
    tokenized = mwe_tokenizer.tokenize(tokenized)
    tokenized_comment = ' '.join(tokenized)
    tokenized_comment = re.sub(r'[^\x00-\x7f]',r'', tokenized_comment)
    tokenized = tokenized_comment.split()
    return tokenized

# %%
from os import path
import json
import re
import subprocess
import nltk
from pprint import pprint
from nltk.tokenize import sent_tokenize, word_tokenize
from tqdm import tqdm
nltk.download('punkt')

def getJsonData(JsonFile):
    with open(JsonFile, encoding="utf8") as f:
        data = json.load(f)
    return data
def read(path):
    return open(path, 'r', encoding = 'utf-8').read()


BASE="E:/codes/"
unique_data = getJsonData('E:\\unified_with_date.json')
data = unique_data[1020]
code_file_name = data['file_name']
base_patch_number = data['base_patch_number']
main_code_path = BASE+code_file_name+'/'+str(base_patch_number)+'.java'
main_code = read(main_code_path)


def get_source_target(file1, file2, line_number, change_window_size=5):
    source_target = subprocess.check_output(['java', '-jar', 'ChangedLineF.jar', \
                                file1, file2, str(line_number), str(change_window_size)]).decode("utf-8")
    (source, target) = source_target.split("<|source-target-sep|>")
    return source, target

def end_scope(start_index, lines):
    #print(lines)
    counter = 0
    end_index = -1
    found = False
    for index in range(start_index, len(lines), 1):
        #print(lines[index])
        #print(counter)
        for char in lines[index]:
            if(char=='{'):
                counter+=1
                found = True
            elif(char == "}"):
                counter-=1
                found = True
            if(counter==0 and found):
                end_index = index
                break
        if end_index!=-1:
            break
    return end_index

unique_data_processed = []
MAX_NUM_TOKEN = 800
UP_TOKEN = MAX_NUM_TOKEN//2
c = 0
ec = 0
errors = []
for idx, data in enumerate(unique_data):#[2428:2429]#[1000:1001]
    c+=1
    code_file_name = data['file_name']
    base_patch_number = data['base_patch_number']
    changed_patch_number = data['changed_patch_number']
    main_code_path = BASE+code_file_name+'/'+str(base_patch_number)+'.java'
    changed_code_path = BASE+code_file_name+'/'+str(changed_patch_number)+'.java'
    line_no = data['line_number']
    main_code = read(main_code_path)
    changed_code = read(changed_code_path)
    sample = main_code
    message = data['message']
    comment_id = data['comment_id']
    
    try:
        source, target = get_source_target(main_code_path, changed_code_path,line_no-1)
    except:
        error = {}
        error['main_code'] = main_code
        error['changed_code'] = changed_code
        error['line_no'] = line_no
        ec+=1
        if(main_code!=''):
            errors.append(error)
        print("falied to store unique_data= ", c, "error count", ec)    
    '''
    if len(errors)>100:
        with open('errors.json', 'w', encoding="utf8") as f:  # writing JSON object
            json.dump(errors, f)
        break
    '''
    #print(source)
    #print(len(errors))
    #print(ec)
    #continue
    sample = source
    #print(source)
    #for i in range(10):
    #    sample = re.sub(r"""\/\*([\S\s]+?)\*\/""", "", sample)
    
    data_dic = {}
    
    #data_dic['source'] = source
    data_dic['message'] = message
    
    data_dic['comment_id'] = comment_id
    data_dic['target'] = target
    data_dic['source'] = source
    data_dic['idx'] = c
    func_list = []
    data_dic['code_snippet'] = ""
    data_dic['prime_var_dic'] = {}
    #print(sample)
    classes = re.findall(r"(?:(public\s))?(class)\s([^\n\s]*)", sample)
    lines = sample.split('\n')
    class_list = []
    sp_start_func= -1
    sp_end_func= len(sample.split('\n'))   
    for cls_tpl in classes:
        s = "".join(cls_tpl[-1])
        s = s.strip()
        class_list.append(s) ## class list
        cls = s
        #print(s)
        start_index = -1
        for i in range(len(lines)):
            if cls in lines[i]:
                start_index = i
                break
        #print(start_index)
        end_index = end_scope(start_index, lines)
        #print(end_index)
        class_scope_dic = {}
        for i in range(start_index, end_index+1):
            class_scope_dic[i] = True
        funcs = re.findall(r"(public|protected|private|static|\s) +([\w\<\>\[\]]+\s+(\w+)) *\([^\)]*\) *(\{?|[^;])", "\n".join(lines[start_index:end_index+1]))
        func_scopes = []
        #print(funcs)
        #continue
        visited_func = set()
        for func in funcs:
            #print(func)
            if(func[-1]!= "{"):
                continue
            fc = list(func)
            fc = fc[-3]
            s = "".join(fc)
            s = s.strip()
            #func_list.append(s) ## function list
            #print(func_list)
            
            for index in range(start_index, end_index+1, 1):
                if s in lines[index]:
                    start_func = index
                    end_func = end_scope(index, lines)
                    
                    func_scopes.append((start_func,end_func))
                    if s not in visited_func:
                        visited_func.add(s)
                        func_list.append(lines[index].replace("{", "").strip())
                    
                    if(start_func<=line_no<=end_func):
                        special_func = "\n".join(lines[start_func:end_func+1])
                        #data_dic['code_snippet'] = special_func
                        #nonlocal sp_start_func
                        sp_start_func= start_func
                        #nonlocal sp_end_func
                        sp_end_func= end_func
        
        for func_sc in func_scopes:
            for i in range(func_sc[0], func_sc[1]+1):
                class_scope_dic[i] = False
        prime_var_list = []
        dic_vars = {}
        for i in range(start_index, end_index+1):
            if class_scope_dic[i]==True:
                #prime_vars = re.findall(r""""[^"]*"|((?=_[a-z_0-9]|[a-z])[a-z_0-9]+((?=\s*=)))""",lines[i])
                if '(' not in lines[i] and "return" not in lines[i] and "extends" not in lines[i]:
                    prime_vars = re.findall(r"""(\w+\s+)([a-zA-Z_][a-zA-Z0-9_]*)""", lines[i])
                    if len(prime_vars)==2:
                        if(len(prime_vars[1])==2 and prime_vars[1][1] in dic_vars.keys()):
                            dic_vars[prime_vars[1][1]]+=1
                        elif len(prime_vars[1])==2:
                            dic_vars[prime_vars[1][1]] =1
        #if(len(list(dic_vars.keys()))>0):
            #print(dic_vars)
        data_dic['prime_var_dic'] = dic_vars
    data_dic['class_list'] = class_list
    data_dic['func_list'] = func_list
    
    #print("specials   ###", sp_start_func, sp_end_func)
    
    if not (0<len(extreme_tokenization(data_dic['code_snippet']))<MAX_NUM_TOKEN): 
        up_count = 0
        up_done = False
        down_count = 0
        down_done = False
        splitted = sample.split("\n")
        while(1):
            #print(max(0, line_no-up_count),line_no+1)
            if len(extreme_tokenization("\n".join(splitted[max(0,sp_start_func, line_no-up_count):line_no+1])))<UP_TOKEN:
                if(up_count==line_no):
                    break
                up_count+=1
            else:
                break
                #print("something is wrong")
                      
        while(1):
            if len(extreme_tokenization("\n".join(splitted[(line_no-up_count):min(line_no+down_count+1,sp_end_func, len(splitted))])))<MAX_NUM_TOKEN:
                if(down_count==len(splitted)):
                    break
                down_count+=1
            else:
                break
    if sp_start_func != -1:
        #data_dic['code_snippet'] = "\n".join(splitted[sp_start_func:sp_end_func+1])
        
        if("startfocus" in splitted[sp_start_func-1]):
            sp_start_func-=1
        if sp_end_func <=len(splitted)-2 and "endfocus" in splitted[sp_end_func+1]:
            sp_end_func+=2
        if sp_end_func <=len(splitted)-1 and "endfocus" in splitted[sp_end_func]:
            sp_end_func+=1
        #print(" ".join(splitted[sp_start_func:sp_end_func+1]))
        #print(sp_start_func)
        #print(sp_end_func)
        code_snippet = "\n".join(splitted[sp_start_func:sp_end_func+1])
        print("in function")
        
    else:
        #data_dic['code_snippet'] = "\n".join(splitted[(line_no-up_count):(line_no+down_count+1)])
        print("not in function")
        if("startfocus" in splitted[(line_no-up_count-1)]):
            up_count+=1
        if line_no+down_count <=len(splitted)-1 and "endfocus" in splitted[line_no+down_count]:
            down_count+=1
        code_snippet = "\n".join(splitted[(line_no-up_count):(line_no+down_count+1)])
        #print(line_no-up_count)
        #print(line_no+down_count+1)
        #print(code_snippet)
    #print(code_snippet)
    #print(data_dic['func_list'])
    if "<|startfocus|>" in code_snippet and "<|endfocus|>" not in code_snippet:
        code_snippet =code_snippet+  "\n<|endfocus|>"
    if "<|startfocus|>" not in code_snippet and "<|endfocus|>" in code_snippet:
        code_snippet = "<|startfocus|>\n"+code_snippet
        
    data_dic['tokenized_code_snippet'] = extreme_tokenization(code_snippet)#data_dic['code_snippet'])
    data_dic['tokenized_target'] = extreme_tokenization(data_dic['target'])
    data_dic['tokenized_comment'] = extreme_tokenization(data_dic['message'])
    #print("specials   ###", sp_start_func, sp_end_func)
   
    
    #print(code_snippet)
    #print("#################")
    #print(data_dic)
    #print(source)
    #data_dic['actual_line_number'] = data['line_number']
    data_dic['base_code_line_number'] = data['line_number']
    data_dic['base_patch_number'] = data['base_patch_number']
    data_dic['changed_patch_number'] = data['changed_patch_number']
    data_dic['code_file_name'] = data['file_name']
    data_dic['comment_id'] = data['comment_id']
    data_dic['message'] = data['message']
    data_dic['line_change'] = data['line_change']
    data_dic['written_on'] = data['written_on']
    data_dic['project_name'] = data['project_name']
    if "<|startfocus|>" in code_snippet and "<|endfocus|>" in code_snippet:
        unique_data_processed.append(data_dic)
    print(idx)
    if(idx%1000==0):
        print(idx)
        print(c)
        pprint(data_dic)

'''
{'actual_line_number': 71, 'base_code_line_number': 73, 'base_patch_number': 3, 'changed_code': '    /*', 'changed_patch_number': 7, 'code_file_name': 'android_3478', 'comment_id': '3745e284_1e49cdaa', 'line_change': 2, 'message': '{@link android.icu.impl.OlsonTimeZone} ?', 'previous_code': '     /*'}
'''
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# in function
# 0
# 0
# 1
# {'base_code_line_number': 64,
#  'base_patch_number': 3,
#  'changed_patch_number': 4,
#  'class_list': ['SwaggerConfiguration'],
#  'code_file_name': 'acumos_197',
#  'code_snippet': '',
#  'comment_id': 'a068aa5b_b404cd60',
#  'func_list': ['public Docket api()', 'private ApiInfo apiInfo()'],
#  'idx': 1,
#  'line_change': 0,
#  'message': 'One last occurrence - please change to acumos.org/...',
#  'prime_var_dic': {},
#  'project_name': 'acumos_',
#  'source': 'E:\\pantho_Tufano_processing\r\n'
#            '\n'
#            ' * '
#            '===============LICENSE_START=======================================================\n'
#            ' * Acumos\n'
#            ' * '
#            '===================================================================================\n'
#            ' * Copyright (C) 2017 AT&T Intellectual Property & Tech Mahindra. '
#            'All rights reserved.\n'
#            ' * '
#            '===================================================================================\n'
#            ' * This Acumos software file is distributed by AT&T and Tech '
#            'Mahindra\n'
#            ' * under the Apache License, Version 2.0 (the "License");\n'
#            ' * you may not use this file except in compliance with the '
#            'License.\n'
#            ' * You may obtain a copy of the License at\n'
#            ' *  \n'
#            ' *      http://www.apache.org/licenses/LICENSE-2.0\n'
#            ' *  \n'
#            ' * This file is distributed on an "AS IS" BASIS,\n'
#            ' * WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or '
#            'implied.\n'
#            ' * See the License for the specific language governing permissions '
#            'and\n'
#            ' * limitations under the License.\n'
#            ' * '
#            '===============LICENSE_END=========================================================\n'
#            ' */\n'
#            '\n'
#            'package org.acumos.cds.config;\n'
#            '\n'
#            'import org.acumos.cds.CdsApplication;\n'
#            'import org.acumos.cds.controller.AbstractController;\n'
#            'import org.springframework.context.annotation.Bean;\n'
#            'import org.springframework.context.annotation.Configuration;\n'
#            '\n'
#            'import springfox.documentation.builders.PathSelectors;\n'
#            'import springfox.documentation.builders.RequestHandlerSelectors;\n'
#            'import springfox.documentation.service.ApiInfo;\n'
#            'import springfox.documentation.service.Contact;\n'
#            'import springfox.documentation.spi.DocumentationType;\n'
#            'import springfox.documentation.spring.web.plugins.Docket;\n'
#            'import '
#            'springfox.documentation.swagger2.annotations.EnableSwagger2;\n'
#            '\n'
#            '/**\n'
#            ' * '
#            'http://www.baeldung.com/swagger-2-documentation-for-spring-rest-api\n'
#            ' */\n'
#            '@Configuration\n'
#            '@EnableSwagger2\n'
#            'public class SwaggerConfiguration {\n'
#            '\t\n'
#            '\t/**\n'
#            '\t * @return new Docket\n'
#            '\t */\n'
#            '\t@Bean\n'
#            '\tpublic Docket api() {\n'
#            '\t\treturn new Docket(DocumentationType.SWAGGER_2).select() //\n'
#            '\t\t\t\t'
#            '.apis(RequestHandlerSelectors.basePackage(AbstractController.class.getPackage().getName())) '
#            '//\n'
#            '\t\t\t\t.paths(PathSelectors.any()) //\n'
#            '\t\t\t\t.build() //\n'
#            '\t\t\t\t.apiInfo(apiInfo());\n'
#            '\t}\n'
#            '\n'
#            '\tprivate ApiInfo apiInfo() {\n'
#            '\t\tfinal String version = '
#            'CdsApplication.class.getPackage().getImplementationVersion();\n'
#            '\t\treturn new ApiInfo("Acumos Common Data Service REST API", // '
#            'title\n'
#            '\t\t\t\t"Provides create, retrieve, update and delete (CRUD) '
#            'services " //\n'
#            '\t\t\t\t\t\t+ " for data about solutions, artifacts and users."//\n'
#            '\t\t\t\t\t\t+ " All service endpoints require basic HTTP '
#            'authentication.", // description\n'
#            '\t\t\t\tversion == null ? "version not available" : version, // '
#            'version\n'
#            '\t\t\t\t"Terms of service", // TOS\n'
#            '\t\t\t\tnew Contact("Acumos Data Model Team",\n'
#            '<|startfocus|>\n'
#            '\t\t\t\t\t\t'
#            '"https://cognita.atlassian.net/wiki/spaces/CW/pages/233610/Data+Model+for+Machine+Learning+Platform",\n'
#            '<|endfocus|>\n'
#            '\t\t\t\t\t\t"cds.someday@acumos.org"), // Contact\n'
#            '\t\t\t\t"License of API", // License\n'
#            '\t\t\t\t"API license URL"); // License URL\n'
#            '\t}\n'
#            '}\n',
#  'target': '\t\t\t\t\t\t'
#            '"https://cognita.atlassian.net/wiki/spaces/CW/pages/233610/Data+Model+for+Machine+Learning+Platform",\n'
#            '\t\t\t\t\t\t"cds.someday@acumos.org"), // Contact\n'
#            '\r\n',
#  'tokenized_code_snippet': ['<|t|>',
#                             'private',
#                             '<|s|>',
#                             'Api',
#                             'Info',
#                             '<|s|>',
#                             'api',
#                             'Info',
#                             '(',
#                             ')',
#                             '<|s|>',
#                             '{',
#                             '<|nl|>',
#                             '<|2-t|>',
#                             'final',
#                             '<|s|>',
#                             'String',
#                             '<|s|>',
#                             'version',
#                             '<|s|>',
#                             '=',
#                             '<|s|>',
#                             'Cds',
#                             'Application',
#                             '.',
#                             'class',
#                             '.',
#                             'get',
#                             'Package',
#                             '(',
#                             ')',
#                             '.',
#                             'get',
#                             'Implementation',
#                             'Version',
#                             '(',
#                             ');',
#                             '<|nl|>',
#                             '<|2-t|>',
#                             'return',
#                             '<|s|>',
#                             'new',
#                             '<|s|>',
#                             'Api',
#                             'Info',
#                             '(',
#                             '"',
#                             'Acumos',
#                             '<|s|>',
#                             'Common',
#                             '<|s|>',
#                             'Data',
#                             '<|s|>',
#                             'Service',
#                             '<|s|>',
#                             'REST',
#                             '<|s|>',
#                             'API',
#                             '"',
#                             ',',
#                             '<|s|>',
#                             '//',
#                             '<|s|>',
#                             'title',
#                             '<|nl|>',
#                             '<|4-t|>',
#                             '"',
#                             'Provides',
#                             '<|s|>',
#                             'create',
#                             ',',
#                             '<|s|>',
#                             'retrieve',
#                             ',',
#                             '<|s|>',
#                             'update',
#                             '<|s|>',
#                             'and',
#                             '<|s|>',
#                             'delete',
#                             '<|s|>',
#                             '(',
#                             'CRUD',
#                             ')',
#                             '<|s|>',
#                             'services',
#                             '<|s|>',
#                             '"',
#                             '<|s|>',
#                             '//',
#                             '<|nl|>',
#                             '<|4-t|>',
#                             '<|2-t|>',
#                             '+',
#                             '<|s|>',
#                             '"',
#                             '<|s|>',
#                             'for',
#                             '<|s|>',
#                             'data',
#                             '<|s|>',
#                             'about',
#                             '<|s|>',
#                             'solutions',
#                             ',',
#                             '<|s|>',
#                             'artifacts',
#                             '<|s|>',
#                             'and',
#                             '<|s|>',
#                             'users',
#                             '.',
#                             '"',
#                             '//',
#                             '<|nl|>',
#                             '<|4-t|>',
#                             '<|2-t|>',
#                             '+',
#                             '<|s|>',
#                             '"',
#                             '<|s|>',
#                             'All',
#                             '<|s|>',
#                             'service',
#                             '<|s|>',
#                             'endpoints',
#                             '<|s|>',
#                             'require',
#                             '<|s|>',
#                             'basic',
#                             '<|s|>',
#                             'HTTP',
#                             '<|s|>',
#                             'authentication',
#                             '.',
#                             '"',
#                             ',',
#                             '<|s|>',
#                             '//',
#                             '<|s|>',
#                             'description',
#                             '<|nl|>',
#                             '<|4-t|>',
#                             'version',
#                             '<|s|>',
#                             '==',
#                             '<|s|>',
#                             'null',
#                             '<|s|>',
#                             '?',
#                             '<|s|>',
#                             '"',
#                             'version',
#                             '<|s|>',
#                             'not',
#                             '<|s|>',
#                             'available',
#                             '"',
#                             '<|s|>',
#                             ':',
#                             '<|s|>',
#                             'version',
#                             ',',
#                             '<|s|>',
#                             '//',
#                             '<|s|>',
#                             'version',
#                             '<|nl|>',
#                             '<|4-t|>',
#                             '"',
#                             'Terms',
#                             '<|s|>',
#                             'of',
#                             '<|s|>',
#                             'service',
#                             '"',
#                             ',',
#                             '<|s|>',
#                             '//',
#                             '<|s|>',
#                             'TOS',
#                             '<|nl|>',
#                             '<|4-t|>',
#                             'new',
#                             '<|s|>',
#                             'Contact',
#                             '(',
#                             '"',
#                             'Acumos',
#                             '<|s|>',
#                             'Data',
#                             '<|s|>',
#                             'Model',
#                             '<|s|>',
#                             'Team',
#                             '"',
#                             ',',
#                             '<|nl|>',
#                             '<|startfocus|>',
#                             '<|nl|>',
#                             '<|4-t|>',
#                             '<|2-t|>',
#                             '"',
#                             'https',
#                             '://',
#                             'cognita',
#                             '.',
#                             'atlassian',
#                             '.',
#                             'net',
#                             '/',
#                             'wiki',
#                             '/',
#                             'spaces',
#                             '/',
#                             'CW',
#                             '/',
#                             'pages',
#                             '/',
#                             '233610',
#                             '/',
#                             'Data',
#                             '+',
#                             'Model',
#                             '+',
#                             'for',
#                             '+',
#                             'Machine',
#                             '+',
#                             'Learning',
#                             '+',
#                             'Platform',
#                             '"',
#                             ',',
#                             '<|nl|>',
#                             '<|endfocus|>',
#                             '<|nl|>',
#                             '<|4-t|>',
#                             '<|2-t|>',
#                             '"',
#                             'cds',
#                             '.',
#                             'someday',
#                             '@',
#                             'acumos',
#                             '.',
#                             'org',
#                             '"',
#                             ')',
#                             ',',
#                             '<|s|>',
#                             '//',
#                             '<|s|>',
#                             'Contact',
#                             '<|nl|>',
#                             '<|4-t|>',
#                             '"',
#                             'License',
#                             '<|s|>',
#                             'of',
#                             '<|s|>',
#                             'API',
#                             '"',
#                             ',',
#                             '<|s|>',
#                             '//',
#                             '<|s|>',
#                             'License',
#                             '<|nl|>',
#                             '<|4-t|>',
#                             '"',
#                             'API',
#                             '<|s|>',
#                             'license',
#                             '<|s|>',
#                             'URL',
#                             '"',
#                             ');<',
#                             '|',
#                             's',
#                             '|',
#                             '>',
#                             '//',
#                             '<|s|>',
#                             'License',
#                             '<|s|>',
#                             'URL',
#                             '<|nl|>',
#                             '<|t|>',
#                             '}'],
#  'tokenized_comment': ['One',
#                        '<|s|>',
#                        'last',
#                        '<|s|>',
#                        'occurrence',
#                        '<|s|>',
#                        '-',
#                        '<|s|>',
#                        'please',
#                        '<|s|>',
#                        'change',
#                        '<|s|>',
#                        'to',
#                        '<|s|>',
#                        'acumos',
#                        '.',
#                        'org',
#                        '/',
#                        '...'],
#  'tokenized_target': ['<|4-t|>',
#                       '<|2-t|>',
#                       '"',
#                       'https',
#                       '://',
#                       'cognita',
#                       '.',
#                       'atlassian',
#                       '.',
#                       'net',
#                       '/',
#                       'wiki',
#                       '/',
#                       'spaces',
#                       '/',
#                       'CW',
#                       '/',
#                       'pages',
#                       '/',
#                       '233610',
#                       '/',
#                       'Data',
#                       '+',
#                       'Model',
#                       '+',
#                       'for',
#                       '+',
#                       'Machine',
#                       '+',
#                       'Learning',
#                       '+',
#                       'Platform',
#                       '"',
#                       ',',
#                       '<|nl|>',
#                       '<|4-t|>',
#                       '<|2-t|>',
#                       '"',
#                       'cds',
#                       '.',
#                       'someday',
#                       '@',
#                       'acumos',
#                       '.',
#                       'org',
#                       '"',
#                       ')',
#                       ',',
#                       '<|s|>',
#                       '//',
#                       '<|s|>',
#                       'Contact',
#                       '<|nl|>',
#                       '<|nl|>'],
#  'written_on': '2017-11-21 20:29:13'}
# not in function
# 1
# not in function
# 2
# not in function
# 3
# not in function
# 4
# not in function
# 5
# in function
# 6
# not in function
# 7
# not in function
# 8
# not in function
# 9
# not in function
# 10
# in function
# 11
# not in function
# 12
# not in function
# 13
# in function
# 14
# in function
# 15
# in function
# 16
# not in function
# 17
# in function
# 18
# in function
# 19
# not in function
# 20
# not in function
# 21
# not in function
# 22
# not in function
# 23
# not in function
# 24
# not in function
# 25
# not in function
# 26
# in function
# 27
# not in function
# 28
# in function
# 29
# not in function
# 30
# not in function
# 31
# in function
# 32
# not in function
# 33
# not in function
# 34
# not in function
# 35
# not in function
# 36
# not in function
# 37
# not in function
# 38
# not in function
# 39
# not in function
# 40
# not in function
# 41
# not in function
# 42
# not in function
# 43
# not in function
# 44
# in function
# 45
# not in function
# 46
# not in function
# 47
# not in function
# 48
# not in function
# 49
# not in function
# 50
# not in function
# 51
# not in function
# 52
# not in function
# 53
# not in function
# 54
# not in function
# 55
# not in function
# 56
# not in function
# 57
# not in function
# 58
# not in function
# 59
# not in function
# 60
# not in function
# 61
# not in function
# 62
# not in function
# 63
# not in function
# 64
# in function
# 65
# not in function
# 66
# not in function
# 67
# in function
# 68
# not in function
# 69
# in function
# 70
# not in function
# 71
# not in function
# 72
# not in function
# 73
# in function
# 74
# not in function
# 75
# not in function
# 76
# not in function
# 77
# not in function
# 78
# not in function
# 79
# not in function
# 80
# in function
# 81
# not in function
# 82
# not in function
# 83
# not in function
# 84
# not in function
# 85
# not in function
# 86
# in function
# 87
# not in function
# 88
# in function
# 89
# not in function
# 90
# not in function
# 91
# not in function
# 92
# not in function
# 93
# not in function
# 94
# not in function
# 95
# in function
# 96
# not in function
# 97
# in function
# 98
# not in function
# 99
# not in function
# 100
# in function
# 101
# in function
# 102
# not in function
# 103
# not in function
# 104
# not in function
# 105
# not in function
# 106
# in function
# 107
# in function
# 108
# not in function
# 109
# not in function
# 110
# not in function
# 111
# not in function
# 112
# not in function
# 113
# not in function
# 114
# not in function
# 115
# in function
# 116
# not in function
# 117
# not in function
# 118
# not in function
# 119
# not in function
# 120
# not in function
# 121
# not in function
# 122
# not in function
# 123
# not in function
# 124
# not in function
# 125
# not in function
# 126
# not in function
# 127
# not in function
# 128
# not in function
# 129
# not in function
# 130
# in function
# 131
# not in function
# 132
# not in function
# 133
# not in function
# 134
# not in function
# 135
# not in function
# 136
# not in function
# 137
# not in function
# 138
# in function
# 139
# not in function
# 140
# not in function
# 141
# not in function
# 142
# not in function
# 143
# not in function
# 144
# not in function
# 145
# not in function
# 146
# not in function
# 147
# not in function
# 148
# not in function
# 149
# not in function
# 150
# not in function
# 151
# not in function
# 152
# not in function
# 153
# not in function
# 154
# falied to store unique_data=  156 error count 1
# not in function
# 155
# in function
# 156
# falied to store unique_data=  158 error count 2
# not in function
# 157
# falied to store unique_data=  159 error count 3
# not in function
# 158
# not in function
# 159
# not in function
# 160
# in function
# 161
# not in function
# 162
# not in function
# 163
# not in function
# 164
# not in function
# 165
# not in function
# 166
# not in function
# 167
# not in function
# 168
# not in function
# 169
# not in function
# 170
# not in function
# 171
# not in function
# 172
# in function
# 173
# not in function
# 174
# in function
# 175
# not in function
# 176
# not in function
# 177
# not in function
# 178
# in function
# 179
# not in function
# 180
# not in function
# 181
# not in function
# 182
# not in function
# 183
# not in function
# 184
# not in function
# 185
# not in function
# 186
# not in function
# 187
# in function
# 188
# in function
# 189
# in function
# 190
# in function
# 191
# not in function
# 192
# not in function
# 193
# not in function
# 194
# not in function
# 195
# not in function
# 196
# in function
# 197
# in function
# 198
# in function
# 199
# in function
# 200
# in function
# 201
# in function
# 202
# in function
# 203
# not in function
# 204
# falied to store unique_data=  206 error count 4
# not in function
# 205
# falied to store unique_data=  207 error count 5
# not in function
# 206
# falied to store unique_data=  208 error count 6
# not in function
# 207
# falied to store unique_data=  209 error count 7
# not in function
# 208
# not in function
# 209
# not in function
# 210
# not in function
# 211
# not in function
# 212
# in function
# 213
# not in function
# 214
# not in function
# 215
# not in function
# 216
# not in function
# 217
# not in function
# 218
# not in function
# 219
# not in function
# 220
# not in function
# 221
# not in function
# 222
# not in function
# 223
# not in function
# 224
# not in function
# 225
# not in function
# 226
# not in function
# 227
# not in function
# 228
# not in function
# 229
# not in function
# 230
# not in function
# 231
# not in function
# 232
# in function
# 233
# not in function
# 234
# not in function
# 235
# not in function
# 236
# in function
# 237
# not in function
# 238
# not in function
# 239
# not in function
# 240
# not in function
# 241
# not in function
# 242
# not in function
# 243
# not in function
# 244
# not in function
# 245
# not in function
# 246
# in function
# 247
# not in function
# 248
# not in function
# 249
# not in function
# 250
# not in function
# 251
# not in function
# 252
# not in function
# 253
# not in function
# 254
# not in function
# 255
# not in function
# 256
# not in function
# 257
# in function
# 258
# in function
# 259
# in function
# 260
# in function
# 261
# in function
# 262
# not in function
# 263
# falied to store unique_data=  265 error count 8
# not in function
# 264
# falied to store unique_data=  266 error count 9
# not in function
# 265
# falied to store unique_data=  267 error count 10
# not in function
# 266
# falied to store unique_data=  268 error count 11
# not in function
# 267
# in function
# 268
# in function
# 269
# in function
# 270
# not in function
# 271
# not in function
# 272
# not in function
# 273
# not in function
# 274
# not in function
# 275
# not in function
# 276
# not in function
# 277
# not in function
# 278
# in function
# 279
# not in function
# 280
# not in function
# 281
# not in function
# 282
# not in function
# 283
# not in function
# 284
# not in function
# 285
# not in function
# 286
# not in function
# 287
# not in function
# 288
# not in function
# 289
# in function
# 290
# not in function
# 291
# not in function
# 292
# not in function
# 293
# not in function
# 294
# in function
# 295
# in function
# 296
# not in function
# 297
# in function
# 298
# not in function
# 299
# not in function
# 300
# not in function
# 301
# not in function
# 302
# not in function
# 303
# in function
# 304
# not in function
# 305
# not in function
# 306
# in function
# 307
# not in function
# 308
# not in function
# 309
# not in function
# 310
# not in function
# 311
# in function
# 312
# not in function
# 313
# not in function
# 314
# in function
# 315
# in function
# 316
# in function
# 317
# in function
# 318
# not in function
# 319
# in function
# 320
# not in function
# 321
# not in function
# 322
# in function
# 323
# in function
# 324
# in function
# 325
# not in function
# 326
# falied to store unique_data=  328 error count 12
# not in function
# 327
# not in function
# 328
# not in function
# 329
# not in function
# 330
# not in function
# 331
# not in function
# 332
# not in function
# 333
# not in function
# 334
# not in function
# 335
# in function
# 336
# in function
# 337
# not in function
# 338
# not in function
# 339
# not in function
# 340
# not in function
# 341
# not in function
# 342
# not in function
# 343
# not in function
# 344
# not in function
# 345
# not in function
# 346
# not in function
# 347
# not in function
# 348
# not in function
# 349
# not in function
# 350
# not in function
# 351
# not in function
# 352
# not in function
# 353
# in function
# 354
# not in function
# 355
# in function
# 356
# in function
# 357
# not in function
# 358
# in function
# 359
# not in function
# 360
# not in function
# 361
# not in function
# 362
# not in function
# 363
# in function
# 364
# falied to store unique_data=  366 error count 13
# not in function
# 365
# falied to store unique_data=  367 error count 14
# not in function
# 366
# falied to store unique_data=  368 error count 15
# not in function
# 367
# falied to store unique_data=  369 error count 16
# not in function
# 368
# falied to store unique_data=  370 error count 17
# not in function
# 369
# not in function
# 370
# not in function
# 371
# in function
# 372
# in function
# 373
# in function
# 374
# in function
# 375
# not in function
# 376
# not in function
# 377
# in function
# 378
# not in function
# 379
# not in function
# 380
# not in function
# 381
# not in function
# 382
# not in function
# 383
# not in function
# 384
# not in function
# 385
# in function
# 386
# in function
# 387
# not in function
# 388
# not in function
# 389
# not in function
# 390
# not in function
# 391
# not in function
# 392
# not in function
# 393
# not in function
# 394
# not in function
# 395
# not in function
# 396
# not in function
# 397
# not in function
# 398
# not in function
# 399
# not in function
# 400
# not in function
# 401
# in function
# 402
# in function
# 403
# not in function
# 404
# not in function
# 405
# not in function
# 406
# not in function
# 407
# not in function
# 408
# not in function
# 409
# not in function
# 410
# not in function
# 411
# not in function
# 412
# in function
# 413
# in function
# 414
# in function
# 415
# in function
# 416
# in function
# 417
# in function
# 418
# in function
# 419
# in function
# 420
# in function
# 421
# in function
# 422
# not in function
# 423
# not in function
# 424
# in function
# 425
# not in function
# 426
# not in function
# 427
# not in function
# 428
# not in function
# 429
# not in function
# 430
# not in function
# 431
# not in function
# 432
# not in function
# 433
# not in function
# 434
# not in function
# 435
# not in function
# 436
# not in function
# 437
# not in function
# 438
# not in function
# 439
# not in function
# 440
# not in function
# 441
# not in function
# 442
# not in function
# 443
# not in function
# 444
# in function
# 445
# in function
# 446
# in function
# 447
# in function
# 448
# in function
# 449
# not in function
# 450
# not in function
# 451
# not in function
# 452
# in function
# 453
# in function
# 454
# in function
# 455
# in function
# 456
# not in function
# 457
# not in function
# 458
# not in function
# 459
# not in function
# 460
# not in function
# 461
# not in function
# 462
# not in function
# 463
# not in function
# 464
# not in function
# 465
# not in function
# 466
# not in function
# 467
# in function
# 468
# not in function
# 469
# not in function
# 470
# in function
# 471
# not in function
# 472
# not in function
# 473
# not in function
# 474
# not in function
# 475
# not in function
# 476
# not in function
# 477
# not in function
# 478
# in function
# 479
# in function
# 480
# not in function
# 481
# not in function
# 482
# not in function
# 483
# not in function
# 484
# not in function
# 485
# not in function
# 486
# not in function
# 487
# not in function
# 488
# not in function
# 489
# not in function
# 490
# not in function
# 491
# not in function
# 492
# not in function
# 493
# not in function
# 494
# in function
# 495
# in function
# 496
# in function
# 497
# not in function
# 498
# not in function
# 499
# not in function
# 500
# in function
# 501
# not in function
# 502
# not in function
# 503
# not in function
# 504
# not in function
# 505
# in function
# 506
# not in function
# 507
# not in function
# 508
# not in function
# 509
# not in function
# 510
# not in function
# 511
# not in function
# 512
# not in function
# 513
# not in function
# 514
# in function
# 515
# not in function
# 516
# not in function
# 517
# in function
# 518
# not in function
# 519
# not in function
# 520
# not in function
# 521
# not in function
# 522
# not in function
# 523
# not in function
# 524
# not in function
# 525
# not in function
# 526
# not in function
# 527
# not in function
# 528
# not in function
# 529
# not in function
# 530
# in function
# 531
# in function
# 532
# in function
# 533
# not in function
# 534
# not in function
# 535
# not in function
# 536
# not in function
# 537
# in function
# 538
# in function
# 539
# in function
# 540
# in function
# 541
# not in function
# 542
# not in function
# 543
# not in function
# 544
# not in function
# 545
# not in function
# 546
# not in function
# 547
# not in function
# 548
# in function
# 549
# not in function
# 550
# in function
# 551
# in function
# 552
# not in function
# 553
# not in function
# 554
# in function
# 555
# not in function
# 556
# not in function
# 557
# not in function
# 558
# not in function
# 559
# not in function
# 560
# not in function
# 561
# not in function
# 562
# in function
# 563
# in function
# 564
# not in function
# 565
# not in function
# 566
# in function
# 567
# in function
# 568
# not in function
# 569
# not in function
# 570
# in function
# 571
# in function
# 572
# in function
# 573
# in function
# 574
# in function
# 575
# in function
# 576
# in function
# 577
# in function
# 578
# in function
# 579
# in function
# 580
# not in function
# 581
# in function
# 582
# not in function
# 583
# not in function
# 584
# not in function
# 585
# in function
# 586
# not in function
# 587
# in function
# 588
# in function
# 589
# in function
# 590
# not in function
# 591
# falied to store unique_data=  593 error count 18
# not in function
# 592
# not in function
# 593
# in function
# 594
# in function
# 595
# in function
# 596
# not in function
# 597
# in function
# 598
# in function
# 599
# in function
# 600
# in function
# 601
# not in function
# 602
# not in function
# 603
# not in function
# 604
# not in function
# 605
# not in function
# 606
# not in function
# 607
# not in function
# 608
# not in function
# 609
# not in function
# 610
# not in function
# 611
# not in function
# 612
# not in function
# 613
# not in function
# 614
# not in function
# 615
# not in function
# 616
# not in function
# 617
# not in function
# 618
# not in function
# 619
# not in function
# 620
# not in function
# 621
# not in function
# 622
# falied to store unique_data=  624 error count 19
# not in function
# 623
# not in function
# 624
# not in function
# 625
# not in function
# 626
# not in function
# 627
# not in function
# 628
# in function
# 629
# not in function
# 630
# in function
# 631
# in function
# 632
# not in function
# 633
# not in function
# 634
# not in function
# 635
# not in function
# 636
# falied to store unique_data=  638 error count 20
# not in function
# 637
# falied to store unique_data=  639 error count 21
# not in function
# 638
# falied to store unique_data=  640 error count 22
# not in function
# 639
# in function
# 640
# not in function
# 641
# not in function
# 642
# not in function
# 643
# not in function
# 644
# not in function
# 645
# in function
# 646
# not in function
# 647
# in function
# 648
# in function
# 649
# not in function
# 650
# not in function
# 651
# in function
# 652
# not in function
# 653
# not in function
# 654
# not in function
# 655
# falied to store unique_data=  657 error count 23
# not in function
# 656
# not in function
# 657
# not in function
# 658
# not in function
# 659
# not in function
# 660
# not in function
# 661
# not in function
# 662
# not in function
# 663
# not in function
# 664
# not in function
# 665
# not in function
# 666
# not in function
# 667
# not in function
# 668
# not in function
# 669
# not in function
# 670
# not in function
# 671
# falied to store unique_data=  673 error count 24
# not in function
# 672
# falied to store unique_data=  674 error count 25
# not in function
# 673
# not in function
# 674
# not in function
# 675
# not in function
# 676
# not in function
# 677
# not in function
# 678
# not in function
# 679
# falied to store unique_data=  681 error count 26
# not in function
# 680
# falied to store unique_data=  682 error count 27
# not in function
# 681
# falied to store unique_data=  683 error count 28
# not in function
# 682
# falied to store unique_data=  684 error count 29
# not in function
# 683
# falied to store unique_data=  685 error count 30
# not in function
# 684
# falied to store unique_data=  686 error count 31
# not in function
# 685
# not in function
# 686
# falied to store unique_data=  688 error count 32
# not in function
# 687
# not in function
# 688
# not in function
# 689
# not in function
# 690
# not in function
# 691
# falied to store unique_data=  693 error count 33
# not in function
# 692
# not in function
# 693
# not in function
# 694
# not in function
# 695
# not in function
# 696
# in function
# 697
# not in function
# 698
# not in function
# 699
# not in function
# 700
# not in function
# 701
# not in function
# 702
# not in function
# 703
# falied to store unique_data=  705 error count 34
# not in function
# 704
# falied to store unique_data=  706 error count 35
# not in function
# 705
# falied to store unique_data=  707 error count 36
# not in function
# 706
# falied to store unique_data=  708 error count 37
# not in function
# 707
# falied to store unique_data=  709 error count 38
# not in function
# 708
# not in function
# 709
# not in function
# 710
# falied to store unique_data=  712 error count 39
# not in function
# 711
# falied to store unique_data=  713 error count 40
# not in function
# 712
# falied to store unique_data=  714 error count 41
# not in function
# 713
# falied to store unique_data=  715 error count 42
# not in function
# 714
# falied to store unique_data=  716 error count 43
# not in function
# 715
# falied to store unique_data=  717 error count 44
# not in function
# 716
# falied to store unique_data=  718 error count 45
# not in function
# 717
# falied to store unique_data=  719 error count 46
# not in function
# 718
# not in function
# 719
# not in function
# 720
# not in function
# 721
# in function
# 722
# not in function
# 723
# in function
# 724
# in function
# 725
# not in function
# 726
# not in function
# 727
# not in function
# 728
# not in function
# 729
# not in function
# 730
# not in function
# 731
# not in function
# 732
# not in function
# 733
# not in function
# 734
# not in function
# 735
# not in function
# 736
# in function
# 737
# not in function
# 738
# not in function
# 739
# not in function
# 740
# not in function
# 741
# in function
# 742
# not in function
# 743
# not in function
# 744
# not in function
# 745
# in function
# 746
# not in function
# 747
# in function
# 748
# in function
# 749
# not in function
# 750
# not in function
# 751
# not in function
# 752
# not in function
# 753
# in function
# 754
# not in function
# 755
# not in function
# 756
# not in function
# 757
# not in function
# 758
# in function
# 759
# falied to store unique_data=  761 error count 47
# not in function
# 760
# not in function
# 761
# not in function
# 762
# not in function
# 763
# not in function
# 764
# not in function
# 765
# falied to store unique_data=  767 error count 48
# not in function
# 766
# falied to store unique_data=  768 error count 49
# not in function
# 767
# not in function
# 768
# not in function
# 769
# not in function
# 770
# not in function
# 771
# not in function
# 772
# not in function
# 773
# not in function
# 774
# not in function
# 775
# not in function
# 776
# not in function
# 777
# not in function
# 778
# not in function
# 779
# not in function
# 780
# not in function
# 781
# not in function
# 782
# not in function
# 783
# not in function
# 784
# not in function
# 785
# not in function
# 786
# not in function
# 787
# not in function
# 788
# not in function
# 789
# not in function
# 790
# in function
# 791
# in function
# 792
# not in function
# 793
# not in function
# 794
# not in function
# 795
# not in function
# 796
# not in function
# 797
# not in function
# 798
# not in function
# 799
# not in function
# 800
# not in function
# 801
# not in function
# 802
# in function
# 803
# in function
# 804
# not in function
# 805
# not in function
# 806
# not in function
# 807
# not in function
# 808
# not in function
# 809
# not in function
# 810
# not in function
# 811
# not in function
# 812
# in function
# 813
# in function
# 814
# not in function
# 815
# not in function
# 816
# in function
# 817
# in function
# 818
# not in function
# 819
# in function
# 820
# not in function
# 821
# not in function
# 822
# in function
# 823
# not in function
# 824
# not in function
# 825
# not in function
# 826
# not in function
# 827
# not in function
# 828
# in function
# 829
# not in function
# 830
# not in function
# 831
# in function
# 832
# not in function
# 833
# not in function
# 834
# not in function
# 835
# not in function
# 836
# not in function
# 837
# in function
# 838
# in function
# 839
# in function
# 840
# in function
# 841
# in function
# 842
# in function
# 843
# not in function
# 844
# not in function
# 845
# not in function
# 846
# not in function
# 847
# not in function
# 848
# not in function
# 849
# not in function
# 850
# not in function
# 851
# in function
# 852
# not in function
# 853
# not in function
# 854
# not in function
# 855
# not in function
# 856
# not in function
# 857
# not in function
# 858
# not in function
# 859
# not in function
# 860
# not in function
# 861
# not in function
# 862
# not in function
# 863
# not in function
# 864
# not in function
# 865
# in function
# 866
# in function
# 867
# in function
# 868
# not in function
# 869
# not in function
# 870
# in function
# 871
# in function
# 872
# in function
# 873
# in function
# 874
# in function
# 875
# in function
# 876
# in function
# 877
# not in function
# 878
# not in function
# 879
# not in function
# 880
# in function
# 881
# in function
# 882
# in function
# 883
# not in function
# 884
# not in function
# 885
# not in function
# 886
# not in function
# 887
# not in function
# 888
# not in function
# 889
# falied to store unique_data=  891 error count 50
# not in function
# 890
# falied to store unique_data=  892 error count 51
# not in function
# 891
# not in function
# 892
# not in function
# 893
# not in function
# 894
# not in function
# 895
# falied to store unique_data=  897 error count 52
# not in function
# 896
# not in function
# 897
# not in function
# 898
# not in function
# 899
# not in function
# 900
# not in function
# 901
# not in function
# 902
# in function
# 903
# in function
# 904
# not in function
# 905
# not in function
# 906
# not in function
# 907
# not in function
# 908
# not in function
# 909
# not in function
# 910
# not in function
# 911
# not in function
# 912
# not in function
# 913
# not in function
# 914
# not in function
# 915
# not in function
# 916
# not in function
# 917
# not in function
# 918
# not in function
# 919
# not in function
# 920
# not in function
# 921
# not in function
# 922
# in function
# 923
# in function
# 924
# not in function
# 925
# not in function
# 926
# not in function
# 927
# in function
# 928
# not in function
# 929
# not in function
# 930
# not in function
# 931
# not in function
# 932
# not in function
# 933
# not in function
# 934
# not in function
# 935
# not in function
# 936
# in function
# 937
# in function
# 938
# in function
# 939
# not in function
# 940
# not in function
# 941
# in function
# 942
# in function
# 943
# in function
# 944
# in function
# 945
# in function
# 946
# not in function
# 947
# in function
# 948
# not in function
# 949
# in function
# 950
# in function
# 951
# not in function
# 952
# not in function
# 953
# not in function
# 954
# not in function
# 955
# not in function
# 956
# not in function
# 957
# not in function
# 958
# not in function
# 959
# in function
# 960
# in function
# 961
# in function
# 962
# not in function
# 963
# in function
# 964
# in function
# 965
# not in function
# 966
# not in function
# 967
# not in function
# 968
# in function
# 969
# in function
# 970
# in function
# 971
# in function
# 972
# in function
# 973
# not in function
# 974
# not in function
# 975
# not in function
# 976
# not in function
# 977
# not in function
# 978
# not in function
# 979
# falied to store unique_data=  981 error count 53
# not in function
# 980
# falied to store unique_data=  982 error count 54
# not in function
# 981
# falied to store unique_data=  983 error count 55
# not in function
# 982
# in function
# 983
# in function
# 984
# not in function
# 985
# not in function
# 986
# not in function
# 987
# not in function
# 988
# not in function
# 989
# not in function
# 990
# not in function
# 991
# not in function
# 992
# in function
# 993
# not in function
# 994
# falied to store unique_data=  996 error count 56
# in function
# 995
# falied to store unique_data=  997 error count 57
# in function
# 996
# not in function
# 997
# not in function
# 998
# not in function
# 999
# not in function
# 1000
# 1000
# 1001
# {'base_code_line_number': 29,
#  'base_patch_number': 1,
#  'changed_patch_number': 2,
#  'class_list': ['SiteContentServiceController'],
#  'code_file_name': 'acumos_28',
#  'code_snippet': '',
#  'comment_id': 'a5004399_a2a84ec6',
#  'func_list': ['public SiteContentServiceController() }',
#                'public JsonResponse<MLPSiteContent> getTermsCondition()',
#                'public JsonResponse<MLPSiteContent> getContactInfo()',
#                'public JsonResponse<MLPSiteContent> getCobrandLogo()',
#                'public JsonResponse<Object> updateCobrandLogo(@RequestBody '
#                'JsonRequest<MLPSiteContent> content)',
#                'public JsonResponse<Object> updateCarouselPicture(@RequestBody '
#                'JsonRequest<MLPSiteContent> content)'],
#  'idx': 1001,
#  'line_change': 0,
#  'message': 'No need for empty no-arg constructor, you get this for free',
#  'prime_var_dic': {},
#  'project_name': 'acumos_',
#  'source': 'E:\\pantho_Tufano_processing\r\n'
#            'kage org.acumos.portal.be.controller;\n'
#            '\n'
#            'import org.acumos.cds.domain.MLPSiteContent;\n'
#            'import org.acumos.portal.be.APINames;\n'
#            'import org.acumos.portal.be.common.JSONTags;\n'
#            'import org.acumos.portal.be.common.JsonRequest;\n'
#            'import org.acumos.portal.be.common.JsonResponse;\n'
#            'import org.acumos.portal.be.service.SiteContentService;\n'
#            'import org.acumos.portal.be.util.EELFLoggerDelegate;\n'
#            'import org.springframework.beans.factory.annotation.Autowired;\n'
#            'import org.springframework.stereotype.Controller;\n'
#            'import org.springframework.web.bind.annotation.PathVariable;\n'
#            'import org.springframework.web.bind.annotation.RequestBody;\n'
#            'import org.springframework.web.bind.annotation.RequestMapping;\n'
#            'import org.springframework.web.bind.annotation.RequestMethod;\n'
#            'import org.springframework.web.bind.annotation.ResponseBody;\n'
#            '\n'
#            'import io.swagger.annotations.ApiOperation;\n'
#            '\n'
#            '@Controller\n'
#            '@RequestMapping(APINames.SITE_PATH)\n'
#            'public class SiteContentServiceController extends '
#            'AbstractController {\n'
#            '\t\n'
#            '\t@Autowired\n'
#            '\tSiteContentService siteContentService;\n'
#            '\t\n'
#            '\tprivate static final EELFLoggerDelegate log = '
#            'EELFLoggerDelegate.getLogger(SiteContentServiceController.class);\n'
#            '\n'
#            '<|startfocus|>\n'
#            '    public SiteContentServiceController() {}\n'
#            '    \n'
#            '    @ApiOperation(value = "Gets terms and conditions ", response = '
#            'MLPSiteContent.class)\n'
#            '    @RequestMapping(value = { APINames.GET_TERMS_CONDITION }, '
#            'method = RequestMethod.GET, produces = APPLICATION_JSON)\n'
#            '    @ResponseBody\n'
#            '    public JsonResponse<MLPSiteContent> getTermsCondition() {\n'
#            '        log.debug(EELFLoggerDelegate.debugLogger, '
#            '"getTermsCondition");\n'
#            '        MLPSiteContent content = null;\n'
#            '        JsonResponse<MLPSiteContent> data = new JsonResponse<>();\n'
#            '        try {\n'
#            '            content = siteContentService.getTermsCondition();\n'
#            '            if (content != null) { \n'
#            '            \tdata.setResponseBody(content);\n'
#            '                '
#            'data.setErrorCode(JSONTags.TAG_ERROR_CODE_SUCCESS);\n'
#            '                data.setResponseDetail("Terms conditions fetched '
#            'successfully");\n'
#            '            }\n'
#            '        } catch (Exception e) {\n'
#            '        \tdata.setErrorCode(JSONTags.TAG_ERROR_CODE);\n'
#            '        \tdata.setResponseDetail("Exception Occurred Fetching '
#            'Terms Conditions");\n'
#            '            log.error(EELFLoggerDelegate.errorLogger, "Exception '
#            'Occurred Fetching Terms Conditions", e);\n'
#            '        }\n'
#            '        return data;\n'
#            '    }\n'
#            '<|endfocus|>\n'
#            '\n'
#            '    @ApiOperation(value = "Gets contact info ", response = '
#            'MLPSiteContent.class)\n'
#            '    @RequestMapping(value = { APINames.GET_CONTACT_INFO }, method '
#            '= RequestMethod.GET, produces = APPLICATION_JSON)\n'
#            '    @ResponseBody\n'
#            '    public JsonResponse<MLPSiteContent> getContactInfo() {\n'
#            '        log.debug(EELFLoggerDelegate.debugLogger, '
#            '"getContactInfo");\n'
#            '        MLPSiteContent content = null;\n'
#            '        JsonResponse<MLPSiteContent> data = new JsonResponse<>();\n'
#            '        try {\n'
#            '            content = siteContentService.getContactInfo();\n'
#            '            if (content != null) { \n'
#            '            \tdata.setResponseBody(content);\n'
#            '                '
#            'data.setErrorCode(JSONTags.TAG_ERROR_CODE_SUCCESS);\n'
#            '                data.setResponseDetail("Contact info fetched '
#            'successfully");\n'
#            '            }\n'
#            '        } catch (Exception e) {\n'
#            '        \tdata.setErrorCode(JSONTags.TAG_ERROR_CODE);\n'
#            '        \tdata.setResponseDetail("Exception Occurred Fetching '
#            'Contact Info");\n'
#            '            log.error(EELFLoggerDelegate.errorLogger, "Exception '
#            'Occurred Fetching Contact Info", e);\n'
#            '        }\n'
#            '        return data;\n'
#            '    }\n'
#            '\n'
#            '    @ApiOperation(value = "Gets cobranding Logo ", response = '
#            'MLPSiteContent.class)\n'
#            '    @RequestMapping(value = { APINames.GET_COBRAND_LOGO }, method '
#            '= RequestMethod.GET, produces = APPLICATION_JSON)\n'
#            '    @ResponseBody\n'
#            '    public JsonResponse<MLPSiteContent> getCobrandLogo() {\n'
#            '        log.debug(EELFLoggerDelegate.debugLogger, '
#            '"getCobrandLogo");\n'
#            '        MLPSiteContent content = null;\n'
#            '        JsonResponse<MLPSiteContent> data = new JsonResponse<>();\n'
#            '        try {\n'
#            '            content = siteContentService.getCobrandLogo();\n'
#            '            if (content != null) { \n'
#            '            \tdata.setResponseBody(content);\n'
#            '                '
#            'data.setErrorCode(JSONTags.TAG_ERROR_CODE_SUCCESS);\n'
#            '                data.setResponseDetail("Cobrand Logo fetched '
#            'successfully");\n'
#            '            }\n'
#            '        } catch (Exception e) {\n'
#            '        \tdata.setErrorCode(JSONTags.TAG_ERROR_CODE);\n'
#            '        \tdata.setResponseDetail("Exception Occurred Fetching '
#            'Cobrand Logo");\n'
#            '            log.error(EELFLoggerDelegate.errorLogger, "Exception '
#            'Occurred Fetching Cobrand Logo", e);\n'
#            '        }\n'
#            '        return data;\n'
#            '    }\n'
#            '\n'
#            '    @ApiOperation(value = "Updates cobranding Logo ", response = '
#            'JsonResponse.class)\n'
#            '    @RequestMapping(value = { APINames.UPDATE_COBRAND_LOGO }, '
#            'method = RequestMethod.POST, produces = APPLICATION_JSON)\n'
#            '    @ResponseBody\n'
#            '    public JsonResponse<Object> updateCobrandLogo(@RequestBody '
#            'JsonRequest<MLPSiteContent> content) {\n'
#            '        log.debug(EELFLoggerDelegate.debugLogger, '
#            '"updateCobrandLogo");\n'
#            '        JsonResponse<Object> data = new JsonResponse<>();\n'
#            '        MLPSiteContent picture = content.getBody();\n'
#            '        if (picture != null) {\n'
#            '            try {\n'
#            '                siteContentService.setCobrandLogo(picture);\n'
#            '            \tdata.setStatus(true);\n'
#            '                '
#            'data.setErrorCode(JSONTags.TAG_ERROR_CODE_SUCCESS);\n'
#            '                data.setResponseDetail("Cobrand Logo updated '
#            'successfully");\n'
#            '            } catch (Exception e) {\n'
# ...
#                             'Gets',
#                             '<|s|>',
#                             'contact',
#                             '<|s|>',
#                             'info',
#                             '<|s|>',
#                             '"',
#                             ',',
#                             '<|s|>',
#                             'response',
#                             '<|s|>',
#                             '=',
#                             '<|s|>',
#                             'MLPSite',
#                             'Content',
#                             '.',
#                             'class',
#                             ')',
#                             '<|nl|>',
#                             '<|4-s|>',
#                             '@',
#                             'Request',
#                             'Mapping',
#                             '(',
#                             'value',
#                             '<|s|>',
#                             '=',
#                             '<|s|>',
#                             '{',
#                             '<|s|>',
#                             'APINames',
#                             '.',
#                             'GET',
#                             '_',
#                             'CONTACT',
#                             '_',
#                             'INFO',
#                             '<|s|>',
#                             '}',
#                             ',',
#                             '<|s|>',
#                             'method',
#                             '<|s|>',
#                             '=',
#                             '<|s|>',
#                             'Request',
#                             'Method',
#                             '.',
#                             'GET',
#                             ',',
#                             '<|s|>',
#                             'produces',
#                             '<|s|>',
#                             '=',
#                             '<|s|>',
#                             'APPLICATION',
#                             '_',
#                             'JSON',
#                             ')',
#                             '<|nl|>',
#                             '<|4-s|>',
#                             '@',
#                             'Response',
#                             'Body',
#                             '<|nl|>',
#                             '<|4-s|>',
#                             'public',
#                             '<|s|>',
#                             'Json',
#                             'Response',
#                             '<',
#                             'MLPSite',
#                             'Content',
#                             '>',
#                             '<|s|>',
#                             'get',
#                             'Contact',
#                             'Info',
#                             '(',
#                             ')',
#                             '<|s|>',
#                             '{',
#                             '<|nl|>',
#                             '<|8-s|>',
#                             'log',
#                             '.',
#                             'debug',
#                             '(',
#                             'EELFLogger',
#                             'Delegate',
#                             '.',
#                             'debug',
#                             'Logger',
#                             ',',
#                             '<|s|>',
#                             '"',
#                             'get',
#                             'Contact',
#                             'Info',
#                             '"',
#                             ');',
#                             '<|nl|>',
#                             '<|8-s|>',
#                             'MLPSite',
#                             'Content',
#                             '<|s|>',
#                             'content',
#                             '<|s|>',
#                             '=',
#                             '<|s|>',
#                             'null',
#                             ';',
#                             '<|nl|>',
#                             '<|8-s|>',
#                             'Json',
#                             'Response',
#                             '<',
#                             'MLPSite',
#                             'Content',
#                             '>',
#                             '<|s|>',
#                             'data',
#                             '<|s|>',
#                             '=',
#                             '<|s|>',
#                             'new',
#                             '<|s|>',
#                             'Json',
#                             'Response',
#                             '<',
#                             '>',
#                             '(',
#                             ');'],
#  'tokenized_comment': ['No',
#                        '<|s|>',
#                        'need',
#                        '<|s|>',
#                        'for',
#                        '<|s|>',
#                        'empty',
#                        '<|s|>',
#                        'no',
#                        '-',
#                        'arg',
#                        '<|s|>',
#                        'constructor',
#                        ',',
#                        '<|s|>',
#                        'you',
#                        '<|s|>',
#                        'get',
#                        '<|s|>',
#                        'this',
#                        '<|s|>',
#                        'for',
#                        '<|s|>',
#                        'free'],
#  'tokenized_target': ['<|t|>',
#                       '@',
#                       'Api',
#                       'Operation',
#                       '(',
#                       'value',
#                       '<|s|>',
#                       '=',
#                       '<|s|>',
#                       '"',
#                       'Gets',
#                       '<|s|>',
#                       'terms',
#                       '<|s|>',
#                       'and',
#                       '<|s|>',
#                       'conditions',
#                       '<|s|>',
#                       '"',
#                       ',',
#                       '<|s|>',
#                       'response',
#                       '<|s|>',
#                       '=',
#                       '<|s|>',
#                       'MLPSite',
#                       'Content',
#                       '.',
#                       'class',
#                       ')',
#                       '<|nl|>',
#                       '<|t|>',
#                       '@',
#                       'Request',
#                       'Mapping',
#                       '(',
#                       'value',
#                       '<|s|>',
#                       '=',
#                       '<|s|>',
#                       '{',
#                       '<|s|>',
#                       'APINames',
#                       '.',
#                       'GET',
#                       '_',
#                       'TERMS',
#                       '_',
#                       'CONDITION',
#                       '<|s|>',
#                       '}',
#                       ',',
#                       '<|s|>',
#                       'method',
#                       '<|s|>',
#                       '=',
#                       '<|s|>',
#                       'Request',
#                       'Method',
#                       '.',
#                       'GET',
#                       ',',
#                       '<|s|>',
#                       'produces',
#                       '<|s|>',
#                       '=',
#                       '<|s|>',
#                       'APPLICATION',
#                       '_',
#                       'JSON',
#                       ')',
#                       '<|nl|>',
#                       '<|t|>',
#                       '@',
#                       'Response',
#                       'Body',
#                       '<|nl|>',
#                       '<|t|>',
#                       'public',
#                       '<|s|>',
#                       'Json',
#                       'Response',
#                       '<',
#                       'MLPSite',
#                       'Content',
#                       '>',
#                       '<|s|>',
#                       'get',
#                       'Terms',
#                       'Condition',
#                       '(',
#                       ')',
#                       '<|s|>',
#                       '{',
#                       '<|nl|>',
#                       '<|2-t|>',
#                       'log',
#                       '.',
#                       'debug',
#                       '(',
#                       'EELFLogger',
#                       'Delegate',
#                       '.',
#                       'debug',
#                       'Logger',
#                       ',',
#                       '<|s|>',
#                       '"',
#                       'get',
#                       'Terms',
#                       'Condition',
#                       '"',
#                       ');',
#                       '<|nl|>',
#                       '<|2-t|>',
#                       'MLPSite',
#                       'Content',
#                       '<|s|>',
#                       'content',
#                       '<|s|>',
#                       '=',
#                       '<|s|>',
#                       'null',
#                       ';',
#                       '<|nl|>',
#                       '<|2-t|>',
#                       'Json',
#                       'Response',
#                       '<',
#                       'MLPSite',
#                       'Content',
#                       '>',
#                       '<|s|>',
#                       'data',
#                       '<|s|>',
#                       '=',
#                       '<|s|>',
#                       'new',
#                       '<|s|>',
#                       'Json',
#                       'Response',
#                       '<',
#                       '>',
#                       '(',
#                       ');',
#                       '<|nl|>',
#                       '<|2-t|>',
#                       'try',
#                       '<|s|>',
#                       '{',
#                       '<|nl|>',
#                       '<|3-t|>',
#                       'content',
#                       '<|s|>',
#                       '=',
#                       '<|s|>',
#                       'site',
#                       'Content',
#                       'Service',
#                       '.',
#                       'get',
#                       'Terms',
#                       'Condition',
#                       '(',
#                       ');',
#                       '<|nl|>',
#                       '<|3-t|>',
#                       'if',
#                       '<|s|>',
#                       '(',
#                       'content',
#                       '<|s|>',
#                       '!=',
#                       '<|s|>',
#                       'null',
#                       ')',
#                       '<|s|>',
#                       '{',
#                       '<|nl|>',
#                       '<|4-t|>',
#                       'data',
#                       '.',
#                       'set',
#                       'Response',
#                       'Body',
#                       '(',
#                       'content',
#                       ');',
#                       '<|nl|>',
#                       '<|4-t|>',
#                       'data',
#                       '.',
#                       'set',
#                       'Error',
#                       'Code',
#                       '(',
#                       'JSONTags',
#                       '.',
#                       'TAG',
#                       '_',
#                       'ERROR',
#                       '_',
#                       'CODE',
#                       '_',
#                       'SUCCESS',
#                       ');',
#                       '<|nl|>',
#                       '<|4-t|>',
#                       'data',
#                       '.',
#                       'set',
#                       'Response',
#                       'Detail',
#                       '(',
#                       '"',
#                       'Terms',
#                       '<|s|>',
#                       'conditions',
#                       '<|s|>',
#                       'fetched',
#                       '<|s|>',
#                       'successfully',
#                       '"',
#                       ');',
#                       '<|nl|>',
#                       '<|3-t|>',
#                       '}',
#                       '<|nl|>',
#                       '<|2-t|>',
#                       '}',
#                       '<|s|>',
#                       'catch',
#                       '<|s|>',
#                       '(',
#                       'Exception',
#                       '<|s|>',
#                       'e',
#                       ')',
#                       '<|s|>',
#                       '{',
#                       '<|nl|>',
#                       '<|3-t|>',
#                       'data',
#                       '.',
#                       'set',
#                       'Error',
#                       'Code',
#                       '(',
#                       'JSONTags',
#                       '.',
#                       'TAG',
#                       '_',
#                       'ERROR',
#                       '_',
#                       'CODE',
#                       ');',
#                       '<|nl|>',
#                       '<|3-t|>',
#                       'data',
#                       '.',
#                       'set',
#                       'Response',
#                       'Detail',
#                       '(',
#                       '"',
#                       'Exception',
#                       '<|s|>',
#                       'Occurred',
#                       '<|s|>',
#                       'Fetching',
#                       '<|s|>',
#                       'Terms',
#                       '<|s|>',
#                       'Conditions',
#                       '"',
#                       ');',
#                       '<|nl|>',
#                       '<|3-t|>',
#                       'log',
#                       '.',
#                       'error',
#                       '(',
#                       'EELFLogger',
#                       'Delegate',
#                       '.',
#                       'error',
#                       'Logger',
#                       ',',
#                       '<|s|>',
#                       '"',
#                       'Exception',
#                       '<|s|>',
#                       'Occurred',
#                       '<|s|>',
#                       'Fetching',
#                       '<|s|>',
#                       'Terms',
#                       '<|s|>',
#                       'Conditions',
#                       '"',
#                       ',',
#                       '<|s|>',
#                       'e',
#                       ');',
#                       '<|nl|>',
#                       '<|2-t|>',
#                       '}',
#                       '<|nl|>',
#                       '<|2-t|>',
#                       'return',
#                       '<|s|>',
#                       'data',
#                       ';',
#                       '<|nl|>',
#                       '<|t|>',
#                       '}',
#                       '<|nl|>',
#                       '<|nl|>',
#                       '<|nl|>'],
#  'written_on': '2019-02-12 21:18:40'}
# not in function
# 1001
# in function
# 1002
# not in function
# 1003
# not in function
# 1004
# not in function
# 1005
# not in function
# 1006
# not in function
# 1007
# not in function
# 1008
# not in function
# 1009
# falied to store unique_data=  1011 error count 58
# in function
# 1010
# falied to store unique_data=  1012 error count 59
# in function
# 1011
# falied to store unique_data=  1013 error count 60
# not in function
# 1012
# in function
# 1013
# in function
# 1014
# in function
# 1015
# not in function
# 1016
# not in function
# 1017
# not in function
# 1018
# not in function
# 1019
# not in function
# 1020
# not in function
# 1021
# not in function
# 1022
# not in function
# 1023
# not in function
# 1024
# not in function
# 1025
# not in function
# 1026
# not in function
# 1027
# not in function
# 1028

# %%
with open('unique_data_processed_with_Date.json', 'w', encoding="utf8") as f:  # writing JSON object
    json.dump(unique_data_processed, f)

# %%
print(unique_data[0])
# Out:
# {'base_patch_number': 3, 'changed_patch_number': 4, 'comment_id': 'a068aa5b_b404cd60', 'file_name': 'acumos_197', 'line_change': 0, 'line_number': 64, 'message': 'One last occurrence - please change to acumos.org/...', 'project_name': 'acumos_', 'written_on': '2017-11-21 20:29:13'}
