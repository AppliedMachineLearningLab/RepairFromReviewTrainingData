# %%
#unified_with_date

# %%
from nltk.tokenize import MWETokenizer, TweetTokenizer, WordPunctTokenizer 
from nltk.tokenize import word_tokenize
import re

VALUES = ['>>>=', '>>=', '<<=',  '%=', '^=', '|=', '&=', '/=',
                  '*=', '-=', '+=', '<<', '--', '++', '||', '&&', '!=',
                  '>=', '<=', '==', '%', '^', '|', '&', '/', '*', '-',
                  '+', ':', '?', '~', '!', '<', '>', '=', '...', '->', '::', '\\', '\\\\', '\*', '*\\', '\\\\\\']
INFIX = ['||', '&&', '|', '^', '&', '==', '!=', '<', '>', '<=', '>=', 
             '<<', '>>', '>>>', '+', '-', '*', '/', '%']
PREFIX = ['++', '--', '!', '~', '+', '-']
POSTFIX = ['++', '--']
ASSIGNMENT = ['=', '+=', '-=', '*=', '/=', '&=', '|=', '^=', '%=', '<<=', '>>=', '>>>=']
LAMBDA = ['->']
COMMENT = ['//', '/*', '*/']
METHOD_REFERENCE = ['::']

WHITESPACE_DICT = {"                ":'<|16-s|>', 
                   "            ":'<|12-s|>', 
                   "        ":'<|8-s|>', 
                   "    ":'<|4-s|>', 
                   "  ":'<|2-s|>', " ":'<|s|>',
                   "\t\t\t\t":'<|4-t|>',"\t\t\t":'<|3-t|>',"\t\t":'<|2-t|>',"\t":'<|t|>',"\n":'<|nl|>'}

WHITESPACES = [WHITESPACE_DICT[x] for x in WHITESPACE_DICT]

CUSTOM_TOKEN = ["<|startcode|>", "<|endcode|>", "<|startfocus|>", "<|endfocus|>", "<|startcomment|>", "<|endcomment|>", 
                   "<|stringliteral|>", "<|singlelinecomment|>", "<|multilinecomment|>", "<|del|>"]

values = list(set(INFIX+PREFIX+POSTFIX+ASSIGNMENT+LAMBDA+COMMENT+METHOD_REFERENCE))
token_phrases = []
word_punct_tokenizer = WordPunctTokenizer()
for tok in CUSTOM_TOKEN+WHITESPACES:
    temp = tuple(word_punct_tokenizer.tokenize(tok))
    token_phrases.append(temp)
for w in values:
    temp = tuple(MWETokenizer().tokenize(w))
    if len(temp) > 1:
        token_phrases.append(temp)

word_punct_tokenizer = WordPunctTokenizer()
tweet_tokenizer = TweetTokenizer()
mwe_tokenizer = MWETokenizer(token_phrases, separator="")

def state(c):
    n = ord(c)
    if n>=97 and n<=122: # lower case
        return 1
    elif n>=65 and n<=90: # upper case
        return 2
    elif n>=48 and n<=57: # numbers
        return 3
    elif c.isspace(): # whitespaces
        return 4
    elif c in ['_', '$']: 
        return 5
    elif n < 128:
        return 6
    else:
        return 7

def space_up(s):
    if s is None or s == "":
        return ""
    new_s = s[0]
    for i in range(1,len(s)):
        prev_state = state(s[i-1])
        curr_state = state(s[i])
        if prev_state in [1,2] and curr_state in [3]:
            new_s += " "
        elif prev_state in [1] and curr_state in [2]:
            new_s += " "
        elif prev_state in [3] and curr_state in [1,2]:
            new_s += " "
        elif prev_state in [1,2,3] and curr_state in [5]:
            new_s += " "
        elif prev_state in [5] and curr_state in [1,2,3]:
            new_s += " "
        new_s+=s[i]
    return new_s

def white_space_tokenize(s):
    for x in WHITESPACE_DICT:
        s = s.replace(x, WHITESPACE_DICT[x])
    for key in WHITESPACE_DICT:
        val = WHITESPACE_DICT[x]
        s = s.replace(val, " "+val+" ")
    return s

def extreme_tokenization(comment):
    comment = white_space_tokenize(comment)
    comment = space_up(comment)
    tokenized = tweet_tokenizer.tokenize(comment)
    tokenized = word_punct_tokenizer.tokenize(' '.join(tokenized))
    tokenized = mwe_tokenizer.tokenize(tokenized)
    tokenized_comment = ' '.join(tokenized)
    tokenized_comment = re.sub(r'[^\x00-\x7f]',r'', tokenized_comment)
    tokenized = tokenized_comment.split()
    return tokenized

# %%
from os import path
import json
import re
import subprocess
import nltk
from pprint import pprint
from nltk.tokenize import sent_tokenize, word_tokenize
from tqdm import tqdm
nltk.download('punkt')

def getJsonData(JsonFile):
    with open(JsonFile, encoding="utf8") as f:
        data = json.load(f)
    return data
def read(path):
    return open(path, 'r', encoding = 'utf-8').read()


BASE="E:/codes/"
unique_data = getJsonData('E:\\unified_with_date.json')
data = unique_data[1020]
code_file_name = data['file_name']
base_patch_number = data['base_patch_number']
main_code_path = BASE+code_file_name+'/'+str(base_patch_number)+'.java'
main_code = read(main_code_path)


def get_source_target(file1, file2, line_number, change_window_size=5):
    source_target = subprocess.check_output(['java', '-jar', 'ChangedLineF.jar', \
                                file1, file2, str(line_number), str(change_window_size)]).decode("utf-8")
    (source, target) = source_target.split("<|source-target-sep|>")
    return source, target

def end_scope(start_index, lines):
    #print(lines)
    counter = 0
    end_index = -1
    found = False
    for index in range(start_index, len(lines), 1):
        #print(lines[index])
        #print(counter)
        for char in lines[index]:
            if(char=='{'):
                counter+=1
                found = True
            elif(char == "}"):
                counter-=1
                found = True
            if(counter==0 and found):
                end_index = index
                break
        if end_index!=-1:
            break
    return end_index

unique_data_processed = []
MAX_NUM_TOKEN = 800
UP_TOKEN = MAX_NUM_TOKEN//2
c = 0
ec = 0
errors = []
#for idx, data in enumerate(unique_data):#[2428:2429]#[1000:1001]
def process(data):    
    code_file_name = data['file_name']
    base_patch_number = data['base_patch_number']
    changed_patch_number = data['changed_patch_number']
    main_code_path = BASE+code_file_name+'/'+str(base_patch_number)+'.java'
    changed_code_path = BASE+code_file_name+'/'+str(changed_patch_number)+'.java'
    line_no = data['line_number']
    main_code = read(main_code_path)
    changed_code = read(changed_code_path)
    sample = main_code
    message = data['message']
    comment_id = data['comment_id']
    source = ""
    target=''
    try:
        source, target = get_source_target(main_code_path, changed_code_path,line_no-1)
    except:
        return
    
    sample = source
    data_dic = {}
    #data_dic['source'] = source
    data_dic['message'] = message
    
    data_dic['comment_id'] = comment_id
    data_dic['target'] = target
    data_dic['source'] = source
    #data_dic['idx'] = c
    func_list = []
    data_dic['code_snippet'] = ""
    data_dic['prime_var_dic'] = {}
    #print(sample)
    classes = re.findall(r"(?:(public\s))?(class)\s([^\n\s]*)", sample)
    lines = sample.split('\n')
    class_list = []
    sp_start_func= -1
    sp_end_func= len(sample.split('\n'))   
    for cls_tpl in classes:
        s = "".join(cls_tpl[-1])
        s = s.strip()
        class_list.append(s) ## class list
        cls = s
        #print(s)
        start_index = -1
        for i in range(len(lines)):
            if cls in lines[i]:
                start_index = i
                break
        #print(start_index)
        end_index = end_scope(start_index, lines)
        #print(end_index)
        class_scope_dic = {}
        for i in range(start_index, end_index+1):
            class_scope_dic[i] = True
        funcs = re.findall(r"(public|protected|private|static|\s) +([\w\<\>\[\]]+\s+(\w+)) *\([^\)]*\) *(\{?|[^;])", "\n".join(lines[start_index:end_index+1]))
        func_scopes = []
        #print(funcs)
        #continue
        visited_func = set()
        for func in funcs:
            #print(func)
            if(func[-1]!= "{"):
                continue
            fc = list(func)
            fc = fc[-3]
            s = "".join(fc)
            s = s.strip()
            #func_list.append(s) ## function list
            #print(func_list)
            
            for index in range(start_index, end_index+1, 1):
                if s in lines[index]:
                    start_func = index
                    end_func = end_scope(index, lines)
                    
                    func_scopes.append((start_func,end_func))
                    if s not in visited_func:
                        visited_func.add(s)
                        func_list.append(lines[index].replace("{", "").strip())
                    
                    if(start_func<=line_no<=end_func):
                        special_func = "\n".join(lines[start_func:end_func+1])
                        #data_dic['code_snippet'] = special_func
                        #nonlocal sp_start_func
                        sp_start_func= start_func
                        #nonlocal sp_end_func
                        sp_end_func= end_func
        
        for func_sc in func_scopes:
            for i in range(func_sc[0], func_sc[1]+1):
                class_scope_dic[i] = False
        prime_var_list = []
        dic_vars = {}
        for i in range(start_index, end_index+1):
            if class_scope_dic[i]==True:
                #prime_vars = re.findall(r""""[^"]*"|((?=_[a-z_0-9]|[a-z])[a-z_0-9]+((?=\s*=)))""",lines[i])
                if '(' not in lines[i] and "return" not in lines[i] and "extends" not in lines[i]:
                    prime_vars = re.findall(r"""(\w+\s+)([a-zA-Z_][a-zA-Z0-9_]*)""", lines[i])
                    if len(prime_vars)==2:
                        if(len(prime_vars[1])==2 and prime_vars[1][1] in dic_vars.keys()):
                            dic_vars[prime_vars[1][1]]+=1
                        elif len(prime_vars[1])==2:
                            dic_vars[prime_vars[1][1]] =1
        #if(len(list(dic_vars.keys()))>0):
            #print(dic_vars)
        data_dic['prime_var_dic'] = dic_vars
    data_dic['class_list'] = class_list
    data_dic['func_list'] = func_list
    
    #print("specials   ###", sp_start_func, sp_end_func)
    
    if not (0<len(extreme_tokenization(data_dic['code_snippet']))<MAX_NUM_TOKEN): 
        up_count = 0
        up_done = False
        down_count = 0
        down_done = False
        splitted = sample.split("\n")
        while(1):
            #print(max(0, line_no-up_count),line_no+1)
            if len(extreme_tokenization("\n".join(splitted[max(0,sp_start_func, line_no-up_count):line_no+1])))<UP_TOKEN:
                if(up_count==line_no):
                    break
                up_count+=1
            else:
                break
                #print("something is wrong")
                      
        while(1):
            if len(extreme_tokenization("\n".join(splitted[(line_no-up_count):min(line_no+down_count+1,sp_end_func, len(splitted))])))<MAX_NUM_TOKEN:
                if(down_count==len(splitted)):
                    break
                down_count+=1
            else:
                break
    if sp_start_func != -1:
        #data_dic['code_snippet'] = "\n".join(splitted[sp_start_func:sp_end_func+1])
        
        if("startfocus" in splitted[sp_start_func-1]):
            sp_start_func-=1
        if sp_end_func <=len(splitted)-2 and "endfocus" in splitted[sp_end_func+1]:
            sp_end_func+=2
        if sp_end_func <=len(splitted)-1 and "endfocus" in splitted[sp_end_func]:
            sp_end_func+=1
        #print(" ".join(splitted[sp_start_func:sp_end_func+1]))
        #print(sp_start_func)
        #print(sp_end_func)
        code_snippet = "\n".join(splitted[sp_start_func:sp_end_func+1])
        #print("in function")
        
    else:
        #data_dic['code_snippet'] = "\n".join(splitted[(line_no-up_count):(line_no+down_count+1)])
        #print("not in function")
        if("startfocus" in splitted[(line_no-up_count-1)]):
            up_count+=1
        if line_no+down_count <=len(splitted)-1 and "endfocus" in splitted[line_no+down_count]:
            down_count+=1
        code_snippet = "\n".join(splitted[(line_no-up_count):(line_no+down_count+1)])
        #print(line_no-up_count)
        #print(line_no+down_count+1)
        #print(code_snippet)
    #print(code_snippet)
    #print(data_dic['func_list'])
    if "<|startfocus|>" in code_snippet and "<|endfocus|>" not in code_snippet:
        code_snippet =code_snippet+  "\n<|endfocus|>"
    if "<|startfocus|>" not in code_snippet and "<|endfocus|>" in code_snippet:
        code_snippet = "<|startfocus|>\n"+code_snippet
        
    data_dic['tokenized_code_snippet'] = extreme_tokenization(code_snippet)#data_dic['code_snippet'])
    data_dic['tokenized_target'] = extreme_tokenization(data_dic['target'])
    data_dic['tokenized_comment'] = extreme_tokenization(data_dic['message'])
    #print("specials   ###", sp_start_func, sp_end_func)
   
    
    #print(code_snippet)
    #print("#################")
    #print(data_dic)
    #print(source)
    #data_dic['actual_line_number'] = data['line_number']
    data_dic['base_code_line_number'] = data['line_number']
    data_dic['base_patch_number'] = data['base_patch_number']
    data_dic['changed_patch_number'] = data['changed_patch_number']
    data_dic['code_file_name'] = data['file_name']
    data_dic['comment_id'] = data['comment_id']
    data_dic['message'] = data['message']
    data_dic['line_change'] = data['line_change']
    data_dic['written_on'] = data['written_on']
    data_dic['project_name'] = data['project_name']
    if "<|startfocus|>" in code_snippet and "<|endfocus|>" in code_snippet:
        unique_data_processed.append(data_dic)
    if(len(unique_data_processed)%100==0):
        print("data size = ", len(unique_data_processed))
    '''
    print(idx)
    if(idx%1000==0):
        print(idx)
        print(c)
        pprint(data_dic)
    '''
'''
{'actual_line_number': 71, 'base_code_line_number': 73, 'base_patch_number': 3, 'changed_code': '    /*', 'changed_patch_number': 7, 'code_file_name': 'android_3478', 'comment_id': '3745e284_1e49cdaa', 'line_change': 2, 'message': '{@link android.icu.impl.OlsonTimeZone} ?', 'previous_code': '     /*'}
'''
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# "\n{'actual_line_number': 71, 'base_code_line_number': 73, 'base_patch_number': 3, 'changed_code': '    /*', 'changed_patch_number': 7, 'code_file_name': 'android_3478', 'comment_id': '3745e284_1e49cdaa', 'line_change': 2, 'message': '{@link android.icu.impl.OlsonTimeZone} ?', 'previous_code': '     /*'}\n"

# %%
import sys,json
import csv
import _thread
import threading
import time
from time import sleep
import pandas as pd

import json
def getJsonData(JsonFile):
    with open(JsonFile, encoding="utf8") as f:
        data = json.load(f)
    return data
def read(path):
    return open(path, 'r', encoding = 'utf-8').read()


BASE="E:/codes/"
unique_data = getJsonData('E:\\unified_with_date.json')
print(len(unique_data))

file_size = 100884
batch_size = 100
  
def translate(file_no):
    for x in range(file_no*batch_size,min(file_size,(file_no+1)*batch_size)):
        process(unique_data[x])
    
thrds = []
for i in range(0,(file_size//batch_size)+1):
    #translate(str(i))
    try:
        '''
        if(False):
           #_thread.start_new_thread(translate, (str(i)))
           print(str(i))
           my = M()
           td =  threading.Thread(target=M.t, args = (str(i),))
           td.start()
           thrds.append(td)
        else:
        '''
        print("processing file = ", str(i))
        td =  threading.Thread(target=translate, args = (i,))
        td.start()
        thrds.append(td)
       
    except:
        print("Error: unable to start thread")
    

for td in thrds:
    td.join()
# Out:
# 100884
# processing file =  0
# processing file =  1
# processing file =  2
# processing file =  3
# processing file =  4
# processing file =  5
# processing file =  6
# processing file =  7
# processing file =  8
# processing file =  9
# processing file =  10
# processing file =  11
# processing file =  12
# processing file =  13
# processing file =  14
# processing file =  15
# processing file =  16
# processing file =  17
# processing file =  18
# processing file =  19
# processing file =  20
# processing file =  21
# processing file =  22
# processing file =  23
# processing file =  24
# processing file =  25
# processing file =  26
# processing file =  27
# processing file =  28
# processing file =  29
# processing file =  30
# processing file =  31
# processing file =  32
# processing file =  33
# processing file =  34
# processing file =  35
# processing file =  36
# processing file =  37
# processing file =  38
# data size =  processing file =  100
# 39
# processing file =  40
# processing file =  41
# processing file =  42
# processing file =  43
# processing file =  44
# processing file =  45
# processing file =  46
# processing file =  47
# processing file =  48
# processing file =  49
# processing file =  50
# processing file =  51
# processing file =  52
# processing file =  53
# processing file =  54
# processing file =  55
# processing file =  56
# processing file =  57
# processing file =  58
# processing file =  59
# processing file =  60
# processing file =  61
# processing file =  62
# processing file =  63
# data size =  processing file = 200
# 64
# processing file =  65
# processing file =  66
# processing file =  67
# processing file =  68
# processing file =  69
# processing file =  data size =  70300
#
# processing file =  71
# processing file =  72
# processing file =  73
# processing file =  74
# processing file =  75
# processing file =  76
# processing file =  77
# processing file =  78data size =
#  processing file = 400
# 79
# processing file =  80
# processing file =  81
# processing file =  82
# processing file =  83
# data size = processing file =   50084
#
# processing file =  85
# processing file =  86
# processing file = data size =   60087
#
# processing file =  88
# processing file =  89
# processing file =  90
# processing file =  91
# processing file = data size =   92
# 700processing file =
#  93
# processing file =  94
# processing file =  95
# processing file =  96
# processing file =  97
# data size = processing file =   98800
#
# processing file =  99
# processing file =  100
# processing file =  101data size =
#  processing file = 900
#  102
# processing file =  103
# processing file =  104
# processing file =  105
# data size = processing file =  1000
# 106
# processing file =  107
# processing file =  108
# processing file = data size =   1091100
#
# processing file =  110
# processing file =  111
# processing file =  112
# processing file =  113
# data size =  processing file = 1200 114
#
# processing file =  115
# processing file =  116
# processing file =  117
# processing file =  118
# processing file =  data size =  119
# 1300processing file =
#  120
# processing file =  121
# processing file =  122
# data size =  processing file = 1400
#  123
# processing file =  124
# processing file =  125
# processing file =  126
# processing file =  127
# processing file =  data size =  128
# 1500processing file =
#  129
# processing file =  130
# processing file =  131
# processing file =  data size = 132
# 1600processing file =
#  133
# processing file =  134
# processing file =  135
# data size =  1700processing file =
# 136
# processing file =  137
# processing file =  138
# processing file =  139data size =
# 1800
# processing file =  140
# processing file =  141
# processing file =  data size = 142
# 1900processing file =
#  143
# processing file =  144
# data size =  processing file = 2000
# 145
# processing file =  146data size =
#  processing file = 2100
#  147
# processing file =  148
# processing file =  data size = 149
# 2200
# processing file =  150
# data size =  processing file =  2300151
#
# processing file =  152
# processing file =  data size = 153
# 2400processing file =
# 154
# processing file =  155
# processing file =  156data size =
#  2500
# processing file =  157
# processing file =  158data size = data size =
#   26002600processing file =
#
# 159
# processing file =  160data size =
# 2700
# processing file =  161
# processing file =  162
# processing file =  163data size =
#  2800processing file =
#  164
# processing file =  data size = 165
# 2900processing file =
#  166
# processing file =  167
# data size = data size =   processing file =  30003000168
#
#
# processing file = data size =   1693100
#
# processing file =  170
# processing file =  171
# processing file = data size =   1723200
#
# processing file =  173
# processing file =  174
# data size = processing file =  3300
# 175
# processing file =  data size = 176
#  3400processing file =
# 177
# processing file = data size =  178 3500
#
# processing file =  179
# data size =  processing file = 3600
# 180
# processing file =  181data size =
#  processing file = 3700
#  182
# processing file = data size =   1833800
#
# processing file =  184
# processing file = data size =  185
# 3900processing file =
# 186
# processing file =  data size = 187
# 4000processing file =
#  188data size =
# processing file =  4100189
#
# data size = processing file =   1904200
#
# processing file =  data size =  191
# 4300
# processing file =  192
# processing file = data size =   1934400
#
# processing file =  194
# data size =  processing file =  4500
# 195
# processing file =  196
# processing file =  data size =  1974600
#
# processing file =  data size =  198
# 4700
# processing file =  199
# processing file = data size =   200
# 4800processing file =
# 201
# processing file = data size =   2024900
#
# processing file =  203
# processing file =  data size =  204
# 5000
# processing file =  205
# processing file = data size =   5100206
#
# processing file =  207
# processing file = data size =   2085200
#
# processing file =  209
# data size = processing file =  5300
# 210
# processing file =  211data size =
#  5400processing file =
#  212
# data size =  processing file = 5500
# 213
# processing file =  214data size =
# 5600
# processing file =  215
# data size =  processing file = 5700 216
#
# processing file =  217
# processing file = data size =   5800218
#
# processing file =  219data size =
#  processing file = 5900 220
#
# processing file = data size =   2216000
#
# processing file =  222data size =
# 6100processing file =
# 223
# processing file = data size =   2246200
#
# processing file =  225
# processing file =  226data size =
# 6300processing file =
#  227
# processing file =  data size =  2286400
#
# processing file =  229
# processing file =  data size =  2306500
#
# processing file =  231
# processing file =  data size = 232 6600
# processing file =
#  233
# processing file = data size =   6700234
#
# processing file =  235
# data size =  processing file =  6800236
#
# processing file =  237data size =
# 6900processing file =
#  238
# data size = processing file =  7000
# 239
# processing file =  240
# processing file =  data size = 241
# 7100
# processing file =  242
# processing file = data size =  243 7200
#
# processing file =  244
# data size =  processing file = 7300
# 245
# processing file =  data size =  2467400
#
# processing file =  247
# processing file = data size =  248 7500
#
# processing file =  data size = 249
#  processing file = 7600
# 250
# data size =  processing file =  7700251
#
# processing file =  data size = 252 7800
#
# processing file =  253
# processing file = data size =   254
# 7900
# data size =  8000
# data size =  8100
# data size = processing file =   2558200
#
# processing file =  256data size =
# 8300processing file =
#  257
# data size = processing file =   8400258
#
# processing file =  data size = 259
#  8500
# processing file =  260data size =
#  8600processing file =
#  261
# data size = processing file =   8700262
#
# data size = processing file =   2638800
# processing file =
#  264
# data size =  8900processing file =
# 265
# data size = processing file =   9000266
#
# processing file =  267
# data size =  processing file =  9100268
#
# data size = processing file =   9200269
#
# processing file =  data size =  9300270
#
# processing file = data size =   2719400
#
# processing file =  272
# data size =  processing file = 9500
# 273
# data size = processing file =  9600 274
#
# processing file = data size =   275
# 9700
# processing file =  276data size =
# processing file =   9800277
#
# processing file = data size =   2789900
#
# processing file = data size =   10000279
#
# processing file = data size =   10100280
#
# processing file =  data size = 281
# processing file = 10200
#  data size =  28210300
#
# processing file =  283
# data size = processing file =   10400284
#
# processing file = data size =   28510500
#
# processing file = data size =   286
# 10600
# processing file = data size =   28710700
#
# processing file =  data size = 288
# 10800processing file =
# data size =  289
# 10900
# processing file =  data size = 290
# 11000processing file =
#  291data size =
#  processing file = 11100
# 292data size =
#  processing file = 11200
# 293
# data size =  11300
# processing file =  data size = 294 11400
# processing file =
# data size = 295
# 11500processing file =
#  296data size =
#  11600processing file =
# 297
# processing file = data size =  298
# 11700processing file =
#  data size = 299
#  11800processing file =
#  300data size =
#  processing file =  11900301
# data size =
#  12000processing file =
#  302data size =
#  12100processing file =
#  303
# data size =  processing file =  12200
# 304
# processing file = data size =   30512300
#
# data size =  12400processing file =
# 306
# data size =  processing file =  30712500
#
# processing file = data size =   30812600
#
# processing file = data size =  309
# 12700processing file =
# 310data size =
# processing file = 12800
#  data size =  311
# 12900processing file =
#  312
# data size =  processing file = 13000 313
#
# data size = processing file =   13100314
#
# processing file = data size =   31513200
#
# processing file =  data size =  31613300
#
# processing file = data size =   31713400
#
# processing file =  data size = 318 13500
#
# processing file =  data size = 319
# 13600processing file =
#  data size = 320
# 13700
# processing file = data size =   32113800
#
# processing file = data size =   13900322
#
# data size = processing file =  14000 323
#
# processing file =  data size = 324
# 14100processing file =
#  data size = 325 14200
# data size =  14300
# data size =  14400
# data size =  14500
# data size =  14600
# data size =  14700
#
# data size =  processing file = 14800
# 326
# data size =  processing file = 14900
# 327
# processing file = data size =   32815000
#
# processing file =  329data size =  15100
#
# processing file =  330
# processing file = data size =   331
# 15200
# data size = processing file =   33215300
#
# processing file =  data size = 333
# 15400
# processing file =  334data size =
# 15500processing file =
# 335
# data size = processing file =   15600336
#
# processing file =  337data size =
#  15700processing file =
#  data size = 338
#  processing file = 15800
# 339data size =
# processing file =   15900340
#
# data size =  16000processing file =
#  341
# data size =  processing file = 16100 342
#
# data size = processing file =   34316200
#
# data size = processing file =   34416300
#
# data size = processing file =   16400
# 345data size =
#  processing file = 16500
# 346data size =
# 16600processing file =
# data size =   34716700
#
# data size =  processing file = 16800
# data size = 348
# 16900
# processing file = data size =   34917000
#
# processing file = data size =   35017100
# data size =  processing file =
#  17200
# 351data size =
#  processing file = 17300 data size = 352
#
# 17400processing file =
#  data size = 353
# 17500processing file =
# data size =   35417600
#
# processing file = data size =   35517700
#
# processing file = data size =   35617800
#
# data size = processing file =   35717900
#
# data size =  processing file =  18000358
# data size =
#  18100processing file =
#  data size = 359
#  processing file = 18200
#  data size = 360
# 18300data size = processing file =
#   18400361
# data size =
# 18500processing file =  data size =
#  36218600
#
# data size = processing file =   18700
# 363data size =
# processing file =   18800364
#
# data size =  processing file = 18900
# 365data size =
#  19000processing file =
# data size =   366
# 19100processing file = data size =
#   36719200
#
# data size = processing file =   19300368
#
# data size = processing file =   19400369
#
# data size = processing file =   19500370
# data size =
#  processing file = 19600
# 371data size =
#  processing file = 19700
# data size = 372
# 19800processing file =
#  data size = 373
# 19900processing file =
#  data size =  37420000
#
# data size = processing file =   20100375
#
# processing file = data size =   37620200
#
# data size = processing file =   20300377
#
# data size = processing file =   20400378
#
# data size = processing file =   20500379
#
# data size = processing file =  20600
# data size = 380
# 20700processing file =
#  381data size =
#  processing file =  20800data size = 382
#
# 20900
# processing file =  data size = 383
# 21000processing file =
#  data size = 384
# 21100
# processing file = data size =   38521200
#
# data size = processing file =   21300386
#
# data size = data size = processing file =    2140038721400data size =
#
#
#  processing file =  21500388
#
# data size =  processing file = 21600
# data size = 389
# 21700processing file =
# data size =   39021800
#
# data size = processing file =   21900391
#
# data size =  processing file = 22000
# 392data size =
#  processing file = 22100 393
# data size =
#  processing file = 22200 394
# data size =
# 22300processing file =
#  395data size =
#  22400processing file =
# 396data size =
#  processing file = 22500
# data size = 397
# 22600processing file =
#  data size = 398
# 22700processing file =
# data size =  399 22800
# data size =
# processing file =  22900
# data size = 400
# 23000processing file =
#  data size = 401
# 23100
# data size =  23200
# data size =  23300
# data size =  23400
# data size =  23500
# data size =  23600
# data size =  23700
# data size =  23800
# data size =  23900
# data size =  24000data size =
#  24100
# data size =  24200
# data size =  24300data size =
#  24400
# data size =  24500data size =
#  24600
# data size =  24700
# data size =  24800
# data size =  24900
# data size =  25000
# data size =  25100
# data size =  25200
# data size =  25300
# data size =  25400
# data size =  25500
# data size =  25600
# data size =  25700
# data size =  25800
# data size =  25900
# data size =  26000
# data size =  26100
# data size =  26200
# data size =  26300processing file =
# 402
# processing file = data size =  403 26400
#
# processing file =  data size = 404 26500
#
# processing file =  405
# data size = processing file =   26600406
#
# processing file =  data size = 407
#  processing file = 26700
# 408data size =
# processing file =   26800
# 409
# data size = processing file =  26900
#  410data size =
#  processing file =  27000411
# data size =
#  processing file = 27100
# 412data size =
#  processing file =  27200413
#
# processing file = data size =   414
# 27300
# processing file =  415
# data size =  processing file =  27400416
#
# processing file =  data size = 417
# processing file = 27500
# 418data size =
# 27600
# processing file =  419
# data size = processing file =   42027700
#
# data size =  processing file = 27800
#  421
# processing file =  data size =  42227900
#
# processing file =  data size = 423
# 28000
# processing file =  data size = 424
#  28100processing file =
#  data size = 425
# 28200processing file =
# data size =  426 28300
#
# processing file =  data size = 427
# 28400processing file =
#  data size = 428
#  processing file = 28500
# 429data size =
#  processing file = 28600
#  data size = 430 28700
#
# processing file =  data size = 431
# 28800processing file =
# data size =   43228900
# data size =
# processing file =   43329000
#
# data size = processing file =   434
# 29100
# processing file =  435
# processing file = data size =   29200
# 436
# processing file =  437data size =
# processing file = 29300
# 438data size =
#  29400processing file =
#  data size = 439
# 29500processing file =
# 440data size =
#  processing file = 29600
# 441data size =
#  processing file = 29700
# 442data size =
#  processing file = 29800
# 443data size =
#  processing file = 29900
# data size = data size =    44430000
# 30000
# processing file =
#  data size = 445
# processing file = 30100
# data size = 446
# processing file = 30200 data size =
#  44730300
# processing file =
# data size =   44830400
#
# processing file = data size =   30500449
#
# data size = processing file =   30600450
# data size =
#  30700processing file =
#  451data size =
#  processing file = 30800
# data size = 452 30900
#
# processing file =  data size = 453
# 31000processing file =
#  454data size =
# processing file = 31100
# 455
# data size =  processing file = 31200
# 456
# data size =  processing file = 31300
# 457
# data size = processing file =   31400458
#
# processing file =  459data size =
# 31500
# processing file =  data size = 460
#  31600processing file =
#  461data size =
#  31700processing file =
# 462data size =
# 31800processing file =
# 463data size =
# processing file =   31900
# 464
# data size =  processing file =  32000
# 465
# data size = processing file =   32100
# 466
# data size = processing file =  32200 467
#
# processing file = data size =   46832300
#
# processing file =  data size = 469
# 32400
# processing file = data size =   32500470
#
# processing file =  471data size =
#  32600processing file =
#  472data size =
# 32700processing file =
#  473
# data size = processing file =   47432800
#
# processing file =  data size =  32900
# data size =  33000
# data size =  33100
# 475
# data size = processing file =   33200
# 476
# processing file = data size =  477
# 33300
# processing file =  data size = 478 33400
#
# processing file =  data size = 479
# 33500processing file =
#  480data size =
# processing file = 33600
# 481data size =
# processing file = 33700
# 482data size =
# processing file =   48333800
#
# processing file = data size =  484
# 33900processing file =
#  485data size =
#  processing file = 34000
# 486data size =
# processing file = 34100
# 487
# data size =  processing file =  34200488data size =
#
# 34300
# processing file =  data size = 489
# 34400processing file =
#  data size =  490
# 34500
# processing file =  data size = 491
#  34600processing file =
#  492
# data size = processing file =   34700
# 493
# data size = processing file =   34800494
#
# data size = processing file =   34900495
#
# data size = processing file =   49635000
#
# processing file = data size =   49735100
#
# processing file = data size =  498 35200
#
# processing file =  data size = 499
#  35300processing file =
# 500
# processing file = data size =   501
# 35400
# processing file =  data size =  50235500
#
# processing file =  data size = 503
# 35600processing file =
#  504
# data size =  processing file = 35700
# 505data size =
#  processing file =  35800
# 506
# processing file = data size =   50735900
#
# processing file =  508
# data size =  processing file = 36000
# 509
# processing file = data size =  510
# 36100
# processing file =  data size = 511 36200
#
# processing file =  data size = 512 36300
#
# processing file =  513data size =
#  36400processing file =
# 514
# data size = processing file =   36500515data size =
#
#  processing file = 36600 516data size =
#
# 36700
# processing file =  data size = 517 36800
#
# data size =  processing file =  36900
# 518
# data size = processing file =  519 37000
# processing file =
#  520data size =
#  37100processing file =
#  521
# data size =  processing file = 37200
#  522
# data size = processing file =  37300
# 523
# processing file = data size =   37400524
#
# processing file =  data size = 525
# processing file =  37500
# 526
# data size = processing file =   37600527
#
# processing file =  data size = 528
# 37700processing file =
# 529
# data size = processing file =   37800
# 530
# processing file =  531
# processing file = data size =  532
#  37900processing file =
# data size = 533 38000
#
# processing file =  534data size =
#  processing file = 38100
#  535
# data size =  processing file = 38200
# 536data size =
#  38300processing file =
#  537
# data size = processing file =   53838400
#
# data size = processing file =   38500539
#
# processing file = data size =   38600540
#
# processing file = data size =   541
# 38700
# processing file =  542data size =
# 38800processing file =
# 543
# processing file = data size =   544
# 38900processing file =
#  data size = 545
# 39000
# processing file =  546data size =
# 39100processing file =
# 547
# data size = processing file =  39200 548
#
# processing file =  549
# data size =  processing file = 39300
# 550
# data size =  processing file =  55139400
#
# processing file = data size =  552
# 39500
# processing file =  data size = 553
#  39600processing file =
#  554
# processing file = data size =   39700
# 555
# processing file =  data size =  39800556
#
# processing file =  557
# data size = processing file =  39900 558
#
# processing file =  data size = 559 40000
#
# processing file =  560
# data size = processing file =  40100 561
#
# processing file =  562
# data size =  processing file =  40200563
#
# data size =  processing file = 40300
#  564
# processing file =  565data size =
# 40400processing file =
# 566
# data size = processing file =   56740500
#
# processing file =  data size = 568
# 40600processing file =
#  data size =  569
# 40700processing file =
# 570
# data size = processing file =  40800
# 571
# data size = processing file =  40900
# 572
# data size = processing file =   41000573
#
# data size = processing file =   41100574
#
# data size = processing file =   57541200
#
# data size = processing file =   576
# 41300
# processing file = data size =   57741400
#
# processing file =  578data size =
# processing file = 41500
# 579
# processing file =  data size = 580 41600
#
# processing file =  581
# data size =  processing file = 41700
# 582
# processing file =  583data size =
#  41800processing file =
#  584
# data size =  processing file = 41900
# 585
# processing file = data size =   58642000
#
# processing file = data size =   58742100
#
# processing file =  data size = 588
# 42200processing file =
#  589data size =
#  42300processing file =
# 590data size =
#  processing file = 42400
# 591
# processing file = data size =   59242500
#
# processing file = data size =   59342600
# processing file =
#  594data size =
#  processing file = 42700
# 595data size =
#  processing file =  42800596
#
# processing file = data size =   42900597
#
# processing file = data size =   43000
# 598
# processing file =  data size = 599 43100
#
# processing file =  600
# processing file = data size =   60143200
#
# processing file = data size =   60243300
#
# processing file =  data size = 603
# 43400processing file =
#  data size =  604
# 43500
# processing file =  605data size =
#  processing file = 43600
# 606
# processing file = data size =   60743700
#
# processing file = data size =   60843800
#
# processing file = data size =   43900609
#
# processing file =  data size = 610
# 44000
# processing file =  611data size =
# 44100processing file =
#  612
# data size =  processing file = 44200
#  613
# data size = processing file =   44300614
#
# processing file = data size =   615
# 44400
# processing file = data size =  616
# 44500
# processing file =  617
# data size = processing file =   44600
# 618
# processing file = data size =   61944700
#
# processing file =  data size =  620
# 44800
# processing file =  621data size =
#  44900processing file =
#  622
# data size = processing file =   45000623
#
# processing file = data size =   45100624
#
# processing file = data size =   45200625
#
# processing file =  data size = 626
# 45300
# processing file =  data size = 627
#  45400processing file =
#  628data size =
#  processing file = 45500
# 629data size =
# processing file = 45600 630
# data size =
#  45700processing file =
# 631
# data size =  processing file = 45800
# 632
# data size =  processing file =  45900633
#
# processing file =  data size = 634
# 46000
# processing file =  635
# data size = processing file =   46100636
#
# data size = processing file =   46200637
#
# processing file =  data size = 638
# 46300
# processing file =  data size = 639
# 46400processing file =
#  data size = 640
#  processing file = 46500
# data size = 641
# processing file = 46600
#  642
# data size =  processing file =  46700643
#
# data size = processing file =   46800644
#
# data size = processing file =   46900645
#
# data size = processing file =   64647000
#
# processing file = data size =   647
# 47100
# processing file = data size =   64847200
#
# processing file =  data size = 649 47300
#
# processing file =  650data size =
#  47400processing file =
#  651
# processing file =  652
# data size =  processing file = 47500 653
#
# processing file =  654
# data size = processing file =   65547600
#
# processing file =  data size =  656
# 47700processing file =
#  data size =  65747800
#
# processing file =  658
# data size = processing file =   65947900
#
# processing file =  data size = 660
# 48000
# processing file =  661
# data size =  processing file =  48100662
#
# processing file =  data size =  48200663
#
# processing file =  664
# processing file = data size =   665
# 48300
# processing file =  666
# processing file =  data size =  667
# 48400processing file =
#  668
# data size =  processing file =  48500
# 669
# processing file =  data size =  67048600
#
# processing file =  data size = 671
# processing file = 48700
#  672data size =
#  48800processing file =
# 673data size =
#  processing file = 48900 674
#
# data size =  processing file = 49000
# data size = 675
# 49100
# processing file =  data size = 676
# 49200processing file =
#  data size = 677
#  processing file =  49300678
#
# data size =  processing file =  49400679
#
# processing file =  680
# data size = processing file =   49500681
#
# processing file = data size =   68249600
#
# processing file =  683
# data size = processing file =   68449700
#
# data size =  49800
# processing file =  data size =  68549900
#
# processing file =  686data size =
# processing file = 50000
#  687
# processing file = data size =   50100688
#
# processing file =  data size =  50200689
#
# processing file =  690
# data size = processing file =  691
# 50300processing file =  692
#
# data size =  processing file = 50400
# 693
# data size = processing file =   50500694
#
# data size = processing file =   50600695
#
# data size = processing file =   50700696
#
# data size = processing file =   50800697
#
# data size = processing file =  50900
# 698
# data size = processing file =   51000699
#
# data size = processing file =   51100700
# data size =
#  processing file = 51200
# data size = 701
# processing file = 51300
# data size =   702
# 51400processing file = data size =
#   70351500
# data size =
# processing file =   70451600
#
# processing file = data size =   51700705
#
# data size = processing file =   51800706
#
# processing file = data size =  707
# 51900data size =
# processing file = 52000
# 708
# processing file =  data size = 709
# 52100processing file =
#  710data size =
# 52200processing file =
#  711
# data size =  processing file = 52300
# 712data size =
#  processing file = 52400
# 713
# data size =  processing file =  52500714
#
# processing file = data size =   52600715
#
# processing file =  716data size =
# 52700processing file =
#  717data size =
#  52800processing file =
#  718data size =
# 52900processing file =
#  719data size =
#  processing file = 53000
# 720
# processing file = data size =   72153100
#
# processing file = data size =   53200
# 722
# processing file =  data size = 723
# 53300processing file =
#  data size =  72453400
#
# processing file =  data size = 725
# processing file =   53500
# 726
# processing file = data size =   72753600
#
# processing file =  728
# processing file =  data size =  729
# 53700
# processing file = data size =  730
# processing file = 53800
#  731data size =
# 53900processing file =
#  data size = 732
# 54000
# processing file =  data size = 733
# 54100
# processing file = data size =   734
# 54200processing file =
# data size = 735 54300
#
# processing file =  736
# data size =  processing file = 54400 737
#
# processing file = data size =   73854500
#
# processing file = data size =   73954600
#
# processing file = data size =   54700740
#
# processing file = data size =   74154800
#
# processing file = data size =   54900
# 742
# data size =  processing file = 55000
#  743
# data size = processing file =   74455100
#
# data size = processing file =   74555200
#
# processing file = data size =   55300746
#
# processing file =  data size = 747
#  55400processing file =
#  data size = 748 55500
#
# processing file = data size =  749 55600
#
# processing file =  750
# data size =  processing file = 55700
# 751data size =
# processing file =  55800
# 752
# processing file = data size =   753
# 55900
# processing file = data size =  754
# 56000processing file =  data size =
# 755 56100
#
# processing file = data size =  756 56200
#
# processing file = data size =   75756300
# processing file =  data size =
# 56400758
#
# processing file =  759data size =
# processing file =   76056500
# data size =
# 56600processing file =
#  761
# data size =  processing file = 56700
# 762
# data size = processing file =   763
# 56800
# data size = processing file =   56900764data size =
#
#  processing file = 57000
# 765data size =
#  processing file = 57100 data size = 766
#
#  57200processing file =  data size =
# 767
# 57300
# processing file = data size =   76857400
# data size =
# processing file =   57500769
#
# data size =  processing file = 57600
# 770data size =
# 57700processing file =
# data size =   77157800
#
# processing file = data size =   77257900
#
# processing file = data size =   77358000
#
# processing file = data size =   774
# 58100processing file =
# data size =  77558200
#
# data size = processing file =   58300776
#
# processing file = data size =   77758400
#
# processing file = data size =   77858500
#
# processing file = data size =   77958600
#
# data size = processing file =   58700780
#
# data size = processing file =   58800781
# data size =
# processing file =   78258900
# data size =
#  processing file = 59000 783
#
# data size =  processing file =  59100784data size =
#
#  59200processing file =
# data size =   78559300
#
# data size = processing file =   59400786
#
# data size =  processing file =  59500787
#
# data size = processing file =   59600788
#
# data size =  59700processing file =
#  data size =  78959800
# processing file =
# data size =   79059900
#
# processing file = data size =   79160000
#
# data size = processing file =  60100
# 792data size =
#  processing file = 60200
# data size = 793
# 60300processing file =
# data size =   79460400
#
# processing file = data size =   79560500
#
# data size = processing file =  60600 796
#
# data size = processing file =  60700 797
# data size =
#  processing file = 60800
#  data size = 798
# 60900processing file =
#  data size = 799
# 61000processing file =
#  data size = 800
# 61100processing file =
# data size = 801
# 61200processing file =
#  data size =  80261300
#
# processing file = data size =   80361400
#
# processing file = data size =   61500804
#
# data size = processing file =   61600
# 805
# data size = processing file =   61700806
# data size =
#  processing file = 61800 807
# data size =
# 61900processing file =
#  808
# processing file = data size =  809 62000
#
# processing file = data size =   810
# 62100processing file =
#  data size = 811
# processing file = 62200 data size =
#  81262300
#
# data size = processing file =  62400
# 813
# data size =  processing file = 62500
#  814data size =
#  processing file = 62600 815
#
# data size = processing file =   62700816data size =
#
#  processing file = 62800data size =
#   817
# 62900processing file =
#  data size = 818
# 63000processing file =
# data size =   81963100
# data size =
# processing file =   63200
# data size = 820
# 63300
# processing file =  data size = 821
# 63400
# processing file = data size =   822
# 63500processing file =
# data size =  823
# 63600data size = processing file =
#   63700824
# data size =
#  processing file = 63800
# 825data size =
#  processing file = 63900
# data size = 826
# 64000processing file =
#  data size =  827
# 64100data size =
# processing file =   64200828
# data size =
#  processing file = 64300
# 829data size =
#  processing file = 64400
#  830data size =
#  processing file = 64500
# data size = 831
#  processing file = 64600
#  data size = 832 64700
# data size =  64800data size =
#  64900
# data size =  65000
# data size =  65100
# data size =  65200
# data size =  65300
# data size =  65400
# data size =  65500
# data size =  65600
# data size =
#  65700processing file =
#  833
# data size = processing file =  834 65800
#
# processing file = data size =   65900835
#
# processing file = data size =   66000836
#
# data size =  processing file = 66100 837
#
# data size = processing file =   66200838
#
# data size = processing file =   66300839data size =
#
#  processing file = 66400 data size =
#  84066500
#
# processing file = data size =   66600841
#
# data size =  processing file = 66700
# 842data size =
#  66800processing file =
# data size =   84366900
#
# processing file = data size =   84467000
#
# data size = processing file =   67100845
#
# data size = processing file =  67200
# 846
# data size =  processing file = 67300
# data size = 847
# 67400
# processing file =  data size =  84867500
# data size =
# processing file =   67600849
# data size =
#  processing file = 67700
#  data size = 850
#  processing file = 67800
# 851data size =
#  processing file = 67900 data size =
# 852
# 68000processing file = data size =
#   85368100
# processing file =
# data size =   85468200
#
# data size = processing file =   68300855
#
# data size = processing file =   68400
# 856
# data size = processing file =   68500857
#
# data size = processing file =   68600
# 858data size =
#  68700processing file =
#  859data size =
#  68800processing file =
#  data size = 860
# 68900
# processing file =  861
# processing file = data size =   86269000
#
# data size = processing file =   86369100
#
# processing file = data size =   86469200
#
# data size = processing file =   69300865
#
# processing file = data size =   86669400
#
# processing file = data size = data size =   867
# 6950069500processing file =
# data size =
#  868
# 69600
# data size = processing file =   69700
# 869
# data size =  69800processing file =  870
#
# data size = processing file =   69900871
#
# data size =  processing file = 70000
# 872
# data size =  processing file = 70100 873
# data size =
#  processing file = 70200
#  874
# processing file = data size =  875 70300
#
# processing file =  data size = 876 70400
#
# processing file =  data size = 877
# 70500processing file =
#  878data size =
# processing file =   70600879
#
# data size = processing file =   70700880
#
# data size =  processing file =  70800
# 881data size =
#  processing file = 70900 data size =
#  88271000
#
# processing file = data size =   88371100
#
# processing file = data size =   71200884
# data size =
# processing file =   71300885
# data size =
#  71400processing file =
#  data size = 886
# 71500processing file =
# data size =   88771600
#
# processing file = data size =   71700888
#
# data size = processing file =  71800
#  889
# data size =  processing file =  71900
# 890
# data size = processing file =   89172000
#
# processing file = data size =   72100892
#
# processing file =  data size = 893
# 72200processing file =
#  894data size =
#  72300processing file =
# 895
# data size = processing file =  72400 896
# data size =
#  processing file = 72500
# 897
# data size = processing file =   72600898
#
# processing file = data size =  899
#  processing file = 72700
#  data size = 900
# 72800processing file =
#  901
# data size =  72900processing file =
#  902
# data size =  processing file = 73000
# 903
# processing file =  data size =  90473100
#
# processing file = data size =  73200
# data size =  73300
# data size =  73400
#  905
# data size = processing file =   90673500
#
# processing file =  907data size =
#  processing file = 73600
# 908data size =
# 73700processing file =
# 909
# processing file = data size =   73800910
#
# processing file = data size =   911
# 73900processing file = data size =
#   91274000
#
# processing file =  data size =  913
# 74100processing file =
#  data size = 914
# 74200
# processing file = data size =   74300915
#
# processing file = data size =   91674400
# data size = processing file =
#   91774500
#
# processing file = data size =   91874600
#
# data size = processing file =  919
# 74700processing file = data size =
#  92074800
#
# processing file = data size =   92174900
#
# processing file =  data size = 922
#  processing file = 75000
#  923data size =
#  processing file = 75100
# 924data size =
#  processing file =  75200
# 925
# data size =  processing file = 75300
# 926
# data size = processing file =  75400
# 927
# processing file =  data size = 928
# 75500processing file =
#  929
# processing file = data size =   75600
# 930
# processing file =  931data size =
#  75700processing file =
# 932
# data size = processing file =   93375800
#
# data size = processing file =   93475900
#
# data size = processing file =   76000935
#
# data size = processing file =   93676100
# data size =
# processing file =   76200937
# data size =
#  processing file = 76300
# 938data size =
# 76400processing file =
#  939data size =
#  76500processing file =
#  data size = 940
# 76600processing file =
#  data size = 941
# 76700processing file =
#  data size = 942
# 76800
# processing file =  data size = 943
# 76900
# processing file = data size =   77000944
#
# data size = processing file =   94577100
#
# data size = processing file =   94677200
#
# data size =  77300processing file =
#  947data size =
# 77400processing file =
#  data size = 948
#  77500processing file =
# 949data size =
#  processing file = 77600
# data size = 950
# 77700
# processing file = data size =   95177800
#
# processing file = data size =   95277900
#
# data size =  processing file = 78000
#  953data size =
#  processing file = 78100
# 954
# data size = processing file =   95578200
#
# data size = processing file =  78300
# 956
# processing file = data size =   957
# 78400
# processing file =  data size =  95878500
#
# processing file =  959
# data size =  processing file = 78600
# 960
# data size = processing file =   78700
# 961data size =
#  78800processing file =
# 962data size =
#  78900processing file =
#  data size = 963
#  processing file = 79000
# 964data size =
#  processing file = 79100data size =   965
#
# 79200processing file =
# 966data size =
# 79300processing file =
#  data size = 967
# 79400processing file =
#  968data size =
#  processing file =  79500969
# data size =
#  processing file = 79600
# 970
# data size =  processing file = 79700
#  971
# data size = processing file =   79800972
#
# data size =  processing file = 79900
#  973
# data size = processing file =   80000974
#
# processing file = data size =  975
#  80100processing file =
#  976
# data size = processing file =   97780200
#
# processing file = data size =  80300
# data size =  80400
# data size =  80500
# data size =  80600
#  978data size =
# processing file =   80700
# 979
# processing file =  data size = 980
#  80800
# processing file =  data size = 981
# 80900processing file =
#  982
# processing file =  data size = 983
#  81000processing file =
# 984data size =
# 81100
# processing file =  985data size =
#  processing file = 81200
# 986data size =
# 81300
# processing file =  987data size =
#  81400processing file =
#  988data size =
#  81500processing file =
#  989data size =
#  processing file = 81600
# data size =   99081700
#
# processing file =  data size = 991
#  processing file = 81800
# 992data size =
#  processing file = 81900
# 993data size =
#  processing file =  82000
# 994
# data size = processing file =   82100995
# data size =
#  processing file = 82200
# 996data size =
# processing file =  82300
# 997
# data size = processing file =  82400
# 998data size =
# processing file =   82500999
#
# processing file =  data size = 1000
# 82600
# processing file =  1001data size =
#  processing file = 82700 1002
#
# data size = processing file =  82800
# 1003data size =
#  processing file = 82900
# data size = 1004
# 83000processing file =
#  data size = 1005 83100
#
# processing file = data size =   832001006
# processing file =
# data size =   833001007
#
# data size = processing file =   834001008
#
# data size =  83500
# data size =  83600
# data size =  83700
# data size =  83800
# data size =  83900
# data size =  84000
# data size =  84100
# data size =  84200
# data size =  84300
# data size =  84400
# data size =  84500
# data size =  84600
# data size =  84700
# data size = data size =   8480084800
#
# data size =  84900
# data size =  85000
# data size =  85100
# data size =  85200
# data size =  85300
# data size =  85400
# data size =  85500
# data size =  85600
# data size =  85700
# data size =  85800
# data size =  85900
# data size =  86000
# data size =  86100
# data size =  86200
# data size =  86300
# data size =  86400
# data size =  86500
# data size =  86600
# data size =  86700
# data size =  86800
# data size =  86900
# data size =  87000
# data size =  87100
# data size =  87200
# data size =  87300
# data size =  87400
# data size =  87500
# data size =  87600
# data size =  87700
# data size =  87800
# data size =  87900
# data size =  88000
# data size =  88100
# data size =  88200
# data size =  88300
# data size =  88400
# data size =  88500
# data size =  88600
# data size =  88700
# data size =  88800
# data size =  88900
# data size =  89000
# data size =  89100
# data size =  89200
# data size =  89300
# data size =  89400
# data size =  89500
# data size =  89600
# data size =  89700
# data size =  89800
# data size =  89900
# data size =  90000
# data size =  90100
# data size =  90200
# data size =  90300
# data size =  90400
# data size =  90500
# data size =  90600
# data size =  90700
# data size =  90800
# data size =  90900
# data size =  91000
# data size =  91100
# data size =  91200
# data size =  91300
# data size =  91400
# data size =  91500
# data size =  91600
# data size =  91700
# data size =  91800
# data size =  91900
# data size =  92000
# data size =  92100
# data size =  92200
# data size =  92300
# data size =  92400
# data size =  92500
# data size =  92600
# data size =  92700
# data size =  92800
# data size =  92900
# data size =  93000
# data size =  93100
# data size =  93200
# data size =  93300
# data size =  93400
# data size =  93500
# data size =  93600
# data size =  93700
# data size =  93800
# data size =  93900
# data size =  94000
# data size =  94100
# data size =  94200
# data size =  94300
# data size =  94400
# data size =  94500
# data size =  94600
# data size =  94700
# data size =  94800
# data size =  94900
# data size =  95000
# data size =  95100
# data size =  95200
# data size =  95300
# data size =  95400
# data size =  95500
# data size =  95600
# data size =  95700
# data size =  95800
# data size =  95900
# data size =  96000
# data size =  96100
# data size =  96200
# data size =  96300
# data size =  96400
# data size =  96500
# data size =  96600

# %%
with open('unique_data_processed_with_Date_multithread.json', 'w', encoding="utf8") as f:  # writing JSON object
    json.dump(unique_data_processed, f)

# %%
len(unique_data_processed)
# Out:
# 96684

# %%
unique_data_processed[0].keys()
# Out:
# dict_keys(['message', 'comment_id', 'target', 'source', 'code_snippet', 'prime_var_dic', 'class_list', 'func_list', 'tokenized_code_snippet', 'tokenized_target', 'tokenized_comment', 'base_code_line_number', 'base_patch_number', 'changed_patch_number', 'code_file_name', 'line_change', 'written_on', 'project_name'])

# %%
import json
def getJsonData(JsonFile):
    with open(JsonFile, encoding="utf8") as f:
        data = json.load(f)
    return data
def read(path):
    return open(path, 'r', encoding = 'utf-8').read()


BASE="E:/codes/"
unique_data = getJsonData('E:\\unified_with_date.json')
print(len(unique_data))
