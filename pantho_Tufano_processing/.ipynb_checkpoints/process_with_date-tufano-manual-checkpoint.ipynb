# %%
#unified_with_dat

# %%
from nltk.tokenize import MWETokenizer, TweetTokenizer, WordPunctTokenizer 
from nltk.tokenize import word_tokenize
import re

VALUES = ['>>>=', '>>=', '<<=',  '%=', '^=', '|=', '&=', '/=',
                  '*=', '-=', '+=', '<<', '--', '++', '||', '&&', '!=',
                  '>=', '<=', '==', '%', '^', '|', '&', '/', '*', '-',
                  '+', ':', '?', '~', '!', '<', '>', '=', '...', '->', '::', '\\', '\\\\', '\*', '*\\', '\\\\\\']
INFIX = ['||', '&&', '|', '^', '&', '==', '!=', '<', '>', '<=', '>=', 
             '<<', '>>', '>>>', '+', '-', '*', '/', '%']
PREFIX = ['++', '--', '!', '~', '+', '-']
POSTFIX = ['++', '--']
ASSIGNMENT = ['=', '+=', '-=', '*=', '/=', '&=', '|=', '^=', '%=', '<<=', '>>=', '>>>=']
LAMBDA = ['->']
COMMENT = ['//', '/*', '*/']
METHOD_REFERENCE = ['::']

WHITESPACE_DICT = {"                ":'<|16-s|>', 
                   "            ":'<|12-s|>', 
                   "        ":'<|8-s|>', 
                   "    ":'<|4-s|>', 
                   "  ":'<|2-s|>', " ":'<|s|>',
                   "\t\t\t\t":'<|4-t|>',"\t\t\t":'<|3-t|>',"\t\t":'<|2-t|>',"\t":'<|t|>',"\n":'<|nl|>'}

WHITESPACES = [WHITESPACE_DICT[x] for x in WHITESPACE_DICT]

REVERSE_WHITESPACE_DICT = {}
for key in WHITESPACE_DICT:
    value = WHITESPACE_DICT[key]
    REVERSE_WHITESPACE_DICT[value] = key

CUSTOM_TOKEN = ["<|startcode|>", "<|endcode|>", "<|startfocus|>", "<|endfocus|>", "<|startcomment|>", "<|endcomment|>", 
                   "<|stringliteral|>", "<|singlelinecomment|>", "<|multilinecomment|>", "<|del|>"]

values = list(set(INFIX+PREFIX+POSTFIX+ASSIGNMENT+LAMBDA+COMMENT+METHOD_REFERENCE))
token_phrases = []
word_punct_tokenizer = WordPunctTokenizer()
for tok in CUSTOM_TOKEN+WHITESPACES:
    temp = tuple(word_punct_tokenizer.tokenize(tok))
    token_phrases.append(temp)
for w in values:
    temp = tuple(MWETokenizer().tokenize(w))
    if len(temp) > 1:
        token_phrases.append(temp)

word_punct_tokenizer = WordPunctTokenizer()
tweet_tokenizer = TweetTokenizer()
mwe_tokenizer = MWETokenizer(token_phrases, separator="")

def state(c):
    n = ord(c)
    if n>=97 and n<=122: # lower case
        return 1
    elif n>=65 and n<=90: # upper case
        return 2
    elif n>=48 and n<=57: # numbers
        return 3
    elif c.isspace(): # whitespaces
        return 4
    elif c in ['_', '$']: 
        return 5
    elif n < 128:
        return 6
    else:
        return 7

def space_up(s):
    if s is None or s == "":
        return ""
    new_s = s[0]
    for i in range(1,len(s)):
        prev_state = state(s[i-1])
        curr_state = state(s[i])
        if prev_state in [1,2] and curr_state in [3]:
            new_s += " "
        elif prev_state in [1] and curr_state in [2]:
            new_s += " "
        elif prev_state in [3] and curr_state in [1,2]:
            new_s += " "
        elif prev_state in [1,2,3] and curr_state in [5]:
            new_s += " "
        elif prev_state in [5] and curr_state in [1,2,3]:
            new_s += " "
        new_s+=s[i]
    return new_s

def white_space_tokenize(s):
    for x in WHITESPACE_DICT:
        s = s.replace(x, WHITESPACE_DICT[x])
    for key in REVERSE_WHITESPACE_DICT:
        #val = REVERSE_WHITESPACE_DICT[x]
        s = s.replace(key, " "+key+" ")
    return s

def extreme_tokenization(comment):
    comment = white_space_tokenize(comment)
    comment = space_up(comment)
    tokenized = tweet_tokenizer.tokenize(comment)
    tokenized = word_punct_tokenizer.tokenize(' '.join(tokenized))
    tokenized = mwe_tokenizer.tokenize(tokenized)
    tokenized_comment = ' '.join(tokenized)
    tokenized_comment = re.sub(r'[^\x00-\x7f]',r'', tokenized_comment)
    tokenized = tokenized_comment.split()
    return tokenized

def extreme_detokenization(tokens):
    s = ""
    for token in tokens:
        if token in REVERSE_WHITESPACE_DICT:
            s+= REVERSE_WHITESPACE_DICT[token]
        else:
            s+= token
    return s

# %%
import json
def getJsonData(JsonFile):
    with open(JsonFile, encoding="utf8") as f:
        data = json.load(f)
    return data
def read(path):
    return open(path, 'r', encoding = 'utf-8').read()


BASE="E:/codes/"
unique_data = getJsonData('unique_data_processed_with_Date_multithread.json')
print(unique_data[0])
# Out:
# {'message': 'One last occurrence - please change to acumos.org/...', 'comment_id': 'a068aa5b_b404cd60', 'target': '\t\t\t\t\t\t"https://cognita.atlassian.net/wiki/spaces/CW/pages/233610/Data+Model+for+Machine+Learning+Platform",\n\t\t\t\t\t\t"cds.someday@acumos.org"), // Contact\n\r\n', 'source': 'E:\\pantho_Tufano_processing\r\n\n * ===============LICENSE_START=======================================================\n * Acumos\n * ===================================================================================\n * Copyright (C) 2017 AT&T Intellectual Property & Tech Mahindra. All rights reserved.\n * ===================================================================================\n * This Acumos software file is distributed by AT&T and Tech Mahindra\n * under the Apache License, Version 2.0 (the "License");\n * you may not use this file except in compliance with the License.\n * You may obtain a copy of the License at\n *  \n *      http://www.apache.org/licenses/LICENSE-2.0\n *  \n * This file is distributed on an "AS IS" BASIS,\n * WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.\n * See the License for the specific language governing permissions and\n * limitations under the License.\n * ===============LICENSE_END=========================================================\n */\n\npackage org.acumos.cds.config;\n\nimport org.acumos.cds.CdsApplication;\nimport org.acumos.cds.controller.AbstractController;\nimport org.springframework.context.annotation.Bean;\nimport org.springframework.context.annotation.Configuration;\n\nimport springfox.documentation.builders.PathSelectors;\nimport springfox.documentation.builders.RequestHandlerSelectors;\nimport springfox.documentation.service.ApiInfo;\nimport springfox.documentation.service.Contact;\nimport springfox.documentation.spi.DocumentationType;\nimport springfox.documentation.spring.web.plugins.Docket;\nimport springfox.documentation.swagger2.annotations.EnableSwagger2;\n\n/**\n * http://www.baeldung.com/swagger-2-documentation-for-spring-rest-api\n */\n@Configuration\n@EnableSwagger2\npublic class SwaggerConfiguration {\n\t\n\t/**\n\t * @return new Docket\n\t */\n\t@Bean\n\tpublic Docket api() {\n\t\treturn new Docket(DocumentationType.SWAGGER_2).select() //\n\t\t\t\t.apis(RequestHandlerSelectors.basePackage(AbstractController.class.getPackage().getName())) //\n\t\t\t\t.paths(PathSelectors.any()) //\n\t\t\t\t.build() //\n\t\t\t\t.apiInfo(apiInfo());\n\t}\n\n\tprivate ApiInfo apiInfo() {\n\t\tfinal String version = CdsApplication.class.getPackage().getImplementationVersion();\n\t\treturn new ApiInfo("Acumos Common Data Service REST API", // title\n\t\t\t\t"Provides create, retrieve, update and delete (CRUD) services " //\n\t\t\t\t\t\t+ " for data about solutions, artifacts and users."//\n\t\t\t\t\t\t+ " All service endpoints require basic HTTP authentication.", // description\n\t\t\t\tversion == null ? "version not available" : version, // version\n\t\t\t\t"Terms of service", // TOS\n\t\t\t\tnew Contact("Acumos Data Model Team",\n<|startfocus|>\n\t\t\t\t\t\t"https://cognita.atlassian.net/wiki/spaces/CW/pages/233610/Data+Model+for+Machine+Learning+Platform",\n<|endfocus|>\n\t\t\t\t\t\t"cds.someday@acumos.org"), // Contact\n\t\t\t\t"License of API", // License\n\t\t\t\t"API license URL"); // License URL\n\t}\n}\n', 'code_snippet': '', 'prime_var_dic': {}, 'class_list': ['SwaggerConfiguration'], 'func_list': ['public Docket api()', 'private ApiInfo apiInfo()'], 'tokenized_code_snippet': ['<|t|>', 'private', '<|s|>', 'Api', 'Info', '<|s|>', 'api', 'Info', '(', ')', '<|s|>', '{', '<|nl|>', '<|2-t|>', 'final', '<|s|>', 'String', '<|s|>', 'version', '<|s|>', '=', '<|s|>', 'Cds', 'Application', '.', 'class', '.', 'get', 'Package', '(', ')', '.', 'get', 'Implementation', 'Version', '(', ');', '<|nl|>', '<|2-t|>', 'return', '<|s|>', 'new', '<|s|>', 'Api', 'Info', '(', '"', 'Acumos', '<|s|>', 'Common', '<|s|>', 'Data', '<|s|>', 'Service', '<|s|>', 'REST', '<|s|>', ...

# %%
from os import path
import json
import re
import subprocess
import nltk
from pprint import pprint
from nltk.tokenize import sent_tokenize, word_tokenize
from tqdm import tqdm
nltk.download('punkt')

def get_source_target(file1, file2, line_number, change_window_size=5):
    source_target = subprocess.check_output(['java', '-jar', 'ChangedLineF.jar', \
                                file1, file2, str(line_number), str(change_window_size)]).decode("utf-8")
    (source, target) = source_target.split("<|source-target-sep|>")
    return source, target

def end_scope(start_index, lines):
    #print(lines)
    counter = 0
    end_index = -1
    found = False
    for index in range(start_index, len(lines), 1):
        #print(lines[index])
        #print(counter)
        for char in lines[index]:
            if(char=='{'):
                counter+=1
                found = True
            elif(char == "}"):
                counter-=1
                found = True
            if(counter==0 and found):
                end_index = index
                break
        if end_index!=-1:
            break
    return end_index

unique_data_processed = []
MAX_NUM_TOKEN = 800
UP_TOKEN = MAX_NUM_TOKEN//2
c = 0
ec = 0
errors = []
tufano_less_then_50 = []
tufano_less_then_100 = []
vis_idx = []
#for idx, data in enumerate(unique_data):#[2428:2429]#[1000:1001]
for idx, data in enumerate(unique_data): #1:75
    #if(idx>3000):
    #    break
    if(idx%100==0):
        print(idx, len(tufano_less_then_50), len(tufano_less_then_100))
    if data['project_name']!='android_':
        continue
    code_file_name = data['code_file_name']
    base_patch_number = data['base_patch_number']
    changed_patch_number = data['changed_patch_number']
    main_code_path = BASE+code_file_name+'/'+str(base_patch_number)+'.java'
    changed_code_path = BASE+code_file_name+'/'+str(changed_patch_number)+'.java'
    line_no = data['base_code_line_number']
    main_code = read(main_code_path)
    changed_code = read(changed_code_path)
    sample = main_code
    message = data['message']
    comment_id = data['comment_id']
    #print("line no = ", line_no)
    sp_start_func= -1
    sp_end_func= len(sample.split('\n'))   
    funcs = re.findall(r"(public|protected|private|static|\s) +([\w\<\>\[\]]+\s+(\w+)) *\([^\)]*\) *(\{?|[^;])",sample)
    func_scopes = []
    lines = sample.split("\n")
    #print(funcs)
    #continue
    visited_func = set()
    for func in funcs:
        #print(func)
        if(func[-1]!= "{"):
            continue
        fc = list(func)
        fc = fc[-3]
        s = "".join(fc)
        s = s.strip()
        found = False
        for index in range(0, len(lines), 1):
            if s in lines[index]:
                start_func = index
                end_func = end_scope(index, lines)
                func_scopes.append((start_func,end_func))
                if s in visited_func:
                    continue
                if s not in visited_func:
                    visited_func.add(s)
                    #func_list.append(lines[index].replace("{", "").strip())
                if(start_func<=line_no<=end_func):
                    found = True
                    special_func = "\n".join(lines[start_func:end_func+1])
                    sp_start_func= start_func
                    sp_end_func= end_func
                    #print("comes")
                    if s not in extreme_detokenization(data['tokenized_code_snippet']):
                        continue
                    last_char =  extreme_detokenization(data['tokenized_code_snippet']).strip()[-1]
                    if last_char!='}':
                        continue
                    detokenized_code = extreme_detokenization(data['tokenized_code_snippet'])
                    #print(detokenized_code)
                    start_f = detokenized_code.find("\n<|startfocus|>\n")
                    end_f = detokenized_code.find("\n<|endfocus|>\n")
                    #print("se ", start_f, " ", end_f)
                    repl_st = detokenized_code[start_f:end_f+15]
                    #print(repl_st)
                    #print(data['target'])
                    with open("temp\\temp.java", 'w', encoding='utf-8') as f:
                        f.write(extreme_detokenization(data['tokenized_code_snippet']).replace("\n<|startfocus|>\n", "").replace("\n<|endfocus|>\n", ""))
                    with open("temp\\temp2.java", 'w', encoding='utf-8') as f:
                        f.write(extreme_detokenization(data['tokenized_code_snippet']).replace(repl_st, data['target']))#replace("\n<|del|>\n", ""))
                    
                    java_cmd = "java -jar src2abs-0.1-jar-with-dependencies.jar single method "
                    java_cmd = java_cmd + "temp\\temp.java"+" "
                    java_cmd = java_cmd+"temp\\processed.java"+' idioms.csv'
                    check = subprocess.call(java_cmd.replace('/', '\\'), shell=True)
                    #print(java_cmd)
                    if check != 0:
                        print(java_cmd)
                        print("java cmd execusion failed on file ", f)
                        continue
                    check = subprocess.call(java_cmd.replace('/', '\\').replace("temp.java", "temp2.java").replace("processed", "processed2"), shell=True)
                    #print(java_cmd)
                    if check != 0:
                        print(java_cmd)
                        print("java cmd execusion failed on file ", f)
                        continue
                    #print("comes")
                    file_data = read("temp\\processed.java")
                    file_data_y = read("temp\\processed2.java")
                    #print(file_data)
                    #print(idx," ",  len(file_data.split(" "))," ", len(file_data_y.split(" ")) )
                    if(len(file_data.split(" "))<=50 and len(file_data_y.split(" "))<=50):
                        dt = {}
                        dt['idx'] = idx
                        dt['project_name'] = data['project_name']
                        dt['written_on'] = data['written_on']
                        #dt['source'] = file_data
                        dt['tufano_target'] = file_data_y
                        dt['comment'] = data['message']
                        dt['tokenized_comment'] = data['tokenized_comment']
                        dt['tufano_code'] = file_data
                        dt['our_target'] = data['target']
                        dt['our_code'] = detokenized_code #.replace("<|startfocus|>\n", "").replace("<|endfocus|>\n", "")
                        dt['tokenized_code'] = data['tokenized_code_snippet']
                        dt['written_on'] = dt['written_on']
                        #print("50->", idx)
                        tufano_less_then_50.append(dt)
                        #func_less_then_50.append(file_data)
                        break
                    if(len(file_data.split(" "))<=100 and len(file_data_y.split(" "))<=100):
                        dt = {}
                        dt['idx'] = idx
                        dt['project_name'] = data['project_name']
                        dt['written_on'] = data['written_on']
                        #dt['source'] = file_data
                        dt['tufano_target'] = file_data_y
                        dt['comment'] = data['message']
                        dt['tokenized_comment'] = data['tokenized_comment']
                        dt['tufano_code'] = file_data
                        dt['our_target'] = data['target']
                        dt['our_code'] = detokenized_code #.replace("<|startfocus|>\n", "").replace("<|endfocus|>\n", "")
                        dt['tokenized_code'] = data['tokenized_code_snippet']
                        dt['written_on'] = dt['written_on']
                        tufano_less_then_100.append(dt)
                        break
# Out:
# 0 0 0
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 100 2 0
# 200 2 6
# 300 3 11
# 400 5 12
# 500 6 18
# 600 7 26
# 700 11 35
# 800 12 37
# 900 15 47
# 1000 19 53
# 1100 20 59
# 1200 21 62
# 1300 24 70
# 1400 28 75
# 1500 33 83
# 1600 35 92
# 1700 41 101
# 1800 44 108
# 1900 46 117
# 2000 47 122
# 2100 50 128
# 2200 54 133
# 2300 56 139
# 2400 61 144
# 2500 68 148
# 2600 71 151
# 2700 77 160
# 2800 82 168
# 2900 83 174
# 3000 86 179
# 3100 88 187
# 3200 89 190
# 3300 90 194
# 3400 92 197
# 3500 96 200
# 3600 99 205
# 3700 103 211
# 3800 108 220
# 3900 112 229
# 4000 114 235
# 4100 118 242
# 4200 120 246
# 4300 125 249
# 4400 127 260
# 4500 128 265
# 4600 131 272
# 4700 135 280
# 4800 137 284
# 4900 140 289
# 5000 141 293
# 5100 144 297
# 5200 146 298
# 5300 150 309
# 5400 153 316
# 5500 156 325
# 5600 158 334
# 5700 162 339
# 5800 164 342
# 5900 168 347
# 6000 172 355
# 6100 175 364
# 6200 178 370
# 6300 178 374
# 6400 179 381
# 6500 183 384
# 6600 187 388
# 6700 188 396
# 6800 188 398
# 6900 189 401
# 7000 192 404
# 7100 197 410
# 7200 198 414
# 7300 203 416
# 7400 206 422
# 7500 207 427
# 7600 209 431
# 7700 211 436
# 7800 214 442
# 7900 217 444
# 8000 218 448
# 8100 219 454
# 8200 221 459
# 8300 221 464
# 8400 223 472
# 8500 226 474
# 8600 229 482
# 8700 230 485
# 8800 233 491
# 8900 235 494
# 9000 238 501
# 9100 241 509
# 9200 244 512
# 9300 249 518
# 9400 249 524
# 9500 249 525
# 9600 250 526
# 9700 258 529
# 9800 259 534
# 9900 261 541
# 10000 262 546
# 10100 262 550
# 10200 263 555
# 10300 265 559
# 10400 268 562
# 10500 273 564
# 10600 275 568
# 10700 275 573
# 10800 277 576
# 10900 278 581
# 11000 282 581
# 11100 282 585
# 11200 283 592
# 11300 287 598
# 11400 287 604
# 11500 288 607
# 11600 290 610
# 11700 291 613
# 11800 292 615
# 11900 295 622
# 12000 298 624
# 12100 302 627
# 12200 303 629
# 12300 307 635
# 12400 312 638
# 12500 315 642
# 12600 318 643
# 12700 318 648
# 12800 322 651
# 12900 322 657
# 13000 323 666
# 13100 323 671
# 13200 325 675
# 13300 326 681
# 13400 329 686
# 13500 329 687
# 13600 331 690
# 13700 333 693
# 13800 333 697
# 13900 333 704
# 14000 335 711
# 14100 336 713
# 14200 337 718
# 14300 339 723
# 14400 341 726
# 14500 344 730
# 14600 346 733
# 14700 347 736
# 14800 348 742
# 14900 348 749
# 15000 348 749
# 15100 350 750
# 15200 352 750
# 15300 353 752
# 15400 354 754
# 15500 356 759
# 15600 357 763
# 15700 359 764
# 15800 360 767
# 15900 361 769
# 16000 361 777
# 16100 363 781
# 16200 365 784
# 16300 367 787
# 16400 369 788
# 16500 372 790
# 16600 372 795
# 16700 372 800
# 16800 374 801
# 16900 376 802
# 17000 381 805
# 17100 381 805
# 17200 381 808
# 17300 384 810
# 17400 386 812
# 17500 390 813
# 17600 392 815
# 17700 393 818
# 17800 393 819
# 17900 395 820
# 18000 399 820
# 18100 401 822
# 18200 403 825
# 18300 403 831
# 18400 405 833
# 18500 406 835
# 18600 408 838
# 18700 410 841
# 18800 414 843
# 18900 415 845
# 19000 415 846
# 19100 416 857
# 19200 417 862
# 19300 417 864
# 19400 418 870
# 19500 418 877
# 19600 419 881
# 19700 421 882
# 19800 421 883
# 19900 422 889
# 20000 422 893
# 20100 422 896
# 20200 424 900
# 20300 426 902
# 20400 427 902
# 20500 428 904
# 20600 428 911
# 20700 430 914
# 20800 431 915
# 20900 433 917
# 21000 434 920
# 21100 436 922
# 21200 437 925
# 21300 438 926
# 21400 440 931
# 21500 443 934
# 21600 446 935
# 21700 448 936
# 21800 450 937
# 21900 450 938
# 22000 451 940
# 22100 453 942
# 22200 455 945
# 22300 457 945
# 22400 457 945
# 22500 457 949
# 22600 458 950
# 22700 460 954
# 22800 463 957
# 22900 466 962
# 23000 467 964
# 23100 468 964
# 23200 469 964
# 23300 471 966
# 23400 471 969
# 23500 474 972
# 23600 475 972
# 23700 475 975
# 23800 476 977
# 23900 479 977
# 24000 480 980
# 24100 482 983
# 24200 483 985
# 24300 484 985
# 24400 487 989
# 24500 489 990
# 24600 490 990
# 24700 491 994
# 24800 491 995
# 24900 491 997
# 25000 491 998
# 25100 494 1000
# 25200 494 1004
# 25300 496 1005
# 25400 498 1009
# 25500 499 1011
# 25600 499 1012
# 25700 500 1014
# 25800 502 1015
# 25900 503 1018
# 26000 503 1020
# 26100 503 1022
# 26200 503 1027
# 26300 503 1030
# 26400 503 1032
# 26500 505 1033
# 26600 507 1035
# 26700 508 1036
# 26800 510 1038
# java -jar src2abs-0.1-jar-with-dependencies.jar single method temp\temp.java temp\processed.java idioms.csv
# java cmd execusion failed on file  <_io.TextIOWrapper name='temp\\temp2.java' mode='w' encoding='utf-8'>
# 26900 512 1041
# 27000 513 1043
# 27100 513 1045
# 27200 513 1046
# 27300 514 1050
# 27400 516 1050
# 27500 516 1053
# 27600 517 1055
# 27700 517 1057
# 27800 519 1058
# 27900 519 1059
# 28000 519 1060
# 28100 519 1060
# 28200 519 1063
# 28300 520 1063
# java -jar src2abs-0.1-jar-with-dependencies.jar single method temp\temp.java temp\processed.java idioms.csv
# java cmd execusion failed on file  <_io.TextIOWrapper name='temp\\temp2.java' mode='w' encoding='utf-8'>
# 28400 520 1065
# 28500 521 1067
# 28600 522 1068
# 28700 524 1069
# 28800 526 1073
# 28900 527 1075
# 29000 527 1076
# 29100 527 1077
# 29200 528 1078
# 29300 529 1079
# 29400 531 1082
# 29500 531 1083
# 29600 531 1085
# 29700 532 1090
# 29800 533 1094
# 29900 537 1095
# 30000 538 1096
# 30100 539 1097
# 30200 540 1099
# 30300 542 1102
# 30400 542 1104
# 30500 543 1106
# 30600 544 1106
# 30700 544 1112
# 30800 544 1112
# 30900 544 1113
# 31000 545 1115
# 31100 545 1116
# 31200 545 1119
# 31300 545 1121
# 31400 545 1123
# 31500 545 1124
# 31600 546 1126
# 31700 548 1126
# 31800 548 1127
# 31900 548 1129
# 32000 549 1129
# 32100 551 1131
# 32200 551 1131
# 32300 551 1132
# 32400 552 1133
# 32500 553 1133
# 32600 553 1134
# 32700 553 1134
# 32800 555 1134
# 32900 555 1135
# 33000 556 1136
# 33100 556 1136
# 33200 557 1136
# 33300 559 1137
# 33400 559 1137
# 33500 559 1138
# 33600 559 1141
# 33700 559 1142
# 33800 559 1146
# 33900 561 1146
# 34000 561 1146
# 34100 561 1146
# 34200 561 1148
# 34300 561 1152
# 34400 562 1153
# 34500 563 1154
# 34600 564 1155
# 34700 564 1156
# 34800 565 1159
# 34900 567 1159
# 35000 568 1160
# 35100 568 1160
# 35200 568 1160
# 35300 568 1161
# 35400 569 1162
# 35500 569 1162
# 35600 570 1163
# 35700 570 1163
# 35800 571 1165
# 35900 571 1166
# 36000 572 1166
# 36100 573 1167
# 36200 573 1170
# 36300 573 1170
# 36400 574 1170
# 36500 574 1171
# 36600 574 1171
# 36700 574 1171
# 36800 575 1173
# 36900 575 1174
# 37000 576 1175
# 37100 576 1176
# 37200 578 1177
# 37300 581 1178
# 37400 582 1178
# 37500 584 1178
# 37600 586 1178
# 37700 588 1180
# 37800 588 1182
# 37900 590 1182
# 38000 590 1184
# 38100 590 1185
# 38200 592 1187
# 38300 593 1190
# 38400 593 1191
# 38500 593 1191
# 38600 593 1191
# 38700 595 1191
# 38800 595 1191
# 38900 595 1191
# 39000 595 1191
# 39100 595 1191
# 39200 595 1191
# 39300 596 1191
# 39400 596 1192
# 39500 596 1192
# 39600 596 1195
# 39700 596 1195
# 39800 597 1196
# 39900 598 1197
# 40000 598 1197
# 40100 599 1197
# 40200 599 1199
# 40300 599 1201
# 40400 599 1203
# 40500 599 1203
# 40600 599 1204
# 40700 599 1205
# 40800 600 1206
# 40900 601 1206
# 41000 602 1206
# 41100 602 1207
# 41200 604 1208
# 41300 605 1208
# 41400 605 1208
# 41500 605 1209
# 41600 605 1209
# 41700 605 1210
# 41800 605 1210
# 41900 605 1211
# 42000 605 1212
# 42100 605 1213
# 42200 606 1213
# 42300 607 1213
# 42400 607 1213
# 42500 607 1216
# 42600 607 1216
# 42700 607 1218
# 42800 607 1219
# 42900 608 1219
# 43000 609 1219
# 43100 610 1219
# 43200 611 1220
# 43300 611 1220
# 43400 611 1222
# 43500 611 1222
# 43600 611 1223
# 43700 612 1224
# 43800 612 1225
# 43900 612 1226
# 44000 612 1226
# 44100 612 1226
# 44200 612 1226
# 44300 612 1226
# 44400 612 1227
# 44500 612 1227
# 44600 612 1227
# 44700 613 1227
# 44800 613 1227
# 44900 613 1228
# 45000 613 1229
# 45100 613 1229
# 45200 613 1230
# 45300 613 1231
# 45400 613 1231
# 45500 613 1231
# 45600 613 1232
# 45700 613 1232
# 45800 615 1233
# 45900 615 1234
# 46000 615 1235
# 46100 615 1237
# 46200 615 1237
# 46300 615 1238
# 46400 615 1238
# 46500 615 1240
# 46600 616 1240
# 46700 616 1241
# 46800 616 1241
# 46900 617 1241
# 47000 618 1241
# 47100 620 1241
# 47200 622 1242
# 47300 623 1242
# 47400 623 1242
# 47500 623 1243
# 47600 623 1243
# 47700 623 1243
# 47800 623 1243
# 47900 623 1243
# 48000 623 1243
# 48100 624 1243
# 48200 624 1243
# 48300 624 1243
# 48400 624 1243
# 48500 624 1243
# 48600 624 1243
# 48700 624 1243
# 48800 624 1243
# 48900 624 1243
# 49000 624 1243
# 49100 624 1243
# 49200 625 1243
# 49300 626 1243
# 49400 628 1244
# 49500 628 1246
# 49600 628 1246
# 49700 628 1246
# 49800 629 1247
# 49900 629 1247
# 50000 629 1247
# 50100 629 1247
# 50200 629 1247
# 50300 630 1247
# 50400 632 1248
# 50500 632 1248
# 50600 632 1248
# 50700 632 1248
# 50800 632 1248
# 50900 632 1249
# 51000 632 1249
# 51100 632 1249
# 51200 632 1249
# 51300 632 1249
# 51400 632 1251
# 51500 632 1251
# 51600 632 1251
# 51700 632 1251
# 51800 632 1251
# 51900 632 1251
# 52000 632 1251
# 52100 632 1252
# 52200 632 1254
# 52300 632 1254
# 52400 632 1255
# 52500 632 1255
# 52600 632 1256
# 52700 632 1256
# 52800 632 1257
# 52900 632 1257
# 53000 633 1257
# 53100 634 1257
# 53200 635 1257
# 53300 635 1257
# 53400 635 1257
# 53500 635 1258
# 53600 635 1259
# 53700 635 1260
# 53800 635 1260
# 53900 635 1260
# 54000 635 1260
# 54100 636 1260
# 54200 636 1260
# 54300 636 1261
# 54400 636 1261
# 54500 636 1262
# 54600 636 1263
# 54700 636 1264
# 54800 636 1264
# 54900 636 1264
# 55000 636 1264
# 55100 636 1264
# 55200 636 1264
# 55300 636 1264
# 55400 636 1264
# 55500 636 1266
# 55600 636 1267
# 55700 636 1267
# 55800 637 1267
# 55900 637 1267
# 56000 637 1267
# 56100 637 1267
# 56200 637 1267
# 56300 637 1267
# 56400 637 1267
# 56500 637 1267
# 56600 637 1267
# 56700 637 1267
# 56800 637 1268
# 56900 638 1268
# 57000 639 1268
# 57100 639 1269
# 57200 639 1269
# 57300 639 1269
# 57400 640 1269
# 57500 641 1269
# 57600 641 1269
# 57700 641 1269
# 57800 641 1270
# 57900 641 1270
# 58000 641 1270
# 58100 641 1272
# 58200 641 1272
# 58300 641 1273
# 58400 641 1274
# 58500 641 1274
# 58600 641 1274
# 58700 641 1274
# 58800 641 1274
# 58900 641 1274
# 59000 641 1275
# 59100 641 1276
# 59200 642 1276
# 59300 642 1277
# 59400 642 1278
# 59500 643 1278
# 59600 644 1278
# 59700 644 1278
# 59800 644 1278
# 59900 644 1279
# 60000 644 1279
# 60100 644 1279
# 60200 644 1279
# 60300 644 1280
# 60400 645 1280
# 60500 646 1280
# 60600 646 1280
# 60700 646 1280
# 60800 646 1281
# 60900 646 1281
# 61000 646 1282
# 61100 646 1283
# 61200 646 1283
# 61300 646 1283
# 61400 646 1283
# 61500 646 1283
# 61600 646 1283
# 61700 646 1283
# 61800 646 1283
# 61900 646 1283
# 62000 646 1284
# 62100 646 1284
# 62200 646 1284
# 62300 646 1284
# 62400 646 1284
# 62500 646 1284
# 62600 646 1284
# 62700 646 1284
# 62800 646 1284
# 62900 646 1284
# 63000 646 1284
# 63100 646 1284
# 63200 647 1285
# 63300 648 1286
# 63400 648 1286
# 63500 648 1286
# 63600 648 1286
# 63700 648 1287
# 63800 649 1287
# 63900 649 1287
# 64000 649 1288
# 64100 649 1288
# 64200 650 1288
# 64300 650 1289
# 64400 650 1289
# 64500 650 1289
# 64600 650 1290
# 64700 650 1290
# 64800 651 1290
# 64900 651 1291
# 65000 651 1291
# 65100 651 1291
# 65200 651 1291
# 65300 651 1291
# 65400 651 1291
# 65500 651 1291
# 65600 652 1291
# 65700 652 1291
# 65800 652 1292
# 65900 652 1294
# 66000 653 1294
# 66100 653 1295
# 66200 654 1295
# 66300 655 1295
# 66400 655 1295
# 66500 655 1295
# 66600 655 1295
# 66700 655 1295
# 66800 655 1296
# 66900 655 1296
# 67000 655 1296
# 67100 655 1296
# 67200 655 1296
# 67300 655 1296
# 67400 655 1297
# 67500 655 1297
# 67600 655 1297
# 67700 655 1298
# 67800 655 1299
# 67900 655 1300
# 68000 655 1302
# 68100 655 1302
# 68200 655 1302
# 68300 655 1302
# 68400 655 1302
# 68500 655 1302
# 68600 656 1302
# 68700 657 1302
# 68800 657 1303
# 68900 657 1303
# 69000 657 1304
# 69100 657 1304
# 69200 657 1304
# 69300 657 1304
# 69400 657 1304
# 69500 657 1304
# 69600 657 1304
# 69700 657 1304
# 69800 657 1304
# 69900 657 1304
# 70000 657 1305
# 70100 657 1305
# 70200 657 1305
# 70300 657 1306
# 70400 657 1306
# 70500 657 1306
# 70600 657 1306
# 70700 657 1306
# 70800 657 1306
# 70900 657 1306
# 71000 657 1306
# 71100 657 1306
# 71200 657 1306
# 71300 657 1306
# 71400 657 1306
# 71500 657 1306
# 71600 657 1306
# 71700 657 1306
# 71800 657 1306
# 71900 657 1306
# 72000 657 1306
# 72100 657 1306
# 72200 657 1306
# 72300 657 1306
# 72400 657 1306
# 72500 657 1306
# 72600 657 1306
# 72700 657 1306
# 72800 657 1306
# 72900 657 1306
# 73000 657 1306
# 73100 657 1306
# 73200 657 1306
# 73300 657 1306
# 73400 657 1306
# 73500 657 1306
# 73600 657 1306
# 73700 657 1306
# 73800 657 1306
# 73900 657 1306
# 74000 657 1307
# 74100 657 1307
# 74200 657 1307
# 74300 657 1307
# 74400 657 1307
# 74500 657 1307
# 74600 657 1307
# 74700 657 1307
# 74800 657 1307
# 74900 657 1307
# 75000 657 1307
# 75100 657 1307
# 75200 657 1307
# 75300 657 1307
# 75400 657 1307
# 75500 657 1307
# 75600 657 1307
# 75700 657 1307
# 75800 657 1307
# 75900 657 1307
# 76000 657 1308
# 76100 657 1308
# 76200 657 1308
# 76300 657 1308
# 76400 657 1308
# 76500 657 1308
# 76600 657 1308
# 76700 657 1308
# 76800 657 1308
# 76900 657 1308
# 77000 657 1308
# 77100 657 1308
# 77200 657 1308
# 77300 657 1308
# 77400 657 1308
# 77500 657 1308
# 77600 657 1308
# 77700 657 1308
# 77800 657 1308
# 77900 657 1308
# 78000 657 1308
# 78100 657 1308
# 78200 657 1308
# 78300 657 1308
# 78400 657 1308
# 78500 657 1308
# 78600 657 1308
# 78700 657 1308
# 78800 657 1308
# 78900 657 1308
# 79000 657 1308
# 79100 657 1308
# 79200 657 1308
# 79300 657 1308
# 79400 657 1308
# 79500 657 1308
# 79600 657 1308
# 79700 657 1308
# 79800 657 1308
# 79900 657 1308
# 80000 657 1308
# 80100 657 1308
# 80200 657 1308
# 80300 657 1308
# 80400 658 1308
# 80500 658 1308
# 80600 658 1308
# 80700 658 1308
# 80800 658 1308
# 80900 658 1308
# 81000 658 1308
# 81100 658 1308
# 81200 658 1308
# 81300 658 1308
# 81400 658 1308
# 81500 658 1308
# 81600 658 1308
# 81700 658 1308
# 81800 658 1308
# 81900 658 1308
# 82000 658 1308
# 82100 658 1308
# 82200 658 1308
# 82300 658 1308
# 82400 658 1308
# 82500 658 1308
# 82600 658 1308
# 82700 658 1308
# 82800 658 1308
# 82900 658 1308
# 83000 658 1308
# 83100 658 1308
# 83200 658 1308
# 83300 658 1308
# 83400 658 1308
# 83500 658 1308
# 83600 658 1308
# 83700 658 1308
# 83800 658 1308
# 83900 658 1308
# 84000 658 1308
# 84100 658 1308
# 84200 658 1308
# 84300 658 1308
# 84400 658 1308
# 84500 658 1308
# 84600 658 1308
# 84700 658 1308
# 84800 658 1308
# 84900 658 1308
# 85000 658 1308
# 85100 658 1308
# 85200 658 1308
# 85300 658 1308
# 85400 658 1309
# 85500 658 1309
# 85600 658 1309
# 85700 658 1309
# 85800 658 1309
# 85900 658 1309
# 86000 659 1309
# 86100 659 1309
# 86200 659 1309
# 86300 659 1309
# 86400 659 1309
# 86500 659 1309
# 86600 659 1309
# 86700 659 1309
# 86800 659 1309
# 86900 659 1309
# 87000 659 1309
# 87100 659 1309
# 87200 659 1309
# 87300 659 1309
# 87400 659 1309
# 87500 660 1309
# 87600 660 1309
# 87700 660 1309
# 87800 660 1309
# 87900 660 1309
# 88000 660 1309
# 88100 660 1309
# 88200 660 1309
# 88300 660 1309
# 88400 660 1309
# 88500 660 1309
# 88600 660 1309
# 88700 660 1309
# 88800 660 1309
# 88900 660 1309
# 89000 660 1309
# 89100 660 1309
# 89200 660 1309
# 89300 660 1309
# 89400 660 1309
# 89500 660 1309
# 89600 660 1309
# 89700 660 1309
# 89800 660 1309
# 89900 660 1309
# 90000 660 1309
# 90100 660 1309
# 90200 660 1309
# 90300 660 1309
# 90400 660 1309
# 90500 660 1309
# 90600 661 1309
# 90700 661 1309
# 90800 661 1309
# 90900 661 1310
# 91000 661 1312
# 91100 661 1312
# 91200 661 1312
# 91300 661 1312
# 91400 661 1312
# 91500 661 1312
# 91600 662 1312
# 91700 662 1312
# 91800 662 1312
# 91900 663 1312
# 92000 664 1313
# 92100 664 1313
# 92200 664 1313
# 92300 665 1313
# 92400 666 1313
# 92500 666 1313
# 92600 667 1313
# 92700 667 1313
# 92800 667 1314
# 92900 667 1314
# 93000 667 1314
# 93100 667 1314
# 93200 667 1314
# 93300 667 1315
# 93400 667 1315
# 93500 667 1317
# 93600 667 1318
# 93700 667 1318
# 93800 668 1319
# 93900 668 1319
# 94000 668 1319
# 94100 668 1320
# 94200 668 1320
# 94300 668 1321
# 94400 668 1321
# 94500 668 1322
# 94600 668 1323
# 94700 668 1323
# 94800 668 1323
# 94900 668 1323
# 95000 668 1323
# 95100 668 1323
# 95200 668 1324
# 95300 668 1324
# 95400 668 1324
# 95500 668 1324
# 95600 668 1325
# 95700 669 1325
# 95800 669 1326
# 95900 669 1326
# 96000 669 1327
# 96100 669 1328
# 96200 669 1329
# 96300 669 1329
# 96400 670 1329
# 96500 670 1332
# 96600 670 1333

# %%
print(len(tufano_less_then_50))
print(len(tufano_less_then_100))
with open('less_then_50_v1.json', 'w', encoding="utf8") as f:  # writing JSON object
    json.dump(tufano_less_then_50, f)
with open('less_then_100_v1.json', 'w', encoding="utf8") as f:  # writing JSON object
    json.dump(tufano_less_then_100, f)
# Out:
# 670
# 1335

# %%
pprint(tufano_less_then_50)
# Out:
# [{'comment': 'Nit: space between `for` and `(`.',
#   'idx': 37,
#   'our_code': '\tprivate static void allocateUnreachableObjects() {\n'
#               '<|startfocus|>\n'
#               '        for(int i = 0; i <<|s|>unreachableObjNum; i++) {\n'
#               '<|endfocus|>\n'
#               '            new MockClass(false);\n'
#               '        }\n'
#               '\t}',
#   'our_target': '        for(int i = 0; i < unreachableObjNum; i++) {\n'
#                 '            new MockClass(false);\n'
#                 '\r\n',
#   'project_name': 'android_',
#   'tokenized_code': ['<|t|>',
#                      'private',
#                      '<|s|>',
#                      'static',
#                      '<|s|>',
#                      'void',
#                      '<|s|>',
#                      'allocate',
#                      'Unreachable',
#                      'Objects',
#                      '(',
#                      ')',
#                      '<|s|>',
#                      '{',
#                      '<|nl|>',
#                      '<|startfocus|>',
#                      '<|nl|>',
#                      '<|8-s|>',
#                      'for',
#                      '(',
#                      'int',
#                      '<|s|>',
#                      'i',
#                      '<|s|>',
#                      '=',
#                      '<|s|>',
#                      '0',
#                      ';',
#                      '<|s|>',
#                      'i',
#                      '<|s|>',
#                      '<<|',
#                      's',
#                      '|>',
#                      'unreachable',
#                      'Obj',
#                      'Num',
#                      ';',
#                      '<|s|>',
#                      'i',
#                      '++',
#                      ')',
#                      '<|s|>',
#                      '{',
#                      '<|nl|>',
#                      '<|endfocus|>',
#                      '<|nl|>',
#                      '<|12-s|>',
#                      'new',
#                      '<|s|>',
#                      'Mock',
#                      'Class',
#                      '(',
#                      'false',
#                      ');',
#                      '<|nl|>',
#                      '<|8-s|>',
#                      '}',
#                      '<|nl|>',
#                      '<|t|>',
#                      '}'],
#   'tokenized_comment': ['Nit',
#                         ':',
#                         '<|s|>',
#                         'space',
#                         '<|s|>',
#                         'between',
#                         '<|s|>',
#                         '`',
#                         'for',
#                         '`',
#                         '<|s|>',
#                         'and',
#                         '<|s|>',
#                         '`',
#                         '(',
#                         '`',
#                         '.'],
#   'tufano_code': 'private static void VAR_1 ( ) { for ( int i = 0 ; i < < | '
#                  'VAR_2 | > VAR_3 ; i ++ ) { new VAR_4 ( false ) ; } }',
#   'tufano_target': 'private static void METHOD_1 ( ) { for ( int i = 0 ; i < '
#                    'VAR_1 ; i ++ ) { new TYPE_1 ( false ) ; new TYPE_1 ( false '
#                    ') ; } }',
#   'written_on': '2017-04-10 14:33:19'},
#  {'comment': 'this might be obsolete now...',
#   'idx': 39,
#   'our_code': '    private static String filterGmt(String name) {\n'
#               '<|startfocus|>\n'
#               "        // We don't use the display names if they're "
#               '"GMT[+-]xx:xx" because icu doesn\'t use the\n'
#               '        // up-to-date time zone transition data, so it gets '
#               'these wrong. TimeZone.getDisplayName\n'
#               '        // creates accurate names on demand.\n'
#               '<|endfocus|>\n'
#               '        if (name == null || name.startsWith("GMT")) {\n'
#               '            return null;\n'
#               '        }\n'
#               '        return name;\n'
#               '    }',
#   'our_target': "        // We don't need to use ICU for GMT or GMT(+-) zones "
#                 'because TimeZone.getDisplayName creates\n'
#                 '        // names on demand using the timezone data. This way '
#                 'we will never rely on ICU calculating\n'
#                 '        // the zone offset correctly.\n'
#                 '        if (name == null || name.startsWith("GMT")) {\n'
#                 '\r\n',
#   'project_name': 'android_',
#   'tokenized_code': ['<|4-s|>',
#                      'private',
#                      '<|s|>',
#                      'static',
#                      '<|s|>',
#                      'String',
#                      '<|s|>',
#                      'filter',
#                      'Gmt',
#                      '(',
#                      'String',
#                      '<|s|>',
#                      'name',
#                      ')',
#                      '<|s|>',
#                      '{',
#                      '<|nl|>',
#                      '<|startfocus|>',
#                      '<|nl|>',
#                      '<|8-s|>',
#                      '//',
#                      '<|s|>',
#                      'We',
#                      '<|s|>',
#                      'don',
#                      "'",
#                      't',
#                      '<|s|>',
#                      'use',
#                      '<|s|>',
#                      'the',
#                      '<|s|>',
#                      'display',
#                      '<|s|>',
#                      'names',
#                      '<|s|>',
#                      'if',
#                      '<|s|>',
#                      'they',
#                      "'",
#                      're',
#                      '<|s|>',
#                      '"',
#                      'GMT',
#                      '[',
#                      '+',
#                      '-',
#                      ']',
#                      'xx',
#                      ':',
#                      'xx',
#                      '"',
#                      '<|s|>',
#                      'because',
#                      '<|s|>',
#                      'icu',
#                      '<|s|>',
#                      'doesn',
#                      "'",
#                      't',
#                      '<|s|>',
#                      'use',
#                      '<|s|>',
#                      'the',
#                      '<|nl|>',
#                      '<|8-s|>',
#                      '//',
#                      '<|s|>',
#                      'up',
#                      '-',
#                      'to',
#                      '-',
#                      'date',
#                      '<|s|>',
#                      'time',
#                      '<|s|>',
#                      'zone',
#                      '<|s|>',
#                      'transition',
#                      '<|s|>',
#                      'data',
#                      ',',
#                      '<|s|>',
#                      'so',
#                      '<|s|>',
#                      'it',
#                      '<|s|>',
#                      'gets',
#                      '<|s|>',
#                      'these',
#                      '<|s|>',
#                      'wrong',
#                      '.',
#                      '<|s|>',
#                      'Time',
#                      'Zone',
#                      '.',
#                      'get',
#                      'Display',
#                      'Name',
#                      '<|nl|>',
#                      '<|8-s|>',
#                      '//',
#                      '<|s|>',
#                      'creates',
#                      '<|s|>',
#                      'accurate',
#                      '<|s|>',
#                      'names',
#                      '<|s|>',
#                      'on',
#                      '<|s|>',
#                      'demand',
#                      '.',
#                      '<|nl|>',
#                      '<|endfocus|>',
#                      '<|nl|>',
#                      '<|8-s|>',
#                      'if',
#                      '<|s|>',
#                      '(',
#                      'name',
#                      '<|s|>',
#                      '==',
#                      '<|s|>',
#                      'null',
#                      '<|s|>',
#                      '||',
#                      '<|s|>',
#                      'name',
#                      '.',
#                      'starts',
#                      'With',
#                      '(',
#                      '"',
#                      'GMT',
#                      '"',
#                      ')',
#                      ')',
#                      '<|s|>',
#                      '{',
#                      '<|nl|>',
#                      '<|12-s|>',
#                      'return',
#                      '<|s|>',
#                      'null',
#                      ';',
#                      '<|nl|>',
#                      '<|8-s|>',
#                      '}',
#                      '<|nl|>',
#                      '<|8-s|>',
#                      'return',
#                      '<|s|>',
#                      'name',
#                      ';',
#                      '<|nl|>',
#                      '<|4-s|>',
#                      '}'],
#   'tokenized_comment': ['this',
#                         '<|s|>',
#                         'might',
#                         '<|s|>',
#                         'be',
#                         '<|s|>',
#                         'obsolete',
#                         '<|s|>',
#                         'now',
#                         '...'],
#   'tufano_code': 'private static String VAR_1 ( String name ) { return null ; '
#                  '} return name ; }',
#   'tufano_target': 'private static String VAR_1 ( String name ) { if ( name == '
#                    'null || name . startsWith ( STRING_1 ) ) { if ( name == '
#                    'null || name . startsWith ( STRING_1 ) ) { return null ; } '
#                    'return name ; }',
#   'written_on': '2015-04-23 17:26:33'},
#  {'comment': 'If it is a context, there is no level here',
#   'idx': 272,
#   'our_code': '  public ProblemLevel getDefaultProblemLevel() {\n'
#               '<|startfocus|>\n'
#               '    return ProblemLevel.INFO;\n'
#               '<|endfocus|>\n'
#               '  }',
#   'our_target': '    return level;\n  }\n\r\n',
#   'project_name': 'android_',
#   'tokenized_code': ['<|2-s|>',
#                      'public',
#                      '<|s|>',
#                      'Problem',
#                      'Level',
#                      '<|s|>',
#                      'get',
#                      'Default',
#                      'Problem',
#                      'Level',
#                      '(',
#                      ')',
#                      '<|s|>',
#                      '{',
#                      '<|nl|>',
#                      '<|startfocus|>',
#                      '<|nl|>',
#                      '<|4-s|>',
#                      'return',
#                      '<|s|>',
#                      'Problem',
#                      'Level',
#                      '.',
#                      'INFO',
#                      ';',
#                      '<|nl|>',
#                      '<|endfocus|>',
#                      '<|nl|>',
#                      '<|2-s|>',
#                      '}'],
#   'tokenized_comment': ['If',
#                         '<|s|>',
#                         'it',
#                         '<|s|>',
#                         'is',
#                         '<|s|>',
#                         'a',
#                         '<|s|>',
#                         'context',
#                         ',',
#                         '<|s|>',
#                         'there',
#                         '<|s|>',
#                         'is',
#                         '<|s|>',
#                         'no',
#                         '<|s|>',
#                         'level',
#                         '<|s|>',
#                         'here'],
#   'tufano_code': 'public TYPE_1 METHOD_1 ( ) { return VAR_1 ; }',
#   'tufano_target': 'public VAR_1 VAR_2 ( ) { return VAR_3 ; } }',
#   'written_on': '2016-05-20 14:19:23'},
#  {'comment': 'Prefer using reflection to avoid static string:\n'
#              '\n'
#              '  return InvokeMethodDebuggee.class.getName()\n'
#              '\n'
#              'I was planning to update the API (before switching to Jack) by '
#              'providing Class<?> instead of String but did not have time to '
#              'work on this so far.',
#   'idx': 344,
#   'our_code': '    protected String getDebuggeeClassName() {\n'
#               '<|startfocus|>\n'
#               '        return '
#               '"org.apache.harmony.jpda.tests.jdwp.InterfaceType.InvokeMethodDebuggee";\n'
#               '<|endfocus|>\n'
#               '    }',
#   'our_target': '        return InvokeMethodDebuggee.class.getName();\n'
#                 '    }\n'
#                 '\r\n',
#   'project_name': 'android_',
#   'tokenized_code': ['<|4-s|>',
#                      'protected',
#                      '<|s|>',
#                      'String',
#                      '<|s|>',
#                      'get',
#                      'Debuggee',
#                      'Class',
#                      'Name',
#                      '(',
#                      ')',
#                      '<|s|>',
#                      '{',
#                      '<|nl|>',
#                      '<|startfocus|>',
#                      '<|nl|>',
#                      '<|8-s|>',
#                      'return',
#                      '<|s|>',
#                      '"',
#                      'org',
#                      '.',
#                      'apache',
#                      '.',
#                      'harmony',
#                      '.',
#                      'jpda',
#                      '.',
#                      'tests',
#                      '.',
#                      'jdwp',
#                      '.',
#                      'Interface',
#                      'Type',
#                      '.',
#                      'Invoke',
#                      'Method',
#                      'Debuggee',
#                      '"',
#                      ';',
#                      '<|nl|>',
#                      '<|endfocus|>',
#                      '<|nl|>',
#                      '<|4-s|>',
#                      '}'],
#   'tokenized_comment': ['Prefer',
#                         '<|s|>',
#                         'using',
#                         '<|s|>',
#                         'reflection',
#                         '<|s|>',
#                         'to',
#                         '<|s|>',
#                         'avoid',
#                         '<|s|>',
#                         'static',
#                         '<|s|>',
#                         'string',
#                         ':',
#                         '<|nl|>',
#                         '<|nl|>',
#                         '<|2-s|>',
#                         'return',
#                         '<|s|>',
#                         'Invoke',
#                         'Method',
#                         'Debuggee',
#                         '.',
#                         'class',
#                         '.',
#                         'get',
#                         'Name',
#                         '(',
#                         ')',
#                         '<|nl|>',
#                         '<|nl|>',
#                         'I',
#                         '<|s|>',
#                         'was',
#                         '<|s|>',
#                         'planning',
#                         '<|s|>',
#                         'to',
#                         '<|s|>',
#                         'update',
#                         '<|s|>',
#                         'the',
#                         '<|s|>',
#                         'API',
#                         '<|s|>',
#                         '(',
#                         'before',
#                         '<|s|>',
#                         'switching',
#                         '<|s|>',
#                         'to',
#                         '<|s|>',
#                         'Jack',
#                         ')',
#                         '<|s|>',
#                         'by',
#                         '<|s|>',
#                         'providing',
#                         '<|s|>',
#                         'Class',
#                         '<?>',
#                         '<|s|>',
#                         'instead',
#                         '<|s|>',
#                         'of',
#                         '<|s|>',
#                         'String',
#                         '<|s|>',
#                         'but',
#                         '<|s|>',
#                         'did',
#                         '<|s|>',
#                         'not',
#                         '<|s|>',
#                         'have',
#                         '<|s|>',
#                         'time',
#                         '<|s|>',
#                         'to',
#                         '<|s|>',
#                         'work',
#                         '<|s|>',
#                         'on',
#                         '<|s|>',
#                         'this',
#                         '<|s|>',
#                         'so',
#                         '<|s|>',
#                         'far',
#                         '.'],
#   'tufano_code': 'protected String METHOD_1 ( ) { return STRING_1 ; }',
#   'tufano_target': 'protected String VAR_1 ( ) { return VAR_2 class . getName '
#                    '( ) ; } }',
#   'written_on': '2016-02-25 09:24:10'},
#  {'comment': 'I am a little confused by this...  is this to get the network '
#              'request with the new parameters?  I think the no-op callback is '
#              'confusing me a little\n'
#              '\n'
#              'maybe it is the naming that is throwing me off.  '
#              'registerMobileNetworkRequest?',
#   'idx': 397,
#   'our_code': '        public void mobileUpstreamRequiresDun(boolean '
#               'dunRequired) {\n'
#               '            final boolean valueChanged = (mDunRequired != '
#               'dunRequired);\n'
#               '            mDunRequired = dunRequired;\n'
#               '            if (valueChanged && mobileExplicitlyRequested()) {\n'
#               '                releaseExplicitMobileRequest();\n'
#               '<|startfocus|>\n'
#               '                registerExplicitMobileRequest();\n'
#               '<|endfocus|>\n'
#               '            }\n'
#               '        }',
#   'our_target': '                registerExplicitMobileRequest();\n'
#                 '            }\n'
#                 '\r\n',
#   'project_name': 'android_',
#   'tokenized_code': ['<|8-s|>',
#                      'public',
#                      '<|s|>',
#                      'void',
#                      '<|s|>',
#                      'mobile',
#                      'Upstream',
#                      'Requires',
#                      'Dun',
#                      '(',
#                      'boolean',
#                      '<|s|>',
#                      'dun',
#                      'Required',
#                      ')',
#                      '<|s|>',
#                      '{',
#                      '<|nl|>',
#                      '<|12-s|>',
#                      'final',
#                      '<|s|>',
#                      'boolean',
#                      '<|s|>',
#                      'value',
#                      'Changed',
#                      '<|s|>',
#                      '=',
#                      '<|s|>',
#                      '(',
#                      'm',
#                      'Dun',
#                      'Required',
#                      '<|s|>',
#                      '!=',
#                      '<|s|>',
#                      'dun',
#                      'Required',
#                      ');',
#                      '<|nl|>',
#                      '<|12-s|>',
#                      'm',
#                      'Dun',
#                      'Required',
#                      '<|s|>',
#                      '=',
#                      '<|s|>',
#                      'dun',
#                      'Required',
#                      ';',
#                      '<|nl|>',
#                      '<|12-s|>',
#                      'if',
#                      '<|s|>',
#                      '(',
#                      'value',
#                      'Changed',
#                      '<|s|>',
#                      '&&',
#                      '<|s|>',
#                      'mobile',
#                      'Explicitly',
#                      'Requested',
#                      '(',
#                      ')',
#                      ')',
#                      '<|s|>',
#                      '{',
#                      '<|nl|>',
#                      '<|16-s|>',
#                      'release',
#                      'Explicit',
#                      'Mobile',
#                      'Request',
#                      '(',
#                      ');',
#                      '<|nl|>',
#                      '<|startfocus|>',
#                      '<|nl|>',
#                      '<|16-s|>',
#                      'register',
#                      'Explicit',
#                      'Mobile',
#                      'Request',
#                      '(',
#                      ');',
#                      '<|nl|>',
#                      '<|endfocus|>',
#                      '<|nl|>',
#                      '<|12-s|>',
#                      '}',
#                      '<|nl|>',
#                      '<|8-s|>',
#                      '}'],
#   'tokenized_comment': ['I',
#                         '<|s|>',
#                         'am',
#                         '<|s|>',
#                         'a',
#                         '<|s|>',
#                         'little',
#                         '<|s|>',
#                         'confused',
#                         '<|s|>',
#                         'by',
#                         '<|s|>',
#                         'this',
#                         '...',
#                         '<|2-s|>',
#                         'is',
#                         '<|s|>',
#                         'this',
#                         '<|s|>',
#                         'to',
#                         '<|s|>',
#                         'get',
#                         '<|s|>',
#                         'the',
#                         '<|s|>',
#                         'network',
#                         '<|s|>',
#                         'request',
#                         '<|s|>',
#                         'with',
#                         '<|s|>',
#                         'the',
#                         '<|s|>',
#                         'new',
#                         '<|s|>',
#                         'parameters',
#                         '?',
#                         '<|2-s|>',
#                         'I',
#                         '<|s|>',
#                         'think',
#                         '<|s|>',
#                         'the',
#                         '<|s|>',
#                         'no',
#                         '-',
#                         'op',
#                         '<|s|>',
#                         'callback',
#                         '<|s|>',
#                         'is',
#                         '<|s|>',
#                         'confusing',
#                         '<|s|>',
#                         'me',
#                         '<|s|>',
#                         'a',
#                         '<|s|>',
#                         'little',
#                         '<|nl|>',
#                         '<|nl|>',
#                         'maybe',
#                         '<|s|>',
#                         'it',
#                         '<|s|>',
#                         'is',
#                         '<|s|>',
#                         'the',
#                         '<|s|>',
#                         'naming',
#                         '<|s|>',
#                         'that',
#                         '<|s|>',
#                         'is',
#                         '<|s|>',
#                         'throwing',
#                         '<|s|>',
#                         'me',
#                         '<|s|>',
#                         'off',
#                         '.',
#                         '<|2-s|>',
#                         'register',
#                         'Mobile',
#                         'Network',
#                         'Request',
#                         '?'],
#   'tufano_code': 'public void METHOD_1 ( boolean VAR_1 ) { final boolean VAR_2 '
#                  '= ( VAR_3 != VAR_1 ) ; VAR_3 = VAR_1 ; if ( VAR_2 && '
#                  'METHOD_2 ( ) ) { METHOD_3 ( ) ; METHOD_4 ( ) ; } }',
#   'tufano_target': 'public void VAR_1 ( boolean VAR_2 ) { final boolean VAR_3 '
#                    '= ( VAR_4 != VAR_2 ) ; VAR_4 = VAR_2 ; if ( VAR_3 && VAR_5 '
#                    '( ) ) { VAR_6 ( ) ; VAR_7 ( ) ; } } }',
#   'written_on': '2017-01-13 04:08:48'},
#  {'comment': 'check if it started here.',
#   'idx': 452,
#   'our_code': '        public void stop() {\n'
#               '<|startfocus|>\n'
#               '            Log.i(TAG, "stop");\n'
#               '            mCodec.stop();\n'
#               '<|endfocus|>\n'
#               '        }',
#   'our_target': '            if(mConfigured) {\n'
#                 '              Log.i(TAG, "stop");\n'
#                 '              mCodec.stop();\n'
#                 '              mConfigured = false;\n'
#                 '            }\n'
#                 '        }\n'
#                 '\r\n',
#   'project_name': 'android_',
#   'tokenized_code': ['<|8-s|>',
#                      'public',
#                      '<|s|>',
#                      'void',
#                      '<|s|>',
#                      'stop',
#                      '(',
#                      ')',
#                      '<|s|>',
#                      '{',
#                      '<|nl|>',
#                      '<|startfocus|>',
#                      '<|nl|>',
#                      '<|12-s|>',
#                      'Log',
#                      '.',
#                      'i',
#                      '(',
#                      'TAG',
#                      ',',
#                      '<|s|>',
#                      '"',
#                      'stop',
#                      '"',
#                      ');',
#                      '<|nl|>',
#                      '<|12-s|>',
#                      'm',
#                      'Codec',
#                      '.',
#                      'stop',
#                      '(',
#                      ');',
#                      '<|nl|>',
#                      '<|endfocus|>',
#                      '<|nl|>',
#                      '<|8-s|>',
#                      '}'],
#   'tokenized_comment': ['check',
#                         '<|s|>',
#                         'if',
#                         '<|s|>',
#                         'it',
#                         '<|s|>',
#                         'started',
#                         '<|s|>',
#                         'here',
#                         '.'],
#   'tufano_code': 'public void METHOD_1 ( ) { TYPE_1 . i ( VAR_1 , STRING_1 ) ; '
#                  'VAR_2 . METHOD_1 ( ) ; }',
#   'tufano_target': 'public void VAR_1 ( ) { if ( VAR_2 ) { VAR_3 . i ( VAR_4 , '
#                    'STRING_1 ) ; VAR_5 ( ) ; VAR_2 = false ; } } }',
#   'written_on': '2015-11-13 04:16:05'},
#  {'comment': 'move to constants section at top of file, same below',
#   'idx': 588,
#   'our_code': '    public void onSaveInstanceState(Bundle outState) {\n'
#               '        super.onSaveInstanceState(outState);\n'
#               '\n'
#               '<|startfocus|>\n'
#               '        outState.putString("CALL_ID", mCallId);\n'
#               '        outState.putString("POST_CHARS", mPostDialStr);\n'
#               '<|endfocus|>\n'
#               '    }',
#   'our_target': '        outState.putString(STATE_CALL_ID, mCallId);\n'
#                 '        outState.putString(STATE_POST_CHARS, mPostDialStr);\n'
#                 '    }\n'
#                 '\r\n',
#   'project_name': 'android_',
#   'tokenized_code': ['<|4-s|>',
#                      'public',
#                      '<|s|>',
#                      'void',
#                      '<|s|>',
#                      'on',
#                      'Save',
#                      'Instance',
#                      'State',
#                      '(',
#                      'Bundle',
#                      '<|s|>',
#                      'out',
#                      'State',
#                      ')',
#                      '<|s|>',
#                      '{',
#                      '<|nl|>',
#                      '<|8-s|>',
#                      'super',
#                      '.',
#                      'on',
#                      'Save',
#                      'Instance',
#                      'State',
#                      '(',
#                      'out',
#                      'State',
#                      ');',
#                      '<|nl|>',
#                      '<|nl|>',
#                      '<|startfocus|>',
#                      '<|nl|>',
#                      '<|8-s|>',
#                      'out',
#                      'State',
#                      '.',
#                      'put',
#                      'String',
#                      '(',
#                      '"',
#                      'CALL',
#                      '_',
#                      'ID',
#                      '"',
#                      ',',
#                      '<|s|>',
#                      'm',
#                      'Call',
#                      'Id',
#                      ');',
#                      '<|nl|>',
#                      '<|8-s|>',
#                      'out',
#                      'State',
#                      '.',
#                      'put',
#                      'String',
#                      '(',
#                      '"',
#                      'POST',
#                      '_',
#                      'CHARS',
#                      '"',
#                      ',',
#                      '<|s|>',
#                      'm',
#                      'Post',
#                      'Dial',
#                      'Str',
#                      ');',
#                      '<|nl|>',
#                      '<|endfocus|>',
#                      '<|nl|>',
#                      '<|4-s|>',
#                      '}'],
#   'tokenized_comment': ['move',
#                         '<|s|>',
#                         'to',
#                         '<|s|>',
#                         'constants',
#                         '<|s|>',
#                         'section',
#                         '<|s|>',
#                         'at',
#                         '<|s|>',
#                         'top',
#                         '<|s|>',
#                         'of',
#                         '<|s|>',
#                         'file',
#                         ',',
#                         '<|s|>',
#                         'same',
#                         '<|s|>',
#                         'below'],
#   'tufano_code': 'public void METHOD_1 ( TYPE_1 VAR_1 ) { super . METHOD_1 ( '
#                  'VAR_1 ) ; VAR_1 . METHOD_2 ( STRING_1 , VAR_2 ) ; VAR_1 . '
#                  'METHOD_2 ( STRING_2 , VAR_3 ) ; }',
#   'tufano_target': 'public void VAR_1 ( VAR_2 VAR_3 ) { super . VAR_1 ( VAR_3 '
#                    ') ; VAR_4 ( VAR_5 , VAR_6 ) ; VAR_4 ( VAR_7 , VAR_8 ) ; } '
#                    '}',
#   'written_on': '2016-01-06 01:20:18'},
#  {'comment': 'Missing javadoc for this one',
#   'idx': 659,
#   'our_code': '  public InlineCloneStatementVisitor(\n'
#               '      @Nonnull TransformationRequest trRequest,\n'
#               '      @Nonnull JMethod enclosingMethod,\n'
#               '      @Nonnull List<JCatchBlock> catchBlocks,\n'
#               '      @CheckForNull JLocal returnLocal,\n'
#               '      @CheckForNull JLabeledStatement returnTarget,\n'
#               '<|startfocus|>\n'
#               '      @CheckForNull JVariable targetInstanceVar,\n'
#               '<|endfocus|>\n'
#               '      @Nonnull Map<JParameter,<|s|>JLocal> parameterMap) {\n'
#               '    super(trRequest, enclosingMethod);\n'
#               '    this.catchBlocks = catchBlocks;\n'
#               '    this.returnLocal = returnLocal;\n'
#               '    this.returnTarget = returnTarget;\n'
#               '    this.parameterMap = parameterMap;\n'
#               '    this.targetInstanceVar = targetInstanceVar;\n'
#               '  }',
#   'our_target': '      @CheckForNull JVariable targetInstanceVar,\n'
#                 '      @Nonnull Map<JParameter, JLocal> parameterMap) {\n'
#                 '\r\n',
#   'project_name': 'android_',
#   'tokenized_code': ['<|2-s|>',
#                      'public',
#                      '<|s|>',
#                      'Inline',
#                      'Clone',
#                      'Statement',
#                      'Visitor',
#                      '(',
#                      '<|nl|>',
#                      '<|4-s|>',
#                      '<|2-s|>',
#                      '@',
#                      'Nonnull',
#                      '<|s|>',
#                      'Transformation',
#                      'Request',
#                      '<|s|>',
#                      'tr',
#                      'Request',
#                      ',',
#                      '<|nl|>',
#                      '<|4-s|>',
#                      '<|2-s|>',
#                      '@',
#                      'Nonnull',
#                      '<|s|>',
#                      'JMethod',
#                      '<|s|>',
#                      'enclosing',
#                      'Method',
#                      ',',
#                      '<|nl|>',
#                      '<|4-s|>',
#                      '<|2-s|>',
#                      '@',
#                      'Nonnull',
#                      '<|s|>',
#                      'List',
#                      '<',
#                      'JCatch',
#                      'Block',
#                      '>',
#                      '<|s|>',
#                      'catch',
#                      'Blocks',
#                      ',',
#                      '<|nl|>',
#                      '<|4-s|>',
#                      '<|2-s|>',
#                      '@',
#                      'Check',
#                      'For',
#                      'Null',
#                      '<|s|>',
#                      'JLocal',
#                      '<|s|>',
#                      'return',
#                      'Local',
#                      ',',
#                      '<|nl|>',
#                      '<|4-s|>',
#                      '<|2-s|>',
#                      '@',
#                      'Check',
#                      'For',
#                      'Null',
#                      '<|s|>',
#                      'JLabeled',
#                      'Statement',
#                      '<|s|>',
#                      'return',
#                      'Target',
#                      ',',
#                      '<|nl|>',
#                      '<|startfocus|>',
#                      '<|nl|>',
#                      '<|4-s|>',
#                      '<|2-s|>',
#                      '@',
#                      'Check',
#                      'For',
#                      'Null',
#                      '<|s|>',
#                      'JVariable',
#                      '<|s|>',
#                      'target',
#                      'Instance',
#                      'Var',
#                      ',',
#                      '<|nl|>',
#                      '<|endfocus|>',
#                      '<|nl|>',
#                      '<|4-s|>',
#                      '<|2-s|>',
#                      '@',
#                      'Nonnull',
#                      '<|s|>',
#                      'Map',
#                      '<',
#                      'JParameter',
#                      ',<|',
#                      's',
#                      '|>',
#                      'JLocal',
#                      '>',
#                      '<|s|>',
#                      'parameter',
#                      'Map',
#                      ')',
#                      '<|s|>',
#                      '{',
#                      '<|nl|>',
#                      '<|4-s|>',
#                      'super',
#                      '(',
#                      'tr',
#                      'Request',
#                      ',',
#                      '<|s|>',
#                      'enclosing',
#                      'Method',
#                      ');',
#                      '<|nl|>',
#                      '<|4-s|>',
#                      'this',
#                      '.',
#                      'catch',
#                      'Blocks',
#                      '<|s|>',
#                      '=',
#                      '<|s|>',
#                      'catch',
#                      'Blocks',
#                      ';',
#                      '<|nl|>',
#                      '<|4-s|>',
#                      'this',
#                      '.',
#                      'return',
#                      'Local',
#                      '<|s|>',
#                      '=',
#                      '<|s|>',
#                      'return',
#                      'Local',
#                      ';',
#                      '<|nl|>',
#                      '<|4-s|>',
#                      'this',
#                      '.',
#                      'return',
#                      'Target',
#                      '<|s|>',
#                      '=',
#                      '<|s|>',
#                      'return',
#                      'Target',
#                      ';',
#                      '<|nl|>',
#                      '<|4-s|>',
#                      'this',
#                      '.',
#                      'parameter',
#                      'Map',
#                      '<|s|>',
#                      '=',
#                      '<|s|>',
#                      'parameter',
#                      'Map',
#                      ';',
#                      '<|nl|>',
#                      '<|4-s|>',
#                      'this',
#                      '.',
#                      'target',
#                      'Instance',
#                      'Var',
#                      '<|s|>',
#                      '=',
#                      '<|s|>',
#                      'target',
#                      'Instance',
#                      'Var',
#                      ';',
#                      '<|nl|>',
#                      '<|2-s|>',
#                      '}'],
#   'tokenized_comment': ['Missing',
#                         '<|s|>',
#                         'javadoc',
#                         '<|s|>',
#                         'for',
#                         '<|s|>',
#                         'this',
#                         '<|s|>',
#                         'one'],
#   'tufano_code': 'public VAR_1 ( super ( VAR_2 , VAR_3 ) ; this . VAR_4 = '
#                  'VAR_4 ; this . VAR_5 = VAR_5 ; this . VAR_6 = VAR_6 ; this . '
#                  'VAR_7 = VAR_7 ; this . VAR_8 = VAR_8 ; }',
#   'tufano_target': 'public VAR_1 ( super ( VAR_2 , VAR_3 ) ; this . VAR_4 = '
#                    'VAR_4 ; this . VAR_5 = VAR_5 ; this . VAR_6 = VAR_6 ; this '
#                    '. VAR_7 = VAR_7 ; this . VAR_8 = VAR_8 ; }',
#   'written_on': '2016-08-17 16:48:20'},
#  {'comment': 'Homogeneity?\n'
#              '\n'
#              'CRE: description + " failed to be read";\n'
#              'WPE: description + " is not " + ((permission == '
#              'Permission.READ)    ? "readable"\n'
#              'NFE: description + " is not actually a file"',
#   'idx': 667,
#   'our_code': '  protected String createMessage(@Nonnull String description) '
#               '{\n'
#               '<|startfocus|>\n'
#               '    String message = "failed to close " + description;\n'
#               '<|endfocus|>\n'
#               '    if (getCause() != null) {\n'
#               '      message += ": " + getCause().getMessage();\n'
#               '    }\n'
#               '    return message;\n'
#               '  }',
#   'our_target': '    String message = "failed to close " + description;\n'
#                 '    if (getCause() != null) {\n'
#                 '\r\n',
#   'project_name': 'android_',
#   'tokenized_code': ['<|2-s|>',
#                      'protected',
#                      '<|s|>',
#                      'String',
#                      '<|s|>',
#                      'create',
#                      'Message',
#                      '(',
#                      '@',
#                      'Nonnull',
#                      '<|s|>',
#                      'String',
#                      '<|s|>',
#                      'description',
#                      ')',
#                      '<|s|>',
#                      '{',
#                      '<|nl|>',
#                      '<|startfocus|>',
#                      '<|nl|>',
#                      '<|4-s|>',
#                      'String',
#                      '<|s|>',
#                      'message',
#                      '<|s|>',
#                      '=',
#                      '<|s|>',
#                      '"',
#                      'failed',
#                      '<|s|>',
#                      'to',
#                      '<|s|>',
#                      'close',
#                      '<|s|>',
#                      '"',
#                      '<|s|>',
#                      '+',
#                      '<|s|>',
#                      'description',
#                      ';',
#                      '<|nl|>',
#                      '<|endfocus|>',
#                      '<|nl|>',
#                      '<|4-s|>',
#                      'if',
#                      '<|s|>',
#                      '(',
#                      'get',
#                      'Cause',
#                      '(',
#                      ')',
#                      '<|s|>',
#                      '!=',
#                      '<|s|>',
#                      'null',
#                      ')',
#                      '<|s|>',
#                      '{',
#                      '<|nl|>',
#                      '<|4-s|>',
#                      '<|2-s|>',
#                      'message',
#                      '<|s|>',
#                      '+=',
#                      '<|s|>',
#                      '"',
#                      ':',
#                      '<|s|>',
#                      '"',
#                      '<|s|>',
#                      '+',
#                      '<|s|>',
#                      'get',
#                      'Cause',
#                      '(',
#                      ')',
#                      '.',
#                      'get',
#                      'Message',
#                      '(',
#                      ');',
#                      '<|nl|>',
#                      '<|4-s|>',
#                      '}',
#                      '<|nl|>',
#                      '<|4-s|>',
#                      'return',
#                      '<|s|>',
#                      'message',
#                      ';',
#                      '<|nl|>',
#                      '<|2-s|>',
#                      '}'],
#   'tokenized_comment': ['Homogeneity',
#                         '?',
#                         '<|nl|>',
#                         '<|nl|>',
#                         'CRE',
#                         ':',
#                         '<|s|>',
#                         'description',
#                         '<|s|>',
#                         '+',
#                         '<|s|>',
#                         '"',
#                         '<|s|>',
#                         'failed',
#                         '<|s|>',
#                         'to',
#                         '<|s|>',
#                         'be',
#                         '<|s|>',
#                         'read',
#                         '"',
#                         ';',
#                         '<|nl|>',
#                         'WPE',
#                         ':',
#                         '<|s|>',
#                         'description',
#                         '<|s|>',
#                         '+',
#                         '<|s|>',
#                         '"',
#                         '<|s|>',
#                         'is',
#                         '<|s|>',
#                         'not',
#                         '<|s|>',
#                         '"',
#                         '<|s|>',
#                         '+',
#                         '<|s|>',
#                         '(',
#                         '(',
#                         'permission',
#                         '<|s|>',
#                         '==',
#                         '<|s|>',
#                         'Permission',
#                         '.',
#                         'READ',
#                         ')',
#                         '<|4-s|>',
#                         '?',
#                         '<|s|>',
#                         '"',
#                         'readable',
#                         '"',
#                         '<|nl|>',
#                         'NFE',
#                         ':',
#                         '<|s|>',
#                         'description',
#                         '<|s|>',
#                         '+',
#                         '<|s|>',
#                         '"',
#                         '<|s|>',
#                         'is',
#                         '<|s|>',
#                         'not',
#                         '<|s|>',
#                         'actually',
#                         '<|s|>',
#                         'a',
#                         '<|s|>',
#                         'file',
#                         '"'],
#   'tufano_code': 'protected String VAR_1 ( message += STRING_1 + VAR_2 ( ) . '
#                  'VAR_3 ( ) ; } return message ; }',
#   'tufano_target': 'protected String VAR_1 ( if ( VAR_2 ( ) != null ) { if ( '
#                    'VAR_2 ( ) != null ) { message += STRING_1 + VAR_2 ( ) . '
#                    'VAR_3 ( ) ; } return message ; }',
#   'written_on': '2016-06-10 08:16:17'},
#  {'comment': 'No defensive copying?',
#   'idx': 673,
#   'our_code': '  public StringResourceData(@NotNull AndroidFacet facet,\n'
#               '                            @NotNull List<String> keys,\n'
#               '                            @NotNull '
#               'SortedMap<String,<|s|>StringResource> keyToResourceMap,\n'
#               '                            @NotNull Collection<Locale> '
#               'locales) {\n'
#               '    myFacet = facet;\n'
#               '<|startfocus|>\n'
#               '    myKeys = Lists.newArrayList(keys);\n'
#               '    myKeyToResourceMap = Maps.newTreeMap(keyToResourceMap);\n'
#               '<|endfocus|>\n'
#               '    myLocales = Lists.newArrayList(locales);\n'
#               '  }',
#   'our_target': '    myKeys = Lists.newArrayList(keys);\n'
#                 '    myKeyToResourceMap = Maps.newTreeMap(keyToResourceMap);\n'
#                 '    myLocales = Lists.newArrayList(locales);\n'
#                 '\r\n',
#   'project_name': 'android_',
#   'tokenized_code': ['<|2-s|>',
#                      'public',
#                      '<|s|>',
#                      'String',
#                      'Resource',
#                      'Data',
#                      '(',
#                      '@',
#                      'Not',
#                      'Null',
#                      '<|s|>',
#                      'Android',
#                      'Facet',
#                      '<|s|>',
#                      'facet',
#                      ',',
#                      '<|nl|>',
#                      '<|16-s|>',
#                      '<|12-s|>',
#                      '@',
#                      'Not',
#                      'Null'
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# '<|nl|>',
#                      '<|4-s|>',
#                      '}'],
#   'tokenized_comment': ['final', '?'],
#   'tufano_code': 'private boolean METHOD_1 ( ) { TYPE_1 VAR_1 = ( TYPE_1 ) '
#                  'VAR_2 . getContext ( ) . METHOD_2 ( VAR_3 ) ; return VAR_1 . '
#                  'METHOD_3 ( ) ; }',
#   'tufano_target': 'private boolean VAR_1 ( ) { final VAR_2 VAR_3 = ( VAR_2 ) '
#                    'VAR_4 . getContext ( ) . VAR_5 ( VAR_6 ) ; VAR_6 ) ; '
#                    'return VAR_7 ( ) ; }',
#   'written_on': '2017-02-27 17:55:09'},
#  {'comment': 'you can combine this with the previous line\n'
#              'Intent intent = new Intent()\n'
#              '                .putExtra();',
#   'idx': 889,
#   'our_code': '    private static void moveToBackgroundNotification(Context '
#               'context, boolean show) {\n'
#               '<|startfocus|>\n'
#               '        Intent intent = new Intent(ACTION_ONGOING_CALL);\n'
#               '        intent.putExtra(EXTRA_ONGOING_CALL_SHOW, show);\n'
#               '<|endfocus|>\n'
#               '        context.sendBroadcast(intent);\n'
#               '    }',
#   'our_target': '        Intent intent = new '
#                 'Intent(TelecomManager.ACTION_ONGOING_CALL)\n'
# ...
#                      ',',
#                      '<|s|>',
#                      '"',
#                      'Interrupt',
#                      '<|s|>',
#                      'received',
#                      '<|s|>',
#                      'while',
#                      '<|s|>',
#                      'waitinf',
#                      '<|s|>',
#                      'for',
#                      '<|s|>',
#                      'de',
#                      '-',
#                      'init',
#                      '<|s|>',
#                      'to',
#                      '<|s|>',
#                      'complete',
#                      '"',
#                      ',',
#                      '<|s|>',
#                      'e',
#                      ');',
#                      '<|nl|>',
#                      '<|16-s|>',
#                      '}',
#                      '<|nl|>',
#                      '<|12-s|>',
#                      '}',
#                      '<|nl|>',
#                      '<|nl|>',
#                      '<|12-s|>',
#                      'if',
#                      '(',
#                      'm',
#                      'Intent',
#                      'Receiver',
#                      '<|s|>',
#                      '!=',
#                      '<|s|>',
#                      'null',
#                      ')',
#                      '<|s|>',
#                      '{',
#                      '<|nl|>',
#                      '<|16-s|>',
#                      'm',
#                      'Context',
#                      '.',
#                      'unregister',
#                      'Receiver',
#                      '(',
#                      'm',
#                      'Intent',
#                      'Receiver',
#                      ');',
#                      '<|nl|>',
#                      '<|16-s|>',
#                      'm',
#                      'Intent',
#                      'Receiver',
#                      '<|s|>',
#                      '=',
#                      '<|s|>',
#                      'null',
#                      ';',
#                      '<|nl|>',
#                      '<|12-s|>',
#                      '}',
#                      '<|nl|>',
#                      '<|12-s|>',
#                      'stop',
#                      'Disconnect',
#                      'Timer',
#                      '(',
#                      ');',
#                      '<|nl|>',
#                      '<|12-s|>',
#                      'clear',
#                      'Notification',
#                      '(',
#                      ');',
#                      '<|nl|>',
#                      '<|nl|>',
#                      '<|12-s|>',
#                      'if',
#                      '(',
#                      'm',
#                      'Handler',
#                      'Thread',
#                      '<|s|>',
#                      '!=',
#                      '<|s|>',
#                      'null',
#                      ')',
#                      '<|s|>',
#                      'try',
#                      '<|s|>',
#                      '{',
#                      '<|nl|>',
#                      '<|16-s|>',
#                      'm',
#                      'Handler',
#                      'Thread',
#                      '.',
#                      'quit',
#                      '(',
#                      ');',
#                      '<|nl|>',
#                      '<|16-s|>',
#                      'm',
#                      'Handler',
#                      'Thread',
#                      '.',
#                      'join',
#                      '(',
#                      ');',
#                      '<|nl|>',
#                      '<|16-s|>',
#                      'm',
#                      'Handler',
#                      'Thread',
#                      '<|s|>',
#                      '=',
#                      '<|s|>',
#                      'null',
#                      ';',
#                      '<|nl|>',
#                      '<|12-s|>',
#                      '}',
#                      '<|s|>',
#                      'catch',
#                      '<|s|>',
#                      '(',
#                      'Interrupted',
#                      'Exception',
#                      '<|s|>',
#                      'e',
#                      ')',
#                      '<|s|>',
#                      '{',
#                      '}',
#                      '<|nl|>',
#                      '<|12-s|>',
#                      'if',
#                      '(',
#                      'm',
#                      'Ril',
#                      'Bt',
#                      'Receiver',
#                      'Thread',
#                      '<|s|>',
#                      '!=',
#                      '<|s|>',
#                      'null',
#                      ')',
#                      '<|s|>',
#                      'try',
#                      '<|s|>',
#                      '{',
#                      '<|nl|>',
#                      '<|16-s|>',
#                      'if',
#                      '(',
#                      'm',
#                      'Ril',
#                      'Bt',
#                      'Receiver',
#                      '<|s|>',
#                      '!=',
#                      '<|s|>',
#                      'null',
#                      ')',
#                      '<|s|>',
#                      '{',
#                      '<|nl|>',
#                      '<|16-s|>',
#                      '<|4-s|>',
#                      'm',
#                      'Ril',
#                      'Bt',
#                      'Receiver',
#                      '.',
#                      'shutdown',
#                      '(',
#                      ');',
#                      '<|nl|>',
#                      '<|16-s|>',
#                      '<|4-s|>',
#                      'm',
#                      'Ril',
#                      'Bt',
#                      'Receiver',
#                      '<|s|>',
#                      '=',
#                      '<|s|>',
#                      'null',
#                      ';',
#                      '<|nl|>',
#                      '<|16-s|>',
#                      '}',
#                      '<|nl|>',
#                      '<|16-s|>',
#                      'm',
#                      'Ril',
#                      'Bt',
#                      'Receiver',
#                      'Thread',
#                      '.',
#                      'join',
#                      '(',
#                      ');',
#                      '<|nl|>',
#                      '<|16-s|>',
#                      'm',
#                      'Ril',
#                      'Bt',
#                      'Receiver',
#                      'Thread',
#                      '<|s|>',
#                      '=',
#                      '<|s|>',
#                      'null',
#                      ';',
#                      '<|nl|>',
#                      '<|12-s|>',
#                      '}',
#                      '<|s|>',
#                      'catch',
#                      '<|s|>',
#                      '(',
#                      'Interrupted',
#                      'Exception',
#                      '<|s|>',
#                      'e',
#                      ')',
#                      '<|s|>',
#                      '{',
#                      '}',
#                      '<|nl|>',
#                      '<|nl|>',
#                      '<|12-s|>',
#                      'if',
#                      '(',
#                      'm',
#                      'Rfcomm',
#                      'In',
#                      '<|s|>',
#                      '!=',
#                      '<|s|>',
#                      'null',
#                      ')',
#                      '<|s|>',
#                      'try',
#                      '<|s|>',
#                      '{',
#                      '<|nl|>',
#                      '<|16-s|>',
#                      'if',
#                      '(',
#                      'VERBOSE',
#                      ')',
#                      '<|s|>',
#                      'Log',
#                      '.',
#                      'i',
#                      '(',
#                      'TAG',
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 'loop',
#                         ',',
#                         '<|s|>',
#                         'maybe',
#                         '<|s|>',
#                         'extract',
#                         '<|s|>',
#                         'this',
#                         '<|s|>',
#                         'to',
#                         '<|s|>',
#                         'a',
#                         '<|s|>',
#                         'local',
#                         '<|s|>',
#                         'variable',
#                         '<|s|>',
#                         'at',
#                         '<|s|>',
#                         'the',
#                         '<|s|>',
#                         'beginning',
#                         '<|s|>',
#                         'of',
#                         '<|s|>',
#                         'the',
#                         '<|s|>',
#                         'method',
#                         '?'],
#   'tufano_code': 'private static TYPE_1 METHOD_1 ( ) { for ( TYPE_1 VAR_1 : '
#                  'TYPE_2 . METHOD_2 ( ) ) { String VAR_2 = VAR_1 . METHOD_3 ( '
#                  ') ; if ( METHOD_4 ( ) . METHOD_5 ( VAR_2 ) ) { return VAR_1 '
#                  '; } } return null ; }',
#   'tufano_target': 'private static TYPE_1 METHOD_1 ( ) { for ( TYPE_1 VAR_1 : '
#                    'TYPE_2 . METHOD_2 ( ) ) { String VAR_2 = VAR_1 . METHOD_3 '
#                    '( ) ; if ( METHOD_4 ( VAR_2 ) ) { return VAR_1 ; return '
#                    'VAR_1 ; } } return null ; }',
#   'written_on': '2013-07-12 19:21:28'},
#  {'comment': 'Nit: indentation is off.',
#   'idx': 93745,
#   'our_code': '\tprivate static void allocateUnreachableObjects() {\n'
#               '<|startfocus|>\n'
#               '        for(int i = 0; i <<|s|>unreachableObjNum; i++) {\n'
#               '<|endfocus|>\n'
#               '            new MockClass(false);\n'
#               '        }\n'
#               '\t}',
#   'our_target': '        for(int i = 0; i < unreachableObjNum; i++) {\n'
#                 '            new MockClass(false);\n'
#                 '\r\n',
#   'project_name': 'android_',
#   'tokenized_code': ['<|t|>',
#                      'private',
#                      '<|s|>',
#                      'static',
#                      '<|s|>',
#                      'void',
#                      '<|s|>',
#                      'allocate',
#                      'Unreachable',
#                      'Objects',
#                      '(',
#                      ')',
#                      '<|s|>',
#                      '{',
#                      '<|nl|>',
#                      '<|startfocus|>',
#                      '<|nl|>',
#                      '<|8-s|>',
#                      'for',
#                      '(',
#                      'int',
#                      '<|s|>',
#                      'i',
#                      '<|s|>',
#                      '=',
#                      '<|s|>',
#                      '0',
#                      ';',
#                      '<|s|>',
#                      'i',
#                      '<|s|>',
#                      '<<|',
#                      's',
#                      '|>',
#                      'unreachable',
#                      'Obj',
#                      'Num',
#                      ';',
#                      '<|s|>',
#                      'i',
#                      '++',
#                      ')',
#                      '<|s|>',
#                      '{',
#                      '<|nl|>',
#                      '<|endfocus|>',
#                      '<|nl|>',
#                      '<|12-s|>',
#                      'new',
#                      '<|s|>',
#                      'Mock',
#                      'Class',
#                      '(',
#                      'false',
#                      ');',
#                      '<|nl|>',
#                      '<|8-s|>',
#                      '}',
#                      '<|nl|>',
#                      '<|t|>',
#                      '}'],
#   'tokenized_comment': ['Nit',
#                         ':',
#                         '<|s|>',
#                         'indentation',
#                         '<|s|>',
#                         'is',
#                         '<|s|>',
#                         'off',
#                         '.'],
#   'tufano_code': 'private static void VAR_1 ( ) { for ( int i = 0 ; i < < | '
#                  'VAR_2 | > VAR_3 ; i ++ ) { new VAR_4 ( false ) ; } }',
#   'tufano_target': 'private static void METHOD_1 ( ) { for ( int i = 0 ; i < '
#                    'VAR_1 ; i ++ ) { new TYPE_1 ( false ) ; new TYPE_1 ( false '
#                    ') ; } }',
#   'written_on': '2017-04-10 14:33:19'},
#  {'comment': 'I thought I saw this constant defined somewhere in an earlier '
#              'file?',
#   'idx': 95688,
#   'our_code': '  public static boolean isAppEngineFacet(Facet facet) {\n'
#               '<|startfocus|>\n'
#               '    if '
#               '(facet.getType().getStringId().equals("google-app-engine")) {\n'
#               '<|endfocus|>\n'
#               '      return true;\n'
#               '    }\n'
#               '    return false;\n'
#               '  }',
#   'our_target': '    if '
#                 '(facet.getType().getStringId().equals("google-app-engine")) '
#                 '{\n'
#                 '      return true;\n'
#                 '\r\n',
#   'project_name': 'android_',
#   'tokenized_code': ['<|2-s|>',
#                      'public',
#                      '<|s|>',
#                      'static',
#                      '<|s|>',
#                      'boolean',
#                      '<|s|>',
#                      'is',
#                      'App',
#                      'Engine',
#                      'Facet',
#                      '(',
#                      'Facet',
#                      '<|s|>',
#                      'facet',
#                      ')',
#                      '<|s|>',
#                      '{',
#                      '<|nl|>',
#                      '<|startfocus|>',
#                      '<|nl|>',
#                      '<|4-s|>',
#                      'if',
#                      '<|s|>',
#                      '(',
#                      'facet',
#                      '.',
#                      'get',
#                      'Type',
#                      '(',
#                      ')',
#                      '.',
#                      'get',
#                      'String',
#                      'Id',
#                      '(',
#                      ')',
#                      '.',
#                      'equals',
#                      '(',
#                      '"',
#                      'google',
#                      '-',
#                      'app',
#                      '-',
#                      'engine',
#                      '"',
#                      ')',
#                      ')',
#                      '<|s|>',
#                      '{',
#                      '<|nl|>',
#                      '<|endfocus|>',
#                      '<|nl|>',
#                      '<|4-s|>',
#                      '<|2-s|>',
#                      'return',
#                      '<|s|>',
#                      'true',
#                      ';',
#                      '<|nl|>',
#                      '<|4-s|>',
#                      '}',
#                      '<|nl|>',
#                      '<|4-s|>',
#                      'return',
#                      '<|s|>',
#                      'false',
#                      ';',
#                      '<|nl|>',
#                      '<|2-s|>',
#                      '}'],
#   'tokenized_comment': ['I',
#                         '<|s|>',
#                         'thought',
#                         '<|s|>',
#                         'I',
#                         '<|s|>',
#                         'saw',
#                         '<|s|>',
#                         'this',
#                         '<|s|>',
#                         'constant',
#                         '<|s|>',
#                         'defined',
#                         '<|s|>',

# %%
tufano_less_then_50 = getJsonData("less_then_50.json")
tufano_less_then_100 = getJsonData("less_then_100.json")

# %%
from os import path
import json
import re
import subprocess
import nltk
from pprint import pprint
from nltk.tokenize import sent_tokenize, word_tokenize
from tqdm import tqdm
nltk.download('punkt')

def merge_code_comment(x):
    message = x['message']
    source = ' '.join(x['tokenized_code_snippet'])
    target = ' '.join(x['target'])
    merged = message + '<>' + source + '<>' + target
    return merged

def get_source_target(file1, file2, line_number, change_window_size=5):
    source_target = subprocess.check_output(['java', '-jar', 'ChangedLineF.jar', \
                                file1, file2, str(line_number), str(change_window_size)]).decode("utf-8")
    (source, target) = source_target.split("<|source-target-sep|>")
    return source, target

def end_scope(start_index, lines):
    #print(lines)
    counter = 0
    end_index = -1
    found = False
    for index in range(start_index, len(lines), 1):
        #print(lines[index])
        #print(counter)
        for char in lines[index]:
            if(char=='{'):
                counter+=1
                found = True
            elif(char == "}"):
                counter-=1
                found = True
            if(counter==0 and found):
                end_index = index
                break
        if end_index!=-1:
            break
    return end_index

import traceback
existing_ids = set()
duplicate_ids = set()
unique_dat = []
i = 0
target_size = 400
error_count = 0
error_list = []
'''
for dt in tufano_less_then_50:
    #print(dt['idx'])
    x = unique_data[dt['idx']]
    i+= 1
    try:
        focuslen = x['tokenized_code_snippet'].index('<|endfocus|>') - x['tokenized_code_snippet'].index('<|startfocus|>')
        key = merge_code_comment(x)
        if key not in existing_ids and len(x['tokenized_target']) <= target_size and focuslen <= target_size:
            existing_ids.add(key)
            unique_dat.append(i-1)
        elif key not in duplicate_ids:
            duplicate_ids.add(key)
    except Exception as e:
        print(e)
        x['error'] = e
        error_list.append(x)
        error_count += 1
        #print(x)
        #break
print(len(unique_dat))
'''

for dt in tufano_less_then_100:
    #print(dt['idx'])
    x = unique_data[dt['idx']]
    i+= 1
    try:
        focuslen = x['tokenized_code_snippet'].index('<|endfocus|>') - x['tokenized_code_snippet'].index('<|startfocus|>')
        key = merge_code_comment(x)
        if key not in existing_ids and len(x['tokenized_target']) <= target_size and focuslen <= target_size:
            existing_ids.add(key)
            unique_dat.append(i-1)
        elif key not in duplicate_ids:
            duplicate_ids.add(key)
    except Exception as e:
        print(e)
        x['error'] = e
        error_list.append(x)
        error_count += 1
        #print(x)
        #break
print(len(unique_dat))
'''
train_new = []

for idx, dt in enumerate(unique_data):
    x = dt
    focuslen = x['tokenized_code_snippet'].index('<|endfocus|>') - x['tokenized_code_snippet'].index('<|startfocus|>')
    key = merge_code_comment(x)
    if key not in existing_ids and len(x['tokenized_target']) <= target_size and focuslen <= target_size and idx not in unique_dat:
        train_new.append(idx)
        existing_ids.add(key)
        unique_dat.append(i-1)
    elif key not in duplicate_ids:
        duplicate_ids.add(key)
print(len(train_new))

'''
manual_less_then_50 = []
manual_less_then_100 = []
for i in unique_dat: #1:75
    mnl = {}
    dt = tufano_less_then_100[i]
    #print(dt['idx'])
    #print(dt['source'])
    data = unique_data[dt['idx']]
    code_file_name = data['code_file_name']
    base_patch_number = data['base_patch_number']
    changed_patch_number = data['changed_patch_number']
    main_code_path = BASE+code_file_name+'/'+str(base_patch_number)+'.java'
    changed_code_path = BASE+code_file_name+'/'+str(changed_patch_number)+'.java'
    line_no = data['base_code_line_number']
    main_code = read(main_code_path)
    changed_code = read(changed_code_path)
    sample = main_code
    message = data['message']
    comment_id = data['comment_id']
    detokenized_code = extreme_detokenization(data['tokenized_code_snippet'])
    #print(detokenized_code.replace("<|startfocus|>\n", "").replace("<|endfocus|>\n", ""))
    mnl['idx'] = dt['idx']
    mnl['comment'] = message
    mnl['tokenized_comment'] = data['tokenized_comment']
    mnl['tufano_code'] = dt['source']
    mnl['our_code'] = detokenized_code#.replace("<|startfocus|>\n", "").replace("<|endfocus|>\n", "")
    mnl['tokenized_code'] = data['tokenized_code_snippet']
    mnl['written_on'] = dt['written_on']
    
    start_f = detokenized_code.find("\n<|startfocus|>\n")
    end_f = detokenized_code.find("\n<|endfocus|>\n")
    repl_st = detokenized_code[start_f:end_f+15]
    #print(repl_st)
    mnl['our_target'] = target
    manual_less_then_100.append(mnl)
with open('manual_less_then_100.json', 'w', encoding="utf8") as f:  # writing JSON object
    json.dump(manual_less_then_100, f)
print(len(manual_less_then_100))
manual_less_then_100[0]

# %%
#print(unique_data[0].keys())
print(tufano_less_then_50[0].keys())

# %%
import json
def getJsonData(JsonFile):
    with open(JsonFile, encoding="utf8") as f:
        data = json.load(f)
    return data
def read(path):
    return open(path, 'r', encoding = 'utf-8').read()


BASE="E:/codes/"
unique_data = getJsonData('E:\\unified_with_date.json')
print(len(unique_data))

# %%
pprint(unique_data[768])

# %%
dt = getJsonData('manual_less_then_50.json')
print(len(dt))
print(dt[0]['idx'])
for key in dt[0]:
    if(dt[0][key]!=tufano_less_then_50[0][key]):
        print(dt[0][key])
        print(tufano_less_then_50[0][key])
        print(dt[0]['our_code'])
#print(dt[0]['idx'])
#tufano_less_then_50[0]['idx']
# Out:
# 912
# 37
# private static void VAR_1 ( ) { < | VAR_2 | > for ( int i = 0 ; i < < | VAR_3 | > VAR_4 ; i ++ ) { < | VAR_5 | > new VAR_6 ( false ) ; } }
# private static void VAR_1 ( ) { for ( int i = 0 ; i < < | VAR_2 | > VAR_3 ; i ++ ) { new VAR_4 ( false ) ; } }
# 	private static void allocateUnreachableObjects() {
# <|startfocus|>
#         for(int i = 0; i <<|s|>unreachableObjNum; i++) {
# <|endfocus|>
#             new MockClass(false);
#         }
# 	}

# %%
tufano_less_then_50[0].keys()
# Out:
# dict_keys(['idx', 'project_name', 'written_on', 'tufano_target', 'comment', 'tokenized_comment', 'tufano_code', 'our_target', 'our_code', 'tokenized_code'])

# %%
data = unique_data[37]
print(extreme_detokenization(extreme_tokenization(data['source'][2020:2200])))

print(extreme_detokenization(data['tokenized_code_snippet']))
# Out:
# private static void allocateUnreachableObjects() {
# <|startfocus|>
#         for(int i = 0; i < unreachableObjNum; i++) {
# <|endfocus|>
#             new MockClass(false);
#         }
# 	}
#
#
# 	private static void allocateUnreachableObjects() {
# <|startfocus|>
#         for(int i = 0; i <<|s|>unreachableObjNum; i++) {
# <|endfocus|>
#             new MockClass(false);
#         }
# 	}
